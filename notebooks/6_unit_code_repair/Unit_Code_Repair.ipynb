# %% [markdown]
# ## load in cddb table

# %%
import numpy as np
import pandas as pd
 

data = pd.read_csv("../../cleaning_stages/6_openrefine_drop_bad/cddb-4-drop.tsv", sep='\t')
tracks = pd.read_csv("../../cleaning_stages/6_openrefine_drop_bad/cddb-tracks.tsv", sep='\t')


# printing data
print(data)
# Out:
#                               artist                category
# 0                    Backstreet Boys                   Blues  \
# 1                          No Return                    Data
# 2          Ã¤â¸â­ã¦?â€˜ã©â€ºâ€¦ã¤â¿å                     Pop
# 3                            Emanuel  Classic Portuguese Pop
# 4                   Luv Lite Massive              Electronic
# ...                              ...                     ...
# 7658  Various Artists - Notting Hill                   Blues
# 7659                          Lenine                   Blues
# 7660                      Ben Harper                   Blues
# 7661                       Alvin Lee                   Blues
# 7662                 Manuel Barrueco                   Blues
#
#                        genre                                         title
# 0                        Pop                                    Millennium  \
# 1                       Data                               Self Mutilation
# 2                        Pop  Ã¦æ’â³ã£?â€žã¥â€¡âºã£?â®ã£?â€¹ã£?â€˜ã£â€šâ€°
# 3     Classic Portuguese Pop                                    Felicidade
# 4                 Electronic                                      One Love
# ...                      ...                                           ...
# 7658              Soundtrack                                  Notting Hill
# 7659                   Samba                                    Na Pressao
# 7660                   Blues                              The Will To Live
# 7661                   Blues                            I Hear You Rockin'
# 7662                    Jazz                                 Nylon & Steel
#
#       tracks  year      id  merged_values
# 0       1000  1999   10000            NaN
# 1       1002  2019  100002            NaN
# 2       1003  1989  100003            NaN
# 3       1004  1998  100004            NaN
# 4       1006  2014  100006            NaN
# ...      ...   ...     ...            ...
# 7658   10758  1999    9838            NaN
# 7659   10759  1999    9863            NaN
# 7660   10760  1997    9868            NaN
# 7661   10761  1993    9876            NaN
# 7662   10762  2001    9969            NaN
#
# [7663 rows x 8 columns]

# %%
# Removing merged_values column becasue it is all null
data.drop('merged_values', axis=1, inplace=True)

# outpus test
print(data)
# Out:
#                               artist                category
# 0                    Backstreet Boys                   Blues  \
# 1                          No Return                    Data
# 2          Ã¤â¸â­ã¦?â€˜ã©â€ºâ€¦ã¤â¿å                     Pop
# 3                            Emanuel  Classic Portuguese Pop
# 4                   Luv Lite Massive              Electronic
# ...                              ...                     ...
# 7658  Various Artists - Notting Hill                   Blues
# 7659                          Lenine                   Blues
# 7660                      Ben Harper                   Blues
# 7661                       Alvin Lee                   Blues
# 7662                 Manuel Barrueco                   Blues
#
#                        genre                                         title
# 0                        Pop                                    Millennium  \
# 1                       Data                               Self Mutilation
# 2                        Pop  Ã¦æ’â³ã£?â€žã¥â€¡âºã£?â®ã£?â€¹ã£?â€˜ã£â€šâ€°
# 3     Classic Portuguese Pop                                    Felicidade
# 4                 Electronic                                      One Love
# ...                      ...                                           ...
# 7658              Soundtrack                                  Notting Hill
# 7659                   Samba                                    Na Pressao
# 7660                   Blues                              The Will To Live
# 7661                   Blues                            I Hear You Rockin'
# 7662                    Jazz                                 Nylon & Steel
#
#       tracks  year      id
# 0       1000  1999   10000
# 1       1002  2019  100002
# 2       1003  1989  100003
# 3       1004  1998  100004
# 4       1006  2014  100006
# ...      ...   ...     ...
# 7658   10758  1999    9838
# 7659   10759  1999    9863
# 7660   10760  1997    9868
# 7661   10761  1993    9876
# 7662   10762  2001    9969
#
# [7663 rows x 7 columns]

# %% [markdown]
# ## Methods

# %%
# this method is a custom value checking
# returns true if input is not unit code
# returns false if input should be deleted

def check_mangled_code(string):
    
    return_var = True
    check_string = string.lower().strip()

    # accptable characters
    # mainly want to catch mangled unit code
    # tried to allow some foreign language
    ok = dict.fromkeys('''0123456789qwertyuioplkjhgfdsazxcvbnm?¦%!±‡ªš½“Ãã /'°~.,-()‰&:;±®ã­ã¨[*]_ãº´+¡ÿ©¶ã¤¸\\#`³²¹â§º¥¼¾''')
    
    # check if ?????
    # two ?? in a row is mangled code
    if "??" in check_string:
        return_var = False
    
    # check if mangled
    elif all(c in ok for c in check_string) == False:
        return_var = False

    return return_var

# %%
good_test = "BackstreetBoys,Blues,Pop,Millennium,1000,1999,10000"
bad_test = "Ã¤â¸â­ã¦?â€˜ã©â€ºâ€¦ã¤â¿å,Pop,Pop,Ã¦æ’â³ã£?â€žã¥â€¡âºã£?â®ã£?â€¹ã£?â€˜ã£â€šâ€°,1003,1989,100003"
another_test = "LesjaskogTrekkspillklubb,Folk,Gammeldans,TrekkspilltreffISã¸ristua,1273,1998,100282"
print(check_mangled_code(good_test))
print(check_mangled_code(bad_test))
print(check_mangled_code(another_test))
# Out:
# True
# False
# True

# %%
def unit_code_repair(df):
    rows_to_drop = []
    
    for i, row in df.iterrows():
        # 1. get row values as string
        row_str = df.iloc[i,:].to_string(header=False, index=False)
        row_str = row_str.replace(" ", "").replace('\n', ',').replace('\r', ',').replace('\t', '').strip()
        
        # 2. condition checking
        if check_mangled_code(row_str) == False:
            # 3. remove from df - add to dictionary
            rows_to_drop.append(i)
            print(row_str)

    return df, rows_to_drop

# %% [markdown]
# ## running method

# %%
# test_data = data.head(3)
# clean_data_test, rr1_t = unit_code_repair(test_data)
# # output below shows what was cleaned
# print("Test Data removed: " + str(len(rr1_t)) + " rows")

clean_data, rr1 = unit_code_repair(data)
print("------------------------------------------------")
clean_tracks, rr2 = unit_code_repair(tracks)

# output below shows what was cleaned
print("Data removed: " + str(len(rr1)) + " rows")
print("Tracks removed: " + str(len(rr2)) + " rows")
# Out:
# Ã¤â¸â­ã¦?â€˜ã©â€ºâ€¦ã¤â¿å,Pop,Pop,Ã¦æ’â³ã£?â€žã¥â€¡âºã£?â®ã£?â€¹ã£?â€˜ã£â€šâ€°,1003,1989,100003
# V.A,Ccm,Ccm,Ãƒã âºâ¹(cd09),1024,2001,100027
# Ã¥â±â±ã¥?â£ã§â„¢â¾ã¦?âµ,Jpop,Jpop,Disc13Ã¨å â±ã£?â€“ã£?â€¹ã£â€šå,1027,2003,100030
# Ã¥?â€šã¦å“â¬ã§å“å¸ã§â¶â¾,Pop,Pop,Lucy,1030,2001,100034
# V.A.,Ã£â€šâµã£â€šâ¦ã£æ’â³ã£æ’â€°ã£æ’ë†ã£æ’â©ã£æ’æ’ã£...,Ã£â€šâµã£â€šâ¦ã£æ’â³ã£æ’â€°ã£æ’ë†ã£æ’â©ã£æ’æ’ã£...,BeatingSurviver-another-,1039,2002,100043
# Ã¥â±â±ã¥â´å½ã£?â¾ã£?â€¢ã£â€šë†ã£?â€”,Jpop,Jpop,Home,1047,1997,100051
# Ã¤ã®ã«ã¥ã°ã¤Ã¹ã¬Ã¤ã¢ã¸ã¥ã¡,Data,Data,Ã¤ã£ã¢Ã°ã§ã¹,1049,2019,100054
# Ã©ë†â´ã¦å“â¨ã£?â€šã£?â¿,Jpop,Jpop,InfinityEighteenVol.1,1052,2000,100057
# Ã§å¸â¢ã¦â²â¢ã¦â°â¸ã¥?â€°,Rock,Rock,SuperLiveÃ¦â€”â¥ã¦å“â¬ã¦â­â¦ã©?â€œã©â¤â¨Disc1,1054,1990,100059
# Â¿ã€ããÿâ±ã¢ãˆâ¹,ContemporaryChristianMusic,ContemporaryChristianMusic,Â»ãµâºâ®â±ã¢âµâµâ¸â¦Ã€â§ã‡ã‘Â°ã¦ã€â½â¾ã‡6,1065,2002,100071
# Ã±ã¡ã®ã°ã­ã¨ãª,Pop,Pop,Absolutãã›ã‰Ã•ãˆã’2,1068,2003,100074
# Ã£?â€¢ã£?â ã£?â¾ã£?â€¢ã£?â€”,Folk,Folk,Ã¤â¸â‚¬ã¤âºâºã§â„¢â¾ã¦â­å’Ã¥â·â»ã¤âºå’,1113,2019,100120
# VariousArtists,Folk,Folk,Ã¤â¸â­ã¥â³â¶ã£?â¿ã£â€šâ€ ã£??SongLibrary1,1146,1997,100153
# Â°ãâ·ã§â±j,Folk,Folk,Â¤sâ¨â£â¤ã«â©ãº,1177,1981,100184
# Ã€ã«ã¥ãªã±ã ã­ã¤ã°Ãã®ã¢ã¨ãªã®ã¢,Folk,Chanson,Ã‘Ãªã°ã ã±ã ã¢ã¨ã¶ã¥ã©Ã¢Ã®ã¡ã­ã¨ã¬ãªã³,1180,1996,100187
# Â¿â¹â¼ã¶ã€ã¼âµâµâ´ãœ,Folk,Gospel,Ã‡ã¢â±ã¢,1208,1999,100216
# Â½â²âµ^,Folk,Jazz,Â½â²âµ^âªã·â¤ã¹â¤lâ¡]â³ã¼â¡^â¤ã‘â²pâºqâ¤k,1327,2001,100338
# Ãƒâ«â®dâ¡â¢ã‘ã®ãâ¼â¡â¢ã€ã®ã¨âªâ¡â¢ã‚ãžâºâ£ã“â¢,Folk,Folk,Ã”ã§â´âºâµã„ã’ã´â·ã»,1372,1999,100385
# Ã‚ã«ã ã¤ã¨ã¬ã¨ã°Ã‚ã»ã±ã®ã¶ãªã¨ã©,Folk,Folk,Ã‚ã«ã ã¤ã¨ã¬ã¨ã°Ã‚ã»ã±ã®ã¶ãªã¨ã©Ã¢Ã§ã ã¯ã¨ã±...,1409,2023,100422
# Ãžã«ã¥ã£Ãšã®ã±ã²ã°ã®ã¢,Folk,Folk,Ãˆã¢ã®ã­ã­ã,1433,2021,100446
# Â³â¯â«ã˜â¦~,Folk,Folk,Â®ã¼â¬v,1435,2017,100449
# Ã ã¸ã©ã·Ã ã©ã©ã°ã¹ã¨ã©ã©ã¯,Folk,Ã©ã¬ã£ã©ã­,Ã¤ã ã¸ã©ã¤,Ã¤ã©ã¥ã°ã¤Ã¥ãºã¸ã°ã¢ã¥ã¬ãºÃ«ã§ã¥ã¬ã¤,1486,1992,100500
# Ãã ã¤ã¥ã¦ã¤ã Ãã ã¡ãªã¨ã­ã,Folk,Folklore,Ãã³ã±ã±ãªã ã¿Ã¯ã¥ã±ã­ã¿3/3,1506,1995,100521
# Ã©â»â€™ã§â„¢â¾ã¥?ë†ã¥â§â€°ã¥â¦â¹,Folk,Gothic,Ã¦å“ë†ã£?â®ã¨?â€¢,1510,1993,100525
# Â³â¶â¸â¸ã€ã‡Ã…ã«â±ã¢ã…â¸,Folk,Folk,Â¹ãœâ»ã§â¸â®ã¦ã‡ãšâ°1,1660,2001,100679
# Ãšã®ã°ã®ã«ã¥ã¢Ã‚ã¨ãªã²ã®ã°,Folk,Chanson,Ãã¼ã¿ã­ã ã¿Ã‚ã¨ã¸ã­ã¿,1698,2000,100717
# Ã£?å¸ã£?â¾,Folk,Folk,Ã¦?â±ã¤âºâ¬ã£æ’â€¢ã£æ’â«ã£æ’â¼ã£æ’â€ž,1706,2000,100726
# Ã£â€šâµã£â€šâ¤ã£â€šâ²ã£æ’â³ã£â€šâ¸,Folk,Indie,Saigenji,1753,2002,100775
# Ãœã¥ã«ãœã²Ã†ã¡ã¶ã¥ãÿã±ã§ã²,Folk,Folk,Ã†ã¹ãžÃ°ã¡ã±ã¡ã¬ãµã¨ãã­ã©ã¡,1785,2003,100808
# Ã’ã ã²ã¼ã¿ã­ã Ãã³ã«ã ã­ã®ã¢ã,Jazz,Pop,Ã‡ã®ã«ã®ã²ã®Ã«ã¾ã¡ã¢ã¨,1833,2001,100856
# Ã¥â²â¡ã¥â®â€°ã¨å â³ã¦ëœå½,Jazz,Jazz,Dear,1862,2001,100885
# Â¥ã‰â¸mâ¯eâ¤g(kojiTamaki),Jazz,Pop,Â°sâ¬ãµâ¦ã¢âªâºâ¤ãÿ,1949,1999,100974
# Ã‹ãœã­ã´ã³ã©ã¡ã²Ã“ã´ã¡ã½ã±ã¯ã²,Jazz,Jazz,Ã…ã°ã©ã³ã´ã±ã¯ã¶ãž,1992,1999,101021
# Ã¦?â¾ã¥â±â€¦ã¦â€¦â¶ã¥â­?,Jazz,Jazz,Ã¦å’â€¡ã§â€™â°ã£â‚¬å“yubiwaã£â‚¬å“,2071,2002,101101
# Ã¦?â¾ã¥â±â€¦ã¦â€¦â¶ã¥â­?,Jazz,Jazz,Ã£æ’â€¢ã£æ’â«ã£æ’â ã£æ’â¼ã£æ’â³ã£æ’â»ã£â€šâ¢ã£æ...,2191,2002,101222
# NaraLeã£o,Jazz,Jazz,Manhã£DeLiberdade,2211,2023,101242
# Â³âªã€â±â¼â±,Jazz,Jazz,Reflect,2357,2001,101397
# JimPepperÂ·ClaudineFrancoisTrio,Jazz,Jazz,Camargue,2367,1989,101407
# Various,Misc,Greek,Ã”ã¡Ã«ã¡ãºãªãœÃ´ã±ã¡ã£ã¯ã½ã¤ã©ã¡Ã¬ã¡ã²,2420,1997,101462
# Ãã…ããÃ‚ã…ãã…ã”ã“ãããã•,Misc,Other,Ãã…ãÃƒã‡,2438,1996,101480
# Lobã£o,Misc,Misc,Vivo,2451,2010,101494
# Ã¨ã ã¨ã¥,Misc,Rock,Ã§ãºã¥ãªÃºã¥ã«ã¯,2459,1988,101502
# Â³â¯â¼zâ¼_,Misc,Pop,Â¥ãƒâ»â·â¬oâ§aâªâºâªbâ¤ã,2462,1989,101505
# Ã©?å ã¤â½?ã¦å“âªã¦â£â®,Misc,JapanesePop,Ã§â©âºã¨â‚¬â³ã£?â®ã¤â¸ëœ,2474,1991,101517
# Ã‘ã¬ã»ã±ã«ã®ã¢ã»ã¥Ã£ã ã«ã«ã¾ã¶ã¨ã­ã ã¶ã¨ã¨,Misc,Misc,Ã‹â¸ã¤9,2480,2001,101523
# Ã£?â€¢ã£?â ã£?â¾ã£?â€¢ã£?â€”,Misc,J-pop,Ã£æ’â„¢ã£â€šâ¹ã£æ’ë†ã¯â¼â€ ã£æ’â„¢ã£â€šâ¹ã£æ’ë†,2506,2003,101549
# VariousArtists,Misc,R&b(ã¤â¸â‚¬ã¨ë†â¬),Rhythm&Babe,2510,2019,101554
# Ã¦â¸â€¦ã¨â²â´,Misc,Pop,I'llBeThere,2549,2001,101595
# Ã¤â¸â­ã¥â³â¶ã£?â¿ã£â€šâ€ ã£??,Misc,Jpop,Ã¦â­å’ã£?â§ã£?â€”ã£?â€¹ã¨â¨â‚¬ã£?ë†ã£?âªã£?â€ž,2572,1991,101618
# Â¹ãšãâ¤ã‡ã¶,Misc,Pop,Forever,2632,2001,101679
# Â©pâµã˜â°â·,Misc,Misc,Â·râªâºâ¥ãº,2688,1996,101738
# Â«â¸â¨|â«ã­,Misc,Â°ãªâ»yâ¬yâ¦ã¦,Â·râ§ãšâ§aâ©ãˆâ¤fâ¶ãœ,2697,2000,101747
# Ãƒã“âµãºã…ã¯,Misc,Â°ãªâ»yâ¬yâ¦ã¦,Â¥bâ¹ãšâ¥bâ¿ã´â¤â§â¶â¡,2712,1988,101762
# Ã¤â¸â­ã¥â³â¶ã§â¾å½ã¥ëœâ€°,Misc,Newage,True,2740,2002,101790
# Ã•ã…â¹ãºãˆã™,Misc,Pop,Leslie,2827,1984,101879
# Â±ã¨â¿âµâµâ¿,Misc,Â±â¹â¾ã‡,Â¹ã™â¶ã·ã€ã‡Â¼ã’â¸â®(windsongs),2893,1999,101947
# A-ha,Misc,Rock,MinorEarth|MajorSky,2909,2000,101964
# Various,Misc,Misc,P@jdaVol.15,2973,2014,102030
# Ã¥â·?ã¦â¾â€žã§â¶â¾ã¥â­?,Misc,Misc,Ã£?â¾ã£?â»ã£â€š?ã£?â¾ã£?â¦ã£?æ’ã£?â£ã£??ForÃ¥...,3004,2003,102062
# Ã ã©ã´ã¤Ã¤ã©ã¬ã£,Misc,Ã©ã¹ã¸ã ã¬ã©,Ã¦ã®ã¯Ã±ã¥ã«ã¸,3062,1993,102120
# Â¼ã’ã‡ã¢,Misc,ContemporaryChristian,Â¼ã’ã‡ã¢Special,3072,2001,102131
# Vintersorg,Misc,Folk/metal,Ã–demarkensSon,3084,1999,102143
# Ã¥?â¤ã¥â€ â€¦ã¦?â±ã¥â­?,Misc,Pop,Distance,3110,1993,102169
# RodrigoLeã£o,Misc,Ambient,AlmaMater,3117,2000,102177
# YoucefElOujdi,Misc,Raã¯,CaVaÃ§aVa,3123,1999,102183
# Ã£â€šâ¦ã£æ’â«ã£æ’â€¢ã£æ’â«ã£â€šâº,Misc,JapaneseRock,Stupid&Honest,3135,1999,102196
# Tiã«sto,Misc,Trance,Summerbreeze,3149,2000,102210
# Radiotrance,Misc,Trance,Ãã®ã«â¸ã²Ãã®ã°ã¬ã ã«ã¼ã­ã»ã©,3162,1996,102223
# Ãƒã¶â²qâ©ã‰,Misc,Pop,TheStoryOfShirley,3221,1993,102282
# AliceMacielEBandaPentecostal,Misc,Gospel,VocãªNã£oPodeDesistir,3255,2002,102316
# Â¡ã‘â¹âµãÂ¡ã‘ã…ã‚ã¬â¨ã’ã„â¡,Misc,Pop,Ã ãšã©â¹â¢ãâºâ¿ã©ã’,3263,2000,102325
# MartinhoDaVila,Misc,Unclassifiable,Conexãµes,3274,2003,102336
# VariousArtists,Misc,Misc,Âªfâ¤ã¨â¤â§â¯]â¢â¼,3285,1976,102349
# Ã‚ãã“ã‰ã‹ã‡ã“Ã”ã…ã‘ã‹ã…ãƒãšãã“,Misc,Misc,ÃÃšãã‹ã•ã”ã…ã‘ãã“,3288,2010,102352
# Â¤ã½â¤oâ§â»,Misc,Pop,Â°ãÿâ¤@,3319,2001,102386
# Tã¢niaMaria,Misc,Mpb,ApresentamosTã¢niaMaria,3375,1969,102442
# Ãˆã¢ã ã­Ãšã³ã·ã¨ã­,Misc,Chanson,Ã•ã°ã³ã±ã²ã ã«ã¼ã­ã ã¿Ã¢ã ã§ã,3408,1995,102477
# Rionegro&Solimãµes,Misc,Sertanejo,NaSolaDaBota,3422,2003,102495
# Â·â¨â¨â¼â©g,Misc,Misc,Ã‚ã·â§oâ¤â§â«e,3426,2000,102499
# Ã©â«ëœã¦â©â€¹ã¥â¹â¸ã¥â®?,Misc,Pop,TheBestWay,3436,1993,102510
# Ã¦?â€°ã¥â±â±ã¦â¸â€¦ã¨â²â´,Misc,Misc,Ã¥â½â¼ã¦â€“â¹ã£?â€¹ã£â€šâ€°ã£?â®ã©â¢â¨,3449,2020,102523
# Â±ã¨ã€â±â¾ã†,Misc,Vocal,Â¼â¨âµâµâ¿ã¬Â¿ã€âºãªÃ€â¯â¾ã®Â½âºâ¸â¶ã€ã,3461,2001,102534
# Ã§å“å¸ã¥â³â¶ã¦ëœå’ã¥ë†â©,Misc,JapaneseRock,Ã¥â¤?ã£?â®ã£?â¬ã£?â€˜ã£?å’ã£â€šâ€°,3464,1989,102537
# Ã£æ’?ã£â€šâ«ã£æ’â»ã£æ’â€“ã£æ’â¼ã£æ’â³,Misc,J-pop,Ã¦ëœâ¥ã¥â¤?ã§â§â€¹ã¥â€ â¬,3466,1994,102539
# Ã§â€¢â ã¥â±â±ã£â‚¬â‚¬ã§â¾å½ã§â€â±ã§â´â‚¬,Misc,Pop,WildAndGentle,3481,2003,102556
# Â±iâ¾ã‡â¤ã,Misc,Pop,Â§ã‘â°oâ§aâ§ãšâ°âµâ¤â£â¨ã¬,3601,1996,102682
# VariousArtists,Misc,Anime,21ã¤â¸â€“ã§â´â‚¬ã£?â«ã©?âºã£?â€”ã£?å¸ã£?â€žã£â€...,3606,2000,102687
# Ã‡ã‘â±â¹â¿â¹â¹ã¨ã€ãžâµâµã€ãšâ¸ã°ã€ã“,Misc,Ccm,Ãã–Ã€ã“ã€ã§Â¾ãˆâ¿â¡â¼â­-WorshipCampLive...,3657,2004,102741
# MohammedKhaznadji,Misc,Other,NoubaHoussineOuaHawzi,3667,\nclassicalAlgerianAndalusianMusic",102751
# Ã¦â€“â°ã¤â¸â€“ã§â€¢å’ã¦â¥â½ã¦â€ºâ²ã©â€ºâ€˜ã¤â¼å...,Misc,Game,Ã©â¢â¨ã©â€ºâ²ã£â€šâ¹ã£æ’â¼ã£æ’â€˜ã£æ’â¼ã£â€šâ¿ã...,3739,1996,102828
# Ã£â€šâ¹ã£æ’?ã£æ’â£ã£æ’â‚¬ã£æ’â©ã£æ’â€˜ã£æ’â¼,Misc,Ã£æ’â€™ã£æ’æ’ã£æ’â€”Ã£æ’â€ºã£æ’æ’ã£æ’â€”(ã¤â¸...,Ã¥?â¶ã§â€žâ¶ã£?â®ã£â€šâ¢ã£æ’â«ã£æ’?ã£æ’â,3788,1996,102879
# Ã¦â¸â¡ã¨â¾âºã£â‚¬â‚¬ã§â¾å½ã©â€¡å’,Misc,Rock,TheLegendMisatoWatanabe,3850,2002,102945
# Ãˆã¢ã ã­Ãšã³ã¯ã ã«ã,Misc,Folk,Ãšã®ã±ã²ã°ã®ã¬ã,3891,1999,102987
# Â¢ã«ãªã§ã³ã´ã©ã²Ãã±ã¹ã´ã¯ã¸ãœã«ã´ã§,Misc,Ã…ã­ã´ã¥ã·ã­ã¯,Ãšãµãªã«ã¯ã¶ã¯ã±ã¾Ãªã©Ã¯ã°ã«ã¯ã¶ã¯ã±ã¾,3906,1989,103002
# [â¹ã©â´ãœã‡ã¢]Ã€ãœâ±ã¢ã‚ã¹5ãã½,Misc,Ballad,NewStory,3936,2001,103032
# Ãšã˜â¹ã”âµã’Ã…ã•âµã”â¡ã˜ã…,Misc,Acoustic,Beau-NonElectricProject,3944,2001,103040
# Ã¥â°â¾ã¥â´å½ã¤âºå“ã§â¾å½,Misc,Pop,AmiiCmNetwork,3957,1987,103055
# Ãƒã‰ãããã‡ã“Ããã‘ã‰ãã“,Misc,Ã…ã‹ã‹ã‡ãã‰ãšã,Ã”ã•ã˜ã…ã‰ã“,3958,1997,103056
# Ã€ã­ã­ã Ãƒã¥ã°ã¬ã ã­,Misc,Vocal,Ã‘ã¯ã ã±ã¨ã¡ã®Ã²ã¥ã¡ã¥,Ã¬ã®â¸Ã±ã¥ã°ã¤ã¶ã¥,3971,2003,103069
# Ã©?å ã¤â½?ã£â‚¬â‚¬ã¦å“âªã¦â£â®,Misc,Pop,StillLife-ã©?â„¢ã£?â€¹ã£?âªã§â€å¸ã¦â´â»-,3985,2001,103084
# Ãâ¶â±ã”ã‚ã¹,Misc,Misc,The3rdSeason,4129,1996,103234
# Â¼ã•â¿âµãã¸,Misc,Gospel,Collection1983-2000,4132,2000,103237
# Â¸sâ¬p,Misc,Misc,Âµã˜â¯ã‡â®ã¶âºâ©â¤ãÿâ¦â±âºã«â¿ã¯,4173,1991,103279
# Â¶ã€âµãžã‚@,Misc,Male,Â°â¨â¤â£â°â±â¿ã¡âªâºâ¼~â¶ã‹,4188,1988,103294
# Ãã³ã²ã»ã°ãªã,Misc,Chanson,Ãã¥ã°ã¢ã»ã©Ã ã«ã¼ã¡ã®ã¬,4289,2003,103398
# Ã‘ã¥ã²ã¨,Misc,Pop,Ãã¥ã¡ã®Ã­ã Ã§ã¥ã¬ã«ã¥,4295,2002,103406
# Ã¦â€“â€°ã¨â€”â¤ã¥â€™å’ã§â¾â©,Misc,Pop,WonderfulFish,4328,1997,103440
# Sana,Misc,Vocal,Sana-modeIiÃ£â‚¬å“pop'nMusic&BeatmaniaMom...,4332,2003,103444
# Ã’ã®ã­ã¨ãªã,Misc,Pop,Ãšã®ã­ã¶ã¥ã°ã²-Ã¡ã¥ã­ã¥ã´ã¨ã±'1994Ã’ã®ã­ã¨ã...,4336,1994,103448
# TheStalin,Misc,PunkRock,Ã¨â„¢â«,4401,1989,103514
# Â°ã¦â¹ã¨â¿ãã‚ã¹â¾ã§,Misc,ChristianGangsta,Ã€ã¼ã‡ãâ¼â¼â¿â¹â¼ã¶1,4450,1972,103565
# Ã©âºâ€”ã§â¾å½,Misc,J-pop,ReimyDisc1,4501,1990,103619
# VariousArtists,Misc,Meditative,NossasCanã§ãµes2,4517,2000,103636
# PeterRauhofer,Misc,House,Live@roxyCd1,4581,2002,103702
# Ã¦â²â¢ã§â€â°ã§â â€ã¤âºå’,Misc,Pop,Ã¦â²â¢ã§â€â°ã§â â€ã¤âºå’SuperBestDisc1,4639,1989,103762
# AnjosDeResgate,Misc,Catã³lico,LuzDasNaã§ãµes,4677,2002,103802
# Â¾hâ°â·â©ãº,Misc,Pop,JoeyMusicFactory,4693,2002,103818
# Ã„ã¥ã¬ã®,Misc,Misc,Ã‘ã®ã«ã­ã»ã¸ãªã®,4706,2019,103830
# VariousArtists,Misc,Pop,Â¶â«â·â½ã–â®ã–ã©iii,4708,1976,103832
# YoLaTengo,Misc,Misc,Genius+Love=YoLaTengo,4712,1996,103836
# Ã£â€šâªã£æ’âªã£â€šâ¸ã£æ’å ã£æ’â«ã£æ’â©ã£æ’â€“,Misc,Pop,SunnySideOfOrignalLove,4756,1995,103882
# Various,Misc,Alternative,Â¤@â®aâ¤h,4793,2002,103920
# Ã¥â·?ã¤âºâ€¢ã¦â€ â²ã¦â¬â¡,Misc,Anime,Patlabor2TheMovie,4827,1993,103957
# Â³ã‚â¹ãºã†â½,Misc,Instrumental,Ã£â«ã’ã¢,4851,1999,103983
# Ã€â¯â½ã‚ãã˜,Misc,Misc,ForSale,4854,2017,103987
# Various,Misc,Misc,Â¥xã†wâ²ã„â¤qâ¤gâ©â¡â­âµã…tâ®i,4876,2002,104009
# EnkhJargal,Misc,NationalFolk,HoirrÃ–ngã¶,4877,2002,104010
# Ã£?â€¹ã£?â¾ã£?â€žã£?å¸ã£?â¡,Misc,JapaneseRock,Ã£?â¯ã£?â¡ã£â€šæ’ã£â€š?ã£?â¡ã£â€šæ’ã§â€¹â€š,4943,2012,104079
# Ãƒã‰ãããã‡ã“Ããã•ã‹ãããã•ã‹ãã“,Misc,Â¸ã­ã´ã¥ã·ã­ã¯,Ã…ã°ã©ã´ãµã·ãÿã¥ã²,4979,1997,104117
# ÃsmaelLedesma,Misc,Ethnic,TierraParaguay,4993,1999,104132
# Various,Misc,Pop,Â½â£ãã€ã‡ã©ã”âµ,5007,2003,104145
# Â³\â¼ã–-â³â¯â¼ã¤ã„r,Misc,Pop,Â¶â¢â±â¡â¶â®â¼ã–,5028,2023,104167
# LuisMiguelCaldas,Misc,Mpb,Sertã£oUrbano,5091,2003,104231
# VariousArtists,Misc,Ethnic,<<CompilationDisc>>WhenIrishEyesAreSmiling,5142,1998,104282
# Ãã¯ãµã«ã¼ã°ã¯ãµã«ã¯ã²Ãƒã©ãœã­ã­ã§ã²,Misc,Other,Ãƒã‰ãããã‡ã“Ããã•ã‹ãããã•ã‹ãã“1,5149,1997,104289
# Ãžã•ã„ã‰ãã“Ãˆãã„ã™ã‘ã‡ã“,Misc,Other,Ã—ã™ã‘ã‰ã“Ããã‘ã…ã,5169,2003,104310
# Ã£â€šâ·ã£æ’â¢ã£æ’â³ã£â€šâº,Misc,J-pop,Ã©â¢â¨ã£?â®ã£?â€œã£?â¨ã£?â¥ã£?â¦,5171,1990,104312
# Ãƒã‰ããƒãšãã•ã“ã‡Ã‹ã‰ã”ã“ã,Misc,Ã‹ãã‰ãšã,2000-ãšãã‰Ã“ã”ãÃ…ãžã‡ã“,5201,2000,104343
# Â¤kâ¤lâ¤qâ¤gâ¼ã–â§{,Misc,Musical,Â¤kâ¤lâ¤qâ¤gâ¼ã–â§{-â¼bâ¤tâ©j-cd1,5230,2003,104373
# Ã—ã ã©ã´,Misc,Rock,Ã˜ã¥ãªã®ã£ã ã«ã¨,5252,1999,104396
# Âºã‚â©g,Misc,Misc,Âºã‚â©g'88Âºtâ°ã›â·|,5258,1988,104402
# Hifana,Misc,Ã¤â¸?ã¦ëœå½,FreshPushBreakin',5264,2003,104408
# Ãšã ã©Ãœã¥ã²ã®ã¢,Misc,Pop,Ã‚ã±ã¯ã®ã¬ã­ã¨Ã¬ã¥ã­ã¿,5266,1995,104410
# Â¶ã€â°â¶â©ãº,Misc,InstrumentalPop,Â´â£âµ^â±â¡â¸ã–,5273,1997,104418
# Ãã½ã°ã°ã¨ã¬ã®ã°,Rock,Punk,Ã‚ã±â¸Ã½ã²ã®Ã¤ã«ã¿Ã²ã¥ã¡ã¿,5354,2002,104500
# MiriamYeung,Rock,Pop,Â¥vâ¤ã‘âªâºâ¬gâ¨ã†,5360,1999,104506
# Ã‰ã¹ã¡ã­ã­ãÿã¤ã§ã²Ãã«ãªãÿã­ã¯ã¯ã²,Rock,EasyListening,Ãã©Ã°ã¥ã±ã©ã°ãã´ã¥ã©ã¥ã²Ã¥ã­ã¼ã²Ã°ã±ã¯ã³ãª...,5385,2003,104533
# Ã¶'ã¸ã¶'ã©ã¬ã©ã­,Rock,ProgressiveRock,Ã¶'ã¸ã¶'ã©ã¬ã©ã­,5399,1968,104548
# Â¤ã¨ã€aã€s,Rock,Instrumental,Âµ\âµ]â¦ã¦,5476,2000,104633
# Estopa,Rock,Pop,Â¿laCalleEsTuya?,5542,2004,104699
# Ã‹ã¥ã®ã­ã¨ã¤Ã‘ã¥ã°ã£ã¥ã¥ã¢,Rock,Ballad,Ã”ã ã°ã´ã®ã°ã®ã¢ã ã¿Ã‘ã¢ã ã¤ã¼ã¡ã,5547,2000,104704
# Â¾gâ¶iâ¤@,Rock,Pop,Ã‚â²ã‚â²â³ã¦â³ã¦,5551,2000,104709
# Ã¥â®â€°ã¨â¥â¿ã£?â²ã£â€š?ã£?â€œ,Rock,Jpop,TrueLove,5592,2000,104751
# Rikki,Rock,Pop,Ã¨å“å“,5594,2002,104753
# Ã€â±âµâµã‡ã¶â¹ãªâµã¥,Rock,Rock,AnUrbanite,5625,2001,104786
# Ãã ã§ã­ã»ã¥Ã¨ã±ã¯ã®ã«ã­ã¨ã²ã¥ã«ã¨,Rock,Retro,Ãã…ã‘ããˆÃžÃ‘ã’ã€ã‹ãˆãã…,5680,2003,104842
# Ã¤â¸â€°ã©â€¡?ã©â€¡å½ã§å¾â³,Rock,Jpop,BabyLeaf,5775,2020,104947
# Ã€ã«ã¥ãªã±ã ã­ã¤ã°Ã‹ã ã½ã°ã²ã±ãªã¨ã©,Rock,Rock,Ã†ã¥ã­ã¹ã¨ã­ã Ã±\ã²ã°ã³ã¡ã®ã©\,5883,1993,105066
# Ã‘ã¥ãªã²ã®ã°Ãƒã ã§ã,Rock,PunkRock,Ãƒã³ã«ã¿ã©Ã¬ã³ã¦ã¨ãª!,5893,1992,105076
# Ãã¯ã¨ã²ã ã´ã¨ã¿,Rock,HardRock,Ãã®ã·ã¥ã¬ã³Ã«ã¾ã¡ã®ã¢ã¼...,5915,2004,105098
# Ã‡ã¨ã­ã·ã³ãª,Rock,InstrumentalRock,Ãžã¤ã¨ã­ã®ãªã¨ã©Ã‚Ãã®ã·ã¨,5944,2002,105131
# Ãšã®ã«ã¨ã¡ã°ã¨,Rock,Electronic,Ãã¥ã¬ã¨ãªã±ã»,5965,1998,105156
# DjSatori,Rock,Techno,TribalMixSessionsVoã¬.1,6038,2002,105233
# Â³â¯â¦ãšâ±j,Rock,Pop,Â´xâ¤ã€ã„ãâªâºâ¬ã¹â·|,6077,1980,105276
# Ãœâ·ã“â½ã·ã«,Rock,Pop,Â±â©â·ã§ã…â®ã‰ã±lorelei,6091,1985,105292
# Ãã­ãžâº,Rock,Rock,Ã„ã‡ã’â»ã„ãª(cd2),6130,2002,105334
# Ã†ã ã±ã¬ã¨ã­,Rock,Pop,Ã„ã®ã«ã£ã¨ã¥Ã„ã­ã¨,6144,2000,105349
# VariousArtists,Rock,Anime,Ã£â‚¬å’ã¦â©å¸ã¥â€¹â€¢ã¦ë†â¦ã¥â£â«ã£â€šâ¬ã£æ’â³ã...,6188,2003,105396
# Gulff,Rock,Rock,Ã¥?â€ã¥â¥?ã¦â€ºâ²ã£â‚¬å“the2ndLpã£â‚¬å“,6281,2002,105496
# Ã€ã­â³Ã‹ã®ã°ã ãª,Rock,Pop,Ã’ã ã¬Ã¤ã¥Ã²ã¨Âº,6360,2002,105585
# Genesis,Rock,ProgressiveRock,AndThenThereWereB-sides{discOne},6402,2003,105629
# Carol,Rock,Rock,Ã£æ’â€¢ã£â€šâ¡ã£æ’â³ã£â€šâ­ã£æ’â¼ã£æ’â»ã£æ’â¢ã£...,6429,2023,105658
# Catapulta,Rock,Hardcore,2âºVersã£o,6480,2022,105712
# Ã¥â¼âµã¥â­â¸ã¥?â€¹,Rock,Soundtrack,1999ã¥?â€¹ã¥â‚¬â€¹ã¤âºâºã¦â¼â€ã¥â€â±ã¦å“æ’[d...,6512,1999,105750
# Ã§â±â³ã§â±â³ã¯â¼â£ã¯â¼â¬ã¯â¼âµã¯â¼â¢,Rock,Jpop,PhiIi,6514,1994,105753
# Ã¸ã©ã·ã©Ã¢ã¬,Rock,Pop,Ã§ã´ã¹Ã¡ã©,6521,1993,105760
# Various,Rock,Electronic,GalacticSoundLab>>>One,6562,1998,105804
# Reincidentes,Rock,PunkRock,Â¿dondeEstaJudas?,6598,1992,105847
# Â¦hâ¦ã¬âºtâ¥xâªãœ,Rock,Electronic,Â¹qâ­âµâ»râ§a4Disc1,6652,2003,105904
# Ã¦â²â³ã§â€â°ã§â´â€ã¥â­?,Rock,Jpop,Prologue,6656,1991,105908
# Legiã£oUrbanaecords,Rock,Rock,Metropolitan-RioDeJaneiro-1994-AnimalR...,6677,1998,105934
# Ã¦â¸â¡ã¨â¾âºã£â‚¬â‚¬ã§â¾å½ã©â€¡å’,Rock,Pop,Spirits,6689,1996,105946
# Ãã³ã«ã ã­ã®ã¢ã Ã’.,Rock,Pop,Ãã²ã®Ã¨ã£ã°ã,6698,2002,105956
# AliceCooperaboCantinaInCaboSanLucas,Mexi...,Rock,HardRock,AFistfulOfAlice-Live@SammyHagar'sCabo...,6717,1997,105976
# Dystopia,Rock,Rock,Human=Garbage,6753,2014,106015
# Â½ã…ãˆâ­[shinhwa],Rock,Rock,6-Â³ãšã€ã‡Â°ã¡ãˆâ¥â½ã„(wedding),6857,2002,106127
# Â§ã…â±ã’â½ã¥,Rock,Other,Â´mâ½ã¥â±ã’â¨ã†Disc1,6875,1999,106146
# Ã£æ’â€”ã£æ’â¬ã£â€šâ¤ã£â€šâ°ã£â€šâ¹,Rock,Rock,Ã©â®â«ã£?â¨ã£æ’?ã£â€šâ¤ã£æ’â€œã£â€šâ¹ã£â€šâ«ã£â...,7000,2000,106278
# SoundSchedule,Rock,Rock,Ã£â€šâ¤ã£æ’å¾ã£â€šâ³ã£â€šâ³ã£æ’â€¹ã£â€šâ¢ã£æ’â«...,7018,2002,106295
# Â¾â¤â©ãº,Rock,Pop,4in1â¬ãƒã‚ãƒâ¶â°,7038,2003,106316
# Grapevine,Rock,Rock,Ã£â€šâ¤ã£æ’â€¡ã£â€šâ¢ã£?â®ã¦â°â´ã¦â§â½,7051,2003,106332
# Ã¦âµå“ã¥â´å½ã£?â€šã£â€šâ€ ã£?â¿,Rock,Jpop,Ayu-mi-xIiVersionAcousticOrchestra,7059,2000,106342
# Ã¥â¤â§ã§â‚¬â§ã¨â©â ã¤â¸â‚¬,Rock,Jpop,B-eachTimeL-ong,7085,1985,106370
# Ã€ãã†ã…ã‹ãˆãšã€Ã‚ã€ãã“ãœ,Rock,Pop,Ã‘ã’ãžã,Ã‹ãžããžãã›ã’ã‘ã’ã‚ãž,7156,2002,106443
# Ã€ã«ã¥ãªã±ã ã­ã¤ã°Ãœã ã«ã¨ã­ã¨ã­,Rock,Retro,Ã‹ã¾ã¡ã¢ã¨Ã¦ã¥ã«ã ã­ã­ã ã¿Ã¯ã®ã°ã,7217,1994,106511
# TheTimers,Rock,Rock,Ã¥â¾â©ã¦â´â»!!TheTimers,7236,1995,106531
# Sheena&TheRokkets,Rock,Rock,Ã§å“å¸ã§â©âºã£æ’â€˜ã£æ’æ’ã£â€šâ¯,7300,2006,106600
# Â³â¯â¬ã•â¼ã¤,Rock,Techno,Â¥xâ»yâªã·â¦â±2,7308,2023,106608
# Ãã®ãªÃžã±ã²ã°ã®ã¢ã,Rock,Rock,Ãã ã¸ã¨,7375,1995,106684
# Molodoã¯,Rock,PunkRock,OnEstLã,7376,1993,106685
# EdMotta,Rock,Pop,Geraã§ã£oPop,7381,1995,106690
# AlienSexFiend,Rock,AlternativeRock,NocturnalEmis$ions:specialEdition,7437,2000,106752
# Ã¤â¸â­ã¦?â€˜ã£?â€šã£â€šâ€ ã£?â¿,Rock,Jpop,HeartOfDiamondsIi-bestAlubum-,7533,1992,106855
# Nofx,Rock,Punk,WhiteTrash,TwoHeebsAndÃ¯â¼â¡Bean,7613,1992,106943
# Anarchy,Rock,Rock,Ã£æ’â€¡ã£â€šâ£ã£æ’â³ã£â€šâ´,7633,2005,106965
# Â³â¯â¼zâµy,Rock,Rock,Â­â¸â¤ã‘â»râ·|,7634,2002,106966
# Ã€ãªã¢ã ã°ã¨ã³ã¬,Rock,Folk/rock,Ã‚ã¨ã§ã¨ã²Ã¢Ãœã®ã±ãªã¢ã³,7716,1993,107056
# Ã‚ã«ã ã¤ã¨ã¬ã¨ã°Ãšã³ã§ã¼ã¬ã¨ã­,Rock,Pop,TheGreatestHitsIv,7745,1997,107087
# Ã¥â°?ã¦â¯â€ã©â¡å¾ã¥â·â»ã£?â€¹ã£?â»ã£â€šâ€¹,Rock,Rock,SilentFictionTour1991,7747,1992,107089
# Ã£â€šâ·ã£æ’â§ã£æ’æ’ã£â€šâ¯ã£â€šâ·ã£æ’â€ ã£â€šâ£...,Rock,Punk,Ã£â€šâªã£æ’â¼ã£â€šâªã£â€šâ¦ã£æ’â»ã£â€šâ¢ã£â€šâ¤...,7772,2001,107119
# DieÃ„rzte,Rock,Rock,Ab80-AllesÃ¼berSex,7774,1999,107123
# Pa-dã¶-dãµ,Rock,Pop,EgyKicsitBulizgatunk,7799,2001,107147
# Soundtrack,Rock,Soundtrack,Ã¥â¥â³ã§â¥å¾ã¨â»â¢ã§â€å¸1&2Ã¥?â¬ã¥â€“å¡ã§â€º...,7827,1991,107175
# Ã¥â°?ã¦å¾â€”ã¦â€”â­,Rock,Pop,Ã£â€šâ¢ã£â€šâ­ã£æ’â©4ã£â‚¬å“ã£æ’â¦ã£æ’â¼ã£æ’â¢ã...,7829,2002,107177
# Papermoon,Rock,Pop,DieGrã¶ãÿtenHitsDer80erUnd90erAusÃ–ster...,7830,1997,107178
# Ã¤â¸å ã¥å½å¸ã£?â€šã£?å¡ã£?â¿,Rock,Jpop,Ã§â€žâ¡ã¨â€°â²,7842,2002,107190
# Various,Rock,Christmas,JustSayNoã«l,7847,1996,107196
# LocalBus,Rock,Pop,Ã¦â¤â€¹ã©â³â¥ã£æ’â­ã£æ’â€œã£æ’â³,7962,2002,107322
# Ãâ¤ã€ã§ã€ã,Rock,Ballad,Â´â«â¹â°â²ã‰,7986,2022,107347
# Ã§â€°â¹ã¦â€™â®,Rock,Rock,Agitator,7990,2001,107351
# RioNegro&Solimãµes,Rock,Country,Sã³Alegria,8005,2001,107368
# Ã¦?â¾ã§â€â°ã¨?â€“ã¥â­?,Rock,Jpop,SeikoAvenue,8015,1984,107379
# Ãrafã¡r,Rock,Rock,AlltSemÃ©gSã©,8042,2002,107408
# Ã¨â¦â³ã¦å“ë†ã£?â€šã£â€šå ã£?â€¢,Rock,Jpop,History-singleCollection-,8070,2004,107438
# Ãã®ã£ã³Ã‘ã¢ã¥ã«ã®,Rock,Rock,Ãšã ã«ã«ã»,8077,2019,107445
# TonicoETinoco,Country,Country,Sertã£oSemPoluiã§ã£o,8114,2000,107484
# Â²ãœã“ã±ãˆã™,Country,Country,Âºãºãã’ã‚ã›ã“ãª,8151,2002,107521
# ChrisCagle,Country,Country,PlayItLoud-{secondRelease},8158,2001,107528
# Joã£oVictor&Vinã­cius,Country,Sertanejo,EuPrecisoDesseAmor,8193,2002,107566
# MercedesBenz,Country,Country,VirgisStakã«nas,8214,2003,107587
# Ã‚ã«ã ã¤ã¨ã¬ã¨ã°Ã€ã±ã¬ã®ã«ã®ã¢,Country,Chanson,Ã’ã ãªã®ã¢ã Ã±ã¥ã«ã¿ã¢ã¨Ã¨ã«ã¨SexÃ¯ã®Ã°ã³ã...,8246,2000,107620
# Â±iâ¬fâªã›,Country,Pop,Â¤â£â¤@â¼ã‹âªâºâ§ãš,8258,2000,107633
# Tiã£oCarreiro&Partinho,Country,Country,ModasDeViolaClasseA-Vol.2,8265,1975,107640
# OsFarraposEIedoSilva,Country,Country,Garrã£oDoPampa,8272,2018,107647
# RicardoHenrique,Country,Country,Violã£oApaixonado,8313,2014,107691
# Ã—ã¥Ã²ã¥Ã­ã ã¤ã®,Country,Country,Ã—ã¥Ã²ã¥Ã­ã ã¤ã®,8351,2016,107730
# Ã‘ã¥ãªã²ã®ã°Ãƒã ã§ã,Country,PunkRock,Ã‘ã¥ãªã²ã®ã°Ãƒã ã§ã,8355,1987,107734
# Ã—ã¨ã¦&Co,Blues,Rock,Ãã¥ã°ã¥ãªã°ã¥ã±ã²ã®ãª,8370,1994,107750
# Ã¤â½?ã©â€¡å½ã¥â€¦æ’ã¦ëœâ¥,Blues,Jpop,Someday,8373,2002,107753
# Ãƒã“âµãºã…ã¯,Blues,Pop,Â·râ±â¡â³â´â¨ã€,8398,1985,107779
# Â¾hâ§ã“â¯e,Blues,EasyListening,Â©pâ¬oâ§ãšâ¥ãƒâ»â·âªâºâ¬kâ¤ã‘,8403,2003,107784
# Ã¦â°â´ã¦â¨â¹ã¥â¥ë†ã£â‚¬â€¦,Blues,Jpop,SupersonicGirl,8412,2001,107794
# NaraLeã£o,Blues,Jazz,ComAã§ucarComAfeto,8455,1980,107839
# Ã§å¸â³ã¥å½å¸ã¦â€¦å½ã¤â¸â‚¬,Blues,Blues,I-sing,8467,2018,107852
# Â©pâ¿â·,Blues,Blues,Â¦nâ·qâ¦nâ¦nâ·râ§a,8480,2000,107866
# W-inds.,Blues,Pop,W-inds.Ã£â‚¬å“theSystemOfAlive,8481,2002,107867
# Ã§å¡â€ ã¥â·?ã§â´â€ã¥â­?,Blues,Jpop,FutureOfBlue,8498,2003,107886
# SamanthaFox,Blues,Pop,IWannaHaveMoreFun-12ã£â€šâ€ºVersionColle...,8518,1988,107908
# ????,Blues,Blues,Hope,8543,1990,107934
# -,Blues,Blues,Â³ãœâ¨ãžâ¤ãâ±â¡â¤h,8581,1999,107974
# Ã§å¸â³ã¥â·?ã£â€šâ»ã£æ’âª,Blues,Pop,Ã§â¿â¼Ã£â‚¬å“Ã¦â­â¦ã¦âºâ‚¬ã¥â¾â¹ã£æ’?ã£æ’æ’ã£...,8588,1995,107982
# Ã£?â¤ã£â€šâ€œã£??,Blues,Jpop,Take1,8590,2004,107984
# Ã¤â¸â­ã¥â³â¶ã£?â¿ã£â€šâ€ ã£??,Blues,Oldies,Ã¥â¤â§ã©å â‚¬ã¥â¹â€¢,8624,1999,108023
# NoirDãƒâ©sir,Blues,Rock,DesVisagesDesFigures,8679,2001,108082
# Âµâ´â§â®âºqâ¤ã¢,Blues,ACappella,Â°ãªâ»yâ±ã†â¦ã¦âº]â¤t,8772,1999,108176
# Â³â³ã»f,Blues,Pop,Â³â³ã»f,8798,1997,108202
# Â¾ã°â´ãâ³ã—Ã€ãœâ¹ãÿâ°ã¼,Newage,Rock,Âºã±âµã‘â±ã¢â´ã‚Ã‡ãâ´ãƒã€ã‡Ãã£,8844,2000,108249
# Ã¦??ã©â€¡å’,Newage,Pop,MoonlitSummerTales,8848,1998,108253
# Ã§å¸â³ã¤âºâ€¢ã§â«å“ã¤â¹å¸,Newage,NewAge,Ã¦âµâªã¦â¼â«,8850,2002,108255
# Ã¥?â€šã¦å“â¬ã£â€šâµã£æ’ë†ã£æ’â«,Newage,Jpop,Ã§âµâ€šã£â€š?ã£â€šâ€°ã£?âªã£?â€žã¦â­å’,8864,2000,108271
# Ã¤â¸â­ã¨â¥â¿ã¥å“â­ã¤â¸â€°,Newage,NewAge,Songs,8866,1998,108273
# DjCulture,Newage,NewAge,EnigmaClub-Ãã®ã·ã¼Ã‚ã ã²ã¨ãªã ã­ã,8874,2002,108281
# Ã£â€šâ¢ã£æ’â«ã£æ’â€¢ã£â€šâ£ã£æ’â¼,Newage,NewAge,LiveInProgressDisc1,8897,1995,108306
# Menã¢â‚¬â„¢s5,Newage,NewAge,Ã©å¸â³ã¦â¥â½ã©å â‚¬ã¥âºâ§,8899,1996,108308
# SusanaZabaleta,Newage,Alternative,Â¿...OFueUnSueã±o?(versiã³nRemasterizada),8932,2003,108343
# 1.5Ãªã£Ã®ã²ã«ã¨ã·ã­ã®ã£ã®Ã¯ã¾ã°ã¥,Newage,Punk,Superpunk(+3BonusTracks),8945,2002,108356
# Ã£æ’?ã£æ’â¥ã£æ’â¼ã£æ’âªã£æ’æ’ã£æ’â€”,Newage,NewAge,Ã£æ’?ã£æ’â¥ã£æ’â¼ã£æ’âªã£æ’æ’ã£æ’â€”ã£æ’â»ã£â€š...,9022,2000,108435
# Ã¦âµâ·ã¦?â´ã©å¡å,Newage,NewAge,Ã¦å“â±ã¥â¤?ã£â€šâ€™ã©?å½ã£?å½ã£?â¦ã§â„¢â½ã§â§â€...,9031,2001,108445
# Ã§â«â¹ã¥â€ â€¦ã£?â¾ã£â€šå ã£â€šâ€ž,Newage,NewAge,Beginning,9093,1997,108510
# Ã¨?â€™ã¤âºâ€¢ã§â€â±ã¥â®å¸,Newage,NewAge,Ã£æ’â¦ã£æ’â¼ã£æ’å¸ã£æ’â³ã£æ’â»ã£â€šâ³ã£æ’â¬ã£â€...,9099,1992,108518
# Ã¦??ã©â€¡å’,Newage,Pop,MindCruisin',9100,1990,108519
# ????,Newage,Polka,A.I.R,9105,2003,108525
# Ã¦?â¾ã¦âµâ¦ã¦å“â€°ã¥â¸å’,Newage,Jpop,InvisibleCircle,9119,1999,108539
# Rastaclone,Reggae,Reggae,Essiã©dubã£o,9223,2002,108647
# BestOfWorldMusic(Mcm)SammyAsuncion&J....,Reggae,Reggae,Jamaã¯que,9239,1994,108664
# Bach,Classical,Classical,EnglishSuiteNo.1Â·Tocattas,9370,1996,108796
# Ã„ã ã°ã¨ã£ã Ãã ã§ã ã°ã¡ã ã¥ã¢ã,Classical,Vocal,Ãã®Ã¿Ã‚ã ã±Ã¢ã±â¸-ã²ã ãªã¨Ã«ã¾ã¡ã«ã¾...,9424,2001,108851
# Â¶ã€ãƒã½â¬ã‚+â¶ã€â¹ã…â¤d,Classical,ClassicRock,Â¥|â¤ã¢ãpâ¼uâ¤â§â¥â´ã‚â½â­âµâ¼ã–â²â°,9432,2002,108860
# V.A,Classical,Classical,Â¹ãœâ¼ã’(cd09-â¿â¹â¼ãºâ°â¡ã€ã‡Ãƒãšâ»ã³),9452,2001,108880
# VariousArtists,Classical,Opera,DeBesteOperettemelodieã«nCd1,9520,1999,108950
# Â¾hã„râ§g,Classical,Oldies,GreatestHitsVol.2,9560,1989,108991
# Joã£oCarlosMartins,Classical,Classical,J.S.Bach-theWellTemperedClavier,BookI,9580,1964,109011
# Â»ã§â¶ã»ã€ã‡Â³â¯â°â³,Classical,Ccm,FlyToTheDream,9581,2002,109012
# Ã“ã¡â²â®ãâ¥,Classical,Classical,Ãšã±ã–ãã‡ã™ã”ãCd2-1,9586,2000,109017
# VariousArtists,Classical,Classical,Â³ã«â·â¡ã€ã‡Â³â¯â°â³Ã€â§â¿â¡Â¶ãÿâ´ã‚Âºâ°,9608,2003,109040
# Â³\\â´âºâ²e,Classical,AcidPunk,Â¤ã‘â³â»âªâºâ¤ã«â®qâ°ãš,9612,1996,109044
# Various,Classical,Classical,1000JahreÃ–sterreich,9646,1996,109078
# Bach,JohannSebastian,Classical,Classical,L'intã©graleDesSonatesPourFlã»te(cd2-2),9657,1967,109089
# Qqq,Classical,Classical,Â¥ã¬â«â½â¡eâºâ¿â¾â·EvaMartonÂ¤kâ°âªâ­âµâ¡eâ½...,9751,1995,109184
# Ã£â€šâ¢ã£æ’â³ã£æ’â€°ã£æ’â¬ã£æ’â»ã£â€šâ®ã£æ’â£ã£...,Classical,Classical,Ã£æ’â€ã£â€šâ¢ã£æ’å½ã£æ’â»ã£æ’â¡ã£æ’æ’ã£â€šâ»ã£...,9791,1997,109228
# GeorgesBizet,Classical,Classical,Carmen{highlights),9821,1995,109258
# Â®]â«ã˜â¥â­&sweetStyle,Classical,Pop,Â­âµâ¼ã–âºãâ³ãµâ¬yâ¦ã¦âªã·â¦â±(â¥|),9889,1992,109327
# Ã‚ã¥ã°ãªã Ã‘ã¥ã°ã¤ã¾ã·ãªã,Classical,Pop,Ã•ã -ãã -ã˜ã®!,9984,2003,109426
# N/a,Soundtrack,NurseryRhyme,Ãˆâ¥ã€ãšâµã»â¶ã³ã‡ãâ´ã‚Â¾ã®â¸â°ã€ãœâµâ¿â¿ã¤02,10030,2000,109472
# VariousArtists,Soundtrack,Soundtrack,OMelhorDoBangBangÃ€Italiana,10057,1991,109499
# Ivory,Soundtrack,Soundtrack,Ã£?â¨ã£â€šâ€°ã£?â€žã£?â€šã£â€šâ€œã£??ã£â€šâ€¹ã£...,10065,2000,109507
# FalcomSoundTeamJ.D.K.,Soundtrack,Game,Per-colleÃ£æ’â€°ã£æ’â©ã£â€šâ´ã£æ’â³ã£â€šâ¹ã£æ’...,10070,1993,109512
# Ã£æ’â€°ã£æ’â©ã£æ’å¾cd,Soundtrack,Soundtrack,Cdã£æ’â€°ã£æ’â©ã£æ’å¾Ã£?â¨ã£??ã£â€š?ã£??ã£æ’â¡...,10091,1995,109533
# Ã£æ’â¦ã£æ’â€¹ã£â€šâ¾ã£æ’â³ã£â€šâ·ã£æ’â€¢ã£æ’ë†,Soundtrack,Soundtrack,Ã¥â¿ëœã£æ’â¬ã£æ’å ã¨?â€°Forget-me-notÃ£â€šâªã...,10093,2002,109535
# Groover,Soundtrack,Soundtrack,Ã£â€šâ°ã£æ’âªã£æ’â¼ã£æ’â³ã£â€šâ°ã£æ’âªã£æ’â¼ã£æ...,10097,2002,109539
# CaveÃ¤â¸â¦ã¦å“â¨ã¥â­â¦,Soundtrack,Game,Ã¦â‚¬â€™ã©â¦â€“ã©â ëœã¨å“â€šÃ¥â¤â§ã¥â¾â‚¬ã§â€...,10106,2003,109548
# Classic,Soundtrack,Soundtrack,4â¿ã¹Ã€ãœâ¾ãÿâ±ã¢O.S.T,10115,2023,109557
# Ã¤â¹â€¦ã§å¸â³ã¨â­â²,Soundtrack,Soundtrack,Ã©â¢â¨ã£?â®ã¨â°â·ã£?â®ã£æ’å ã£â€šâ¦ã£â€šâ·ã£â€š...,10146,1987,109588
# Various,Soundtrack,Pop,Ã‡ã Ã¤ã¢ã³ã¬ã¿Ã§ã ã©ã¶ã ã¬ã¨,10165,2003,109608
# PajamasSoft,Soundtrack,Soundtrack,Ã£æ’â€˜ã£æ’â€ ã£â€šâ£ã£â€šâ·ã£â€šâ¨ã£?âªã£?â«ã£...,10167,2003,109610
# Â°ã»â»ã³â¿â±,Soundtrack,Gospel,Ãƒâ¹â¹ã¸ã‚â°Â¿â¹â¼ã¶Ã€ãœâ¾ãÿâ±ã¢-Â°ã¸â»ã½â¾ã–,10183,2001,109626
# Tokio23,Soundtrack,Anime,Ã£æ’â¡ã£â€šâ¬ã£â€šâ¾ã£æ’â¼ã£æ’â³23Ã£â€šâªã£æ’â...,10190,2000,109634
# Â¢ã­ã­ã¡Ã‚ãÿã³ã³ã§,Soundtrack,Ãã¯ãã¥,Ãã¡ã±ãœã®ã¥ã­ã¥ã²Ã¥ã©ãªã¼ã­ã¥ã²,10207,2004,109651
# VariousArtists,Soundtrack,Soundtrack,Ã£æ’â€žã£â€šâ¤ã£æ’â³ã£æ’â€œã£æ’â¼Paradise5th....,10210,2006,109654
# VariousArtists,Soundtrack,Soundtrack,Â»âªãˆã‹âµã§ã“â°ã’ã´ã€ã–âµã¤â²ã˜,10215,1999,109659
# Â±iâ¾ã‡â¤ã,Soundtrack,Soundtrack,1999Â¤ãâ­ã“â¤hâ¡eâºtâ°ã›â·|-[discTwo],10235,1999,109680
# Ãšã®ã°ã­ã¥ã«ã¾ãªÃˆã£ã®ã°ã¼,Soundtrack,Soundtrack,Ãã ã­ã¤ã¨ã²ã±ãªã¨ã©Ãã¥ã²ã¥ã°ã¡ã³ã°ã£(ã¬ã³ã§...,10242,2001,109687
# Ã¥â€™å’ã§â€â°Ã¨â€“â«,Soundtrack,Anime,3ãƒâ€”3EyesÃ§â¬â¬ã¥â¼?ã§â«â,10252,1991,109697
# Various,Soundtrack,Soundtrack,Ãã¥ã§ã³ã¬ã­ã»ã©Ã„ã¥ã­ã¼Ã¨ã«ã¨Ã†ã¥ã­ã¨ã²ã¼ã¡...,10269,2003,109714
# VariousArtists,Soundtrack,Soundtrack,Â¹ãœâ¼ãºâ°ã¼Â¿â·Âµâ¿â¹â°â¿ã¸,10287,1998,109732
# Â±ã¨Â´ã«ãˆâ«,Soundtrack,Soundtrack,Â¹ãœâ¼ãºâ°ã¼â¿â·Âµâ¿â¹â°â¿ã¸,10296,2000,109743
# Ããÿãªã¯ã²Ãã¯ã±ã´ã¯ãªãœã«ã¯ã£ã«ã¯ãµ,Soundtrack,Soundtrack,Ãœã°ã±ã¡ã¦ã©ã«ãã±ã¯Ost,10301,2001,109749
# ÃœmitBesen,Soundtrack,Fantazi,OGece,10305,2003,109753
# ExplodeCoraã§ã£o,Soundtrack,Soundtrack,Nacional,10307,1995,109755
# Kbs,Soundtrack,Soundtrack,KbsTvâ¸â¸ãˆâ­â¿âµãˆâ­Â³ã«â·â¡â¸ã°ã€â½,10328,2000,11455
# Â¼ã’â¸â®â¿â¤,Ccm(contemporaryChristianMusic),Ccm(contemporaryChristianMusic),ModernWorshipShema(â½â¦â¸â¶),10337,2002,1866
# Ãœã³ã°ã§ã¨ã«ãªã¨International,Folk,RussianPop,Ãœã³ã°ã§ã¨ã«ãªã¨+,10345,2003,2252
# Â²ãœã‡ã™,Folk,Pop,Ãžã§ã’â¹â³â¡,10350,1995,2418
# Ãœã³ã°ã§ã¨ã«ãªã¨International,Misc,RussianPop,Ãœã³ã°ã§ã¨ã«ãªã¨+,10438,2003,4733
# Lenine,Misc,Misc,NaPressã£o,10452,1999,5025
# Kbs,Misc,Soundtrack,KbsTvâ¸â¸ãˆâ­â¿âµãˆâ­Â³ã«â·â¡â¸ã°ã€â½,10460,2000,5289
# Molotov,Misc,Misc,Â¿dã³ndeJugaranLasNiã±as?,10462,1997,5360
# DepecheMode,Rock,NewAge,TheSingles86>98(disc2),10505,1998,6377
# Ã¦??ã©â€¡å’,Rock,Pop,Opus21Disk1,10597,1995,7605
# Molotov,Rock,Grunge,Â¿dondeJugarã¡nLasNiã±as?,10660,1997,8430
# SmashingPumpkins,Rock,Rock,Live@UnitedCenter,Chicago(29.11.2000)Cd1,10702,2000,8908
# ------------------------------------------------
# 36,1003,Ã§â€ºâ€ ã¥â¸â°ã£â€šå
# 37,1003,Ã£?â€žã£?â¤ã£?â€¹ã¨â¡â€”ã£?â§ã¤â¼å¡ã£?â£ã£?å¸ã£...
# 38,1003,Ã©â¢â¨ã£?â®ã£?âªã£?â€žã¦â€”â¥
# 39,1003,Ã£?å¸ã£?â ã£?å ã¥â€°?ã£?å’ã£?â€žã£?â€ž
# 40,1003,Ã£?âµã£â€šå’ã£?â€šã£?â€ž
# 41,1003,Ã£?â€šã£â€š?ã©?â€™ã¦ëœâ¥
# 42,1003,Ã¤â¿âºã£?å¸ã£?â¡ã£?â®ã¦â€”â€¦
# 43,1003,Ã§â„¢â½ã£?â€žã¥â¯â«ã§å“å¾ã©â¤â¨
# 44,1003,Ã£?â€¢ã£?â„¢ã£â€šâ€°ã£?â€žã¦â„¢â€šã¤â»â£
# 45,1003,Ã¥â¤å“ã¨â¡å’ã¥ë†â€”ã¨â»å
# 46,1003,Ã£?â€šã£?âªã£?å¸ã£â€šâ€™ã¦â€žâ€ºã£?â„¢ã£â€šâ€¹ã...
# 47,1003,Ã©?â€™ã¦ëœâ¥ã¨â²â´ã¦â€”?
# 54,1004,S.Joã£oÃ©Foliã£o
# 56,1004,TudoFareiParaTerATuaPaixã£o
# 58,1004,VemBailarOTicTicVerã§ã£oDance
# 60,1005,Ã£æ’â¡ã£æ’â¢ã£æ’âªã£æ’â¼
# 61,1005,Ã£â€šâªã£æ’â¼ã£æ’â´ã£â€šâ¡ã£æ’?ã£æ’â¥ã£â€šâ¢
# 62,1005,Ã£â€šâ¸ã£â€šâ§ã£æ’âªã£â€šâ¯ã£æ’â«ã£â€šâ½ã£æ’â³ã...
# 63,1005,Ã£æ’?ã£æ’â¼ã£æ’å¸ã£æ’â³ã£â€šâ°ã£æ’â»ã£â€šâªã£æ’...
# 64,1005,Ã£â€šâ¸ã£â€šâ§ã£æ’â€¹ã£â€šâ¨ã£æ’â€¹ã£æ’â€°ã£æ’æ...
# 65,1005,Ã£æ’â©ã£æ’â ã£æ’â»ã£â€šâ¿ã£æ’â ã£æ’â»ã£â€šâ¿ã£â...
# 66,1005,Ã£â€šâ°ã£æ’âªã£â€šâ¶ã£æ’â„¢ã£æ’â©Ã¢ë†â€™ã¥â¨â¼...
# 67,1005,Ã£æ’?ã£â€šâ¹ã£æ’ë†ã£æ’â€¢ã£â€šâ¡ã£æ’â¼ã£â€šâ¸ã£...
# 68,1005,Ã£æ’å¾ã£æ’â³ã£â€šâ´ã£â€šâ¸ã£â€šâ§ã£æ’âªã£æ’â¼ã£...
# 69,1005,Ã£æ’â€¡ã£æ’â¥ã£æ’ë†ã£æ’â­ã£æ’å½ã£æ’å¸ã£æ’â¼Ã¢ë...
# 70,1005,Ã£â€šâ¸ã£â€šâ§ã£æ’âªã£â€šâ¯ã£æ’â«ã¨ë†å¾ã¨â¸?ã¤â¼å¡
# 71,1005,Ã£æ’â¡ã£æ’â¢ã£æ’âªã£æ’â¼
# 133,1011,Ãã–â´ã‚Â³âªâ¸â¦Â±ã¢â¸â£â½ãƒâ´ã‚Â¸ã±ã€ãš
# 134,1011,Â³âªâ´ã‚Â¹ãã€â½ã€â¸â·ãž
# 135,1011,Â°ã…â·ã¨ã‡ãâ½ã…Ã‡ãâ³âªâ´ã”(giveThanks)
# 136,1011,Â¿â¹â¼ã¶Â»ã§â¶ã»ã‡ãâ½ã‰ã€âº
# 137,1011,Â¿ã¬â¸â®ã‡ã”â²â²Â±ã¢â»âµã‡ã˜
# 138,1011,Â¿ã¬â¸â®â¸ã°âµãžÂ¼ã•â»ãã„â¡â¸ã§
# 139,1011,Âºã±ãƒãÿâ¼ã’â¼â­
# 140,1011,Ãˆâ£â»ãªâ³âª
# 141,1011,Ãã–â´ã”ã€ã‡Â½ãƒâ°â£â¿â¡
# 142,1011,Â¼â±â»ã½â´ã”â°ãºÃ€ã›ã€âºÃƒâµâ»ã§âµã©
# 143,1011,Â¿ãâ¿ãâ¼ã›
# 144,1011,Ã‚ã¹â¾ã§ã‡ã˜
# 180,1015,????????
# 181,1015,???????
# 182,1015,?????
# 183,1015,???????????
# 184,1015,???????
# 185,1015,???????????????
# 186,1015,???????
# 187,1015,????????
# 188,1015,?????
# 189,1015,???????
# 190,1015,????????
# 191,1015,??????
# 192,1015,??
# 193,1015,????????
# 254,1021,Ã¦â€”â€¦ã¤âºâº
# 255,1021,Ã£æ’â€œã£æ’â¥ã£æ’â¼ã£æ’â€ ã£â€šâ£ã£æ’â€¢ã£æ’â«ã...
# 257,1021,Ã£æ’?ã£æ’æ’ã£æ’â€ã£æ’â¼ã£æ’â©ã£â€šâ¤ã£æ’â€¢
# 258,1021,Ã£?â€¢ã£â€šâ€°ã£?â°ã¦?â€¹ã¤âºâº
# 259,1021,Ã¥æ’â€¢ã£?â®ã¥â£â°-albumVersion-
# 260,1021,Ã§â©âºã£?â«ã¥â€â€žã£?ë†ã£?â°
# 261,1021,EndOfã¢â‚¬â¦
# 262,1021,Ã£â‚¬å’ã¦â€°â€¹ã§â´â„¢ã£â‚¬?
# 263,1021,Ã£æ’å“ã£æ’â¼ã£æ’å ã£â€šâ¹ã£æ’ë†ã£æ’â©ã£æ’æ’ã£â€šâ¯
# 279,1023,Ã£?â€šã£â€šå ã£?âµã£â€šå’ã£?å¸ã¦â€”â¥ã¥â¸â¸ã£â€...
# 289,1024,Â¿ã‹â±ã¢ã€ã¥ã€ãœÂ¼â±â±â³â´ãœ-Ãã–â´ã‚Â³âªâ¸...
# 290,1024,Ã€â§âµã¥-Ãã–ã€ã‡Ã€ãœâ¸â§Â³ã´ã€ãœâ¸ã§
# 291,1024,Â¿â¤â½ãœâ¾ã®ãã®-Ãã–â´ã”ã€ãœÂ³âªâ¸â¦Ã€â§ã‡...
# 292,1024,Âµã•ãã¶-Âµâµâ½ãƒã€ã‡Â¹ã£Ã‡ãâ´ãƒâ¿â£Âºâ°ã...
# 293,1024,Â´ãžã†ã˜ã€ãœ-Â¸â»â¾ã¸ã€ãœÂ»ã§â¶ã»ã‡ãâ¿â©â¶ã³
# 294,1024,Ã‡ã±â½ãƒâ¹ã™-Â°ã…â·ã¨ã‡ãâ½ã…Ã‡ãâ´ã€â´ã”
# 295,1024,Say-Ã€ãœãâ¦Â¿ã¬â¸â®Ã€ãœâ°ã·â¿â¡
# 296,1024,Â¼ã’â¿ã¸-Ãâ¸â±ãã‡ã‘Ã€ãœâ¿â¡â°ã”
# 297,1024,Ã€ãžã„â¡-Âµâ¿ã‡ã 2
# 298,1024,Â¹ãšâ¶ã³â³âª-Â³â»Ãã–â¸â¦Â°â¡â±ã®ã€ãœÃ‡ãâ...
# 299,1024,Ã‡ã”âºãžâ¿âµ-Â³âªã€ã‡Â±ã¢âµâµâ¸â¦
# 300,1024,Ã†ã²ãˆâ­â³âªâ¶ã³-Â»ã§â¶ã»ã‡ã˜â¿ã¤
# 325,1026,RetourEnGã¢tine
# 326,1027,Ã¨å â±ã§â­â€ ã¦â€“â€¡ã¥â­â€”
# 327,1027,Ã©â„¢â½ã£?â®ã£?â€šã£?å¸ã£â€šâ€¹ã¥?â€šã©?â€œ
# 328,1027,Ã¦â€šâ²ã©â¡ëœã¨å â±
# 329,1027,Ã¨â¨â‚¬ã£â€š?ã£?â¬ã£?å’ã¨å â±
# 330,1027,Ã©?â€™ã£?â€žã§â¾å ã¦â­â¯-ã£â€šâ¢ã£â€šâ¸ã£â€šâ¢...
# 331,1027,Ã©â£â€ºã©â¨â¨ã£?â®ã¥?å ã£â€šå ã¦â©â€¹
# 332,1027,Ã§â§â€¹ã¦â¡å“
# 333,1027,Ã£?â€šã£?â¾ã£â€šå ã£â€šå ã£?â„¢
# 334,1027,Ã£æ’â€°ã£æ’â©ã£â€šâ¤ã£æ’â€¢ã£æ’â©ã£æ’â¯ã£æ’â¼
# 336,1027,Ã¦å“â‚¬ã¥â¾å’ã£?â®ã©â ?
# 337,1027,Ã¥â¯â€™ã¦â¤â¿
# 350,1029,3!@l>f4o1b8&
# 352,1029,C<3d
# 353,1029,H%@z32@:3j8&:88g
# 354,1029,3j@gBx0\
# 355,1029,>n5r@l0hhw8i
# 356,1029,G6{
# 357,1029,}@o<190
# 359,1029,G6{gr6'1nav
# 365,1030,Ã£æ’å¾ã£æ’â¡ã£â€šâ·ã£æ’?
# 366,1030,Ã£â€šâ¢ã£â€šâ¹ã£æ’ë†ã£æ’â­ã£æ’å“ã£?â®ã§â©âº
# 367,1030,Ã£â€šâ¢ã£æ’â«ã£â€šâ«ã£æ’â­ã£â€šâ¤ã£æ’â€°
# 368,1030,Ã§â´â€¦ã¨å’â¶
# 369,1030,Ã¦å“â¨ã§â„¢â»ã£â€šå ã£?â¨ã¨âµâ¤ã£?â€žã£â€šâ¹ã£â...
# 372,1030,Tã£â€šâ·ã£æ’â£ã£æ’â€ž
# 373,1030,Ã§â©âºã¦â°â€”ã£?â¨ã¦ëœå¸
# 374,1030,Rule~ã¨â€°â²ã¨â¤âªã£?â€ºã£?âªã£?â€žã¦â€”â¥ã£â‚¬â€¦
# 375,1030,Ã§â§?ã£?â¯ã¤â¸ëœã£?â®ã¤â¸å ã£?â€¹ã£â€šâ€°ã¨å â±...
# 477,1038,Â³âªâ¸â¦Âµâ¹â¾ã†âºã
# 478,1038,Â¾ã‹â°ã­Ã€ã–â¾ãºâ¾ã®
# 479,1038,Â±ã—â´ã«Ãã¶â±ãÂ´ã™â½ãƒ
# 480,1038,Â¹â«ãâ¦
# 481,1038,Âºã¸â¼ã“â¿â¡â¼â­
# 483,1038,Ãˆã»âµã©â¾ã®
# 484,1038,Â¶ã‡Ã‡ãâ³âªã€ã‡Â½â½ã‡ã„
# 485,1038,Â±ã—Â¶â§
# 486,1038,Â¿ã¬â¸â®â´ã‚
# 487,1038,Â¿â©â¸â§â¾ãˆâ¿â¡â¼â­
# 488,1038,Â¾ã ã‡ã‘Â³â²ã€ãš
# 490,1039,Qingdao-ã§âª?ã¨â²â«ã¥â·â¥ã¤âºâ€¹edit-
# 495,1039,Ã¦?â±ã¦â€“â°ã¥â®â¿millionaire
# 652,1045,Noã«lInterdit
# 671,1047,Ã£â€šâ¢ã£æ’â€°ã£æ’â¬ã£æ’å ã£æ’âªã£æ’â³
# 672,1047,Ã£â€šâ»ã£æ’â­ã£æ’âª
# 673,1047,Ã£æ’â„¢ã£æ’â³ã£â€šâ¸ã£æ’â£ã£æ’å¸ã£æ’â³
# 674,1047,Ã£â€šâ¹ã£â€šâ¯ã£æ’âªã£æ’â¼ã£æ’å¸ã£æ’â³'97
# 675,1047,Ã¥??ã¥â€°?ã£?â®ã£?âªã£?â€žã©â³â¥
# 676,1047,Ã£â€šâ³ã£æ’å¡ã£æ’â«ã£æ’â€¹ã£â€šâ¯ã£â€šâ¹ã£?â®ã¥?âµ
# 677,1047,Ã¥æ’â€¢ã£â€šâ€°ã£?â®ã§â€¦â©ã¦â€šâ©
# 678,1047,Ã¦ëœâ¼ã¤â¼â€˜ã£?â¿
# 680,1047,Ã£æ’â¤ã£â€šâµã§â€â·ã£?â®ã¥â¤â¢
# 693,1049,Ã¬ã Ã®ã¥ã¥ãºã¸
# 694,1049,Ã¤ã®ã«ã¥ã°ã¤Ã¹ã¬Ã¤ã¢ã¸ã¥ã¡
# 695,1049,Ã¹ã¬ã¥ã­,Ã±ã¬ã ã­,Peace
# 696,1049,Ã¢'ã¸ã¥ã¦ã¬ã­
# 697,1049,Ã¨ã¸ã¥ã®ã´ã¬ã£ã¥ã¸
# 698,1049,(ã®ã¡ã©ã¨(ã ã©ã¦ã¤Ã¢ã°ã¥ã¡
# 699,1049,Ã ã³Ã ã§ã£
# 700,1049,Ã²ã¡ã¸ã©ã©ã¯
# 702,1049,Ã¤ã¥ã¥ã¬ã©ã¥ã­Ã²ã¥ã¬ã¤
# 703,1049,(ã¤ã£ã¢Ã°ã§ã¹(ã¢'ã ã­
# 704,1049,Ã·ã¥ã±ã ã®ã ã®ã·
# 745,1052,Ã£?â€šã£?â€”ã£?å¸ã£?â®ã§â§?ã£?â«ã¤â¼å¡ã£?â€žã£?...
# 766,1054,Ã¤â¸â€“ã¨â©â±ã£?å’ã£â€šâ€žã£?â€˜ã£â€šâ€¹ã£?å“
# 767,1054,Ã¥â¥â´ã£?â¯ã£æ’â€¡ã£æ’â€œã£æ’â«
# 768,1054,Ã¦å“â‚¬ã¥â¾å’ã£?â®ã§â´â€žã¦?å¸
# 769,1054,Ã£â€šâ­ã£æ’â£ã£æ’â­ã£æ’â«
# 770,1054,Ã¥â¤?ã£?â®ã£æ’â€¢ã£â€šâ©ã£æ’ë†ã£â€šâ°ã£æ’â©ã£æ’â€¢
# 771,1054,Ã¨â€¹â¦ã£?â€žã¦â¶â„¢
# 772,1054,Ã¦?â€¹ã£?â®ã¥ë†â€”ã¨â»å ã£?â¯ã£æ’âªã£æ’?ã£æ’â€”...
# 773,1054,Ã£â€šâµã£æ’â€“ã£â€šâ¦ã£â€šâ§ã£â€šâ¤ã§â€°â¹ã¦â‚¬â¥
# 774,1054,Ã£æ’â©ã£â€šâ¤ã£æ’â€¢ã£æ’â»ã£â€šâ¤ã£â€šâºã£æ’â»ã...
# 775,1054,Ã£æ’ë†ã£æ’â©ã£æ’â„¢ã£æ’âªã£æ’â³ã£æ’â»ã£æ’?ã£â€šâ¹
# 776,1054,Ã§â€¡æ’ã£?ë†ã£â€šâ€¹ã£â€šâµã£æ’â³ã£â€šâ»ã£æ’æ’ã...
# 878,1061,01_â¿ã˜ãã¶_â´ã€â³â¦ã€ãœ_ããâ¾ã†
# 880,1061,03_â¿ã€â·â£_â±ã¢â¾ã¯â¼ã“_â³ãšâ¿â¡â°ã”
# 881,1061,04_âµãž_â¹ã¸ã‚â°_ã€ãœâºâ°
# 882,1061,05_âºã±â¹ã
# 883,1061,06_ãã¸â½ã‰
# 884,1061,07_â³ãž_ã€â§ã‡ã‘_ã€ãšâ¸â®
# 885,1061,08_âºâ¡â¾ã®â¸â®_â³ãƒâ°â¡â½â¿
# 887,1061,10_âµâ¿ãˆâ­
# 888,1061,11_ã‡ã’â¸ã“â´ãâ¿ã_â»â¡â°â£_â½âºâ¿ã¾ã…ã
# 926,1065,Â¿ã¬â¸â®Âºâ¸ãã‚Â¾ã•â¿â¡â¸ã°â¿â©
# 927,1065,Â¿ã€Â½ã…â½ã‡Ã‡ãâ½ã…Ãã–
# 928,1065,Ãã–â¸â¸Â¹ã™â¶ã³âºâ¼ã‚ã®â¶ã³
# 929,1065,Â¼â¼â»ã³Â¸ã°âµã§Â¹ãžãâ·ã€ãœ
# 930,1065,Â¾ã°ãâ¦â³âªÂ³â»â¸ã°â½ã€
# 931,1065,Â¸ã°âµã§Ã€ãœâ¸â§ã€â§â¿â¡Â¶ã™â¾ã®â³â­
# 932,1065,Â»ã§â¶ã»ã‡ãâ´ã‚Â³âªã€ã‡Â¾ã†â¹ã¶ãã¶
# 933,1065,Â³â»Â°â¨ã€âºÂ´â«â¾ãˆâ¿â¡
# 934,1065,Ãã–â²â²Â°â¡â¿ã€â´ã
# 935,1065,Â³âªã€ã‡Â¸â¶ã€â½ã€â»Ãâ¤â±ãâ°ãºÂ°â°ã€ãœ
# 936,1065,Â³âªã€ã‡Â°â¡â´ã‚â±ã¦
# 937,1065,Ãã–ã€ã‡Â»ã§â¶ã»ã€â»Ãã–ã€ã‡Â¼â±ã‡ãâ½ã‰ã€âº
# 938,1065,Â¾ã†ã„â§â¾ãˆâ°â³Â´â«â¾ã•Â°â¡â¸â®âµã­
# 939,1065,Â¾ã†ã„â§â¿â¡Ãã–ã€ã‡Ã€ãžã€ãšã‡ãâ½ã‰ã€âº
# 964,1068,Ã€ãªã³ã«ã -Ã‘ã²ã ã¨Ã¯ã²ã¨ã¶
# 965,1068,Ãšã°ã ã±ãªã¨-Ã‚ã±ã¥ã£ã®15Ã«ã¥ã²
# 966,1068,Ãã³ãªã¨Ã‚ã¢ã¥ã°ãµ-10Ã«ã¥ã²
# 967,1068,Ã‚ãˆã€Ãƒãã€-Ã‚ã®ã²Ã²ã ãªã¨ã¥Ã¤ã¥ã«ã
# 968,1068,Ãžã²ã¯ã¥ã²ã»ã¥Ã¬ã®ã¸ã¥ã­ã­ã¨ãªã¨Ã¨Ã€ã£ã³ã²ã¨...
# 969,1068,Ãã«ã¥ã±ã²ã¿ã¹ã¨ã¥-Ã€ã¯ã¥ã«ã¼ã±ã¨ã­ã®ã¢ã ã¿Ã...
# 970,1068,Ã…ã¢ã°ã®-Ãšã®ã«ã¿ã­
# 971,1068,Ã”ã ã¡ã°ã¨ãªã -Ãœã®ã°ã¥Ã§ã®ã¢â¸ã²
# 972,1068,Ãã³ã±ã±ãªã¨ã©Ã°ã ã§ã¬ã¥ã°-Ãžã¡ã­ã¨ã¬ã¨Ã¬ã¥...
# 973,1068,Ã†ã ã±ã¬ã¨ã­-100%Ã«ã¾ã¡ã¢ã¨
# 974,1068,Triplex-Ãã°ã¨ã£ã ã¤ã
# 975,1068,Ã„ã°ã³ã£ã¨ã¥Ã¯ã°ã ã¢ã¨ã«ã -Ãžã­ã Ã²ã¥ã¡ã¥Ã...
# 976,1068,Ã‘ã²ã°ã¥ã«ãªã¨-Ã‚ã¥ã²ã¥ã°ã®ãª
# 977,1068,Ãƒã®ã±ã²ã¨Ã¨ã§Ã¡ã³ã¤ã³ã¹ã¥ã£ã®-Ã“ã§ã­ã ã©Ã...
# 978,1068,Ãšã®ã¬ã¨ã±ã±ã ã°-Ã€ã­ã£ã¥ã«
# 979,1068,Ã’ã ã²ã³-Ãã¥Ã¢ã¥ã°ã¼,Ã­ã¥Ã¡ã®ã©ã±ã¿,Ã­ã¥...
# 980,1068,Ã•ã«ã¥ã¡ã­ã¨ãªã®ã¢ã -Ã€Ã¿Ã­ã ã°ã¿ã¤ã­ã ã¿
# 981,1068,McÃ‚ã±ã¯ã»ã¸ãªã¨ã­-Ãšã®ã«ã¡ã ã±ã­ã»ã©Ã¶ã¥ãµ
# 982,1068,Ã‚ã¨ã°ã³ã±-Ãã°ã ã²ã¨ã¸ãªã (ã°ã¥ã¬ã¨ãªã±)
# 983,1068,Ã.Ãã ã°ã¶ã¨ã±ã±-Ã˜ã®ãªã®ã«ã ã¤ã­ã»ã©Ã§ã ã¿ã¶
# 984,1068,Ãœ.Ãã¦ã¥ã¢ã±ãªã ã¿-Ãšã®ã¸ãªã
# 985,1068,Ã‚ã ã°ã³ã¬-Ãã¥ã¯ã®ã£ã®ã¤ã
# 986,1068,Ãœã ã°ã¸ã ã«-Ãžã²ã¯ã³ã±ã²ã¨Ã«ã¾ã¡ã®ã¢ã¼
# 987,1068,Ãšã ã²ã¿Ã‹ã¥ã«ã¼-Ã„ã®ã«ã¥ã²ã ã©
# 988,1068,Ã‘ã¥ã°ã¤ã¾ã·ãªã -Ã‘ã¢ã ã¤ã¥ã¡ã­ã ã¿
# 989,1068,Ãž.Ãžã°ã«ã®ã¢ã -Ã‹ã ã¤ã®ã­ã¨
# 990,1068,Ã‚ã ã«ã¥ã°ã¨ã¿-Ã‘ã²ã°ã ã­ã Ã«ã¾ã¡ã¢ã¨
# 991,1068,Ãƒã«ã¾ãªã®ã§ã -Ã‘ã­ã¥ã£
# 1077,1076,Ã‡ãâ´ãƒã€ã‡Ãƒãšâ´ã«(inviteFromTheHeaven)
# 1078,1076,Ãã–â´ã”ã€ã‡Â»ã§â¶ã»(loveOfGod)
# 1079,1076,Â³â»â°ã”Â°â­Â°â°ã€âºÃ†ã²ãˆâ­(peaceLikeAR...
# 1080,1076,Â³â»Â¿âµãˆâ¥â¾ã†(ohMySoul)
# 1081,1076,Â½ãƒã†ã­133ã†ã­(psalms133)
# 1082,1076,Ãã–Â³âªã€ã‡Ã‡ãâ³âªâ´ã”(theLordMyGod)
# 1083,1076,Ãã–â´ã”ã€â»Ã‚ã¹â¾ã§ã‡ãâ¶ã³(praiseTheLord)
# 1084,1076,Ã‡ãâ³âªâ´ã”ã€ãœÃã–â½ãƒâ´ã‚Ãƒã âºâ¹(theBle...
# 1085,1076,Ã€ãœâ»ã§â¾ãÿ61ã€ã¥(issaiah61)
# 1086,1076,Â»ã§â¶ã»ã‡ã•â´ãâ´ã™(loveInJesus)
# 1087,1076,Â»ã§â¶ã»ã‡ã•â´ãâ´ã™-â¹ããã–(loveInJesus-...
# 1186,1084,Joã£oPernambuco/SonsDeCarrilhoes-MarcoP...
# 1191,1085,Mã¤dcheNemmMichInD'rÃ„rm
# 1237,1088,PederPersson/Ã–st-trã¶nder
# 1239,1089,Ã¤â¸â€°ã§â€¢âªã§â€ºâ®ã£?â®ã¥â¹â¸ã£?â€º
# 1240,1089,Ã£?â€žã£?â¤ã£?â€¹
# 1241,1089,Ã£â€šâ»ã£â€šâ¯ã£â€šâ·ã£æ’â¼ã£æ’â»ã£æ’?ã£â€šâ¹ã£...
# 1242,1089,Ã£?â€¢ã£â€šë†ã£?âªã£â€šâ€°ã£?â¯2bã£?â®ã©â€°â€ºã...
# 1243,1089,Ã¦â¨âªã©â¡â€
# 1244,1089,Ã¥â¤â¢ã¨â¦â€¹ã£?â¡ã£â€šæ’ã£?â€žã£?âªã£â€šâ¿ã£â€...
# 1246,1089,12ã¦å“ë†ã£?â®ã©â€ºâ¨
# 1247,1089,Ã£?â€žã£?â¨ã£?â€”ã£?â®ã£â€šâ¨ã£æ’âªã£æ’â¼
# 1276,1092,LeGoã»tDuMiel
# 1470,1107,Â¿quienQuiereJugar?
# 1533,1113,Ã¦â¡å“ã¦â€¢â£ã£â€šâ€¹
# 1534,1113,Ã¨â„¢â¹ã£?â®ã¦å“â¨
# 1535,1113,Ã¦â­â³ã¦â„¢â€šã¨â¨ëœ
# 1536,1113,Ã¦â¡?ã£?â®ã¨å â±
# 1537,1113,Onlyã£â‚¬å“ã¨â€“â€ã¨â€“â€¡ã¥å“â€™ã£â‚¬å“
# 1539,1113,Ã£â€šâ¸ã£æ’â£ã£â€šâ«ã£æ’â©ã£æ’â³ã£æ’â‚¬ã£?â®ã¤â¸ëœ
# 1540,1113,Ã¥â¤â¢ã£?â€”ã£?â ã£â€šå’
# 1541,1113,OctoberÃ£â‚¬å“ã£æ’âªã£æ’âªã£æ’â¼ã£â€šâ«ã£â€šâµ...
# 1542,1113,Ã£æ’â€¡ã£â€šâ¤ã£â€šâ¸ã£æ’â¼
# 1543,1113,Ã£?â²ã£?â¾ã£â€š?ã£â€šå
# 1945,1145,UmaNovaUnã§ã£o
# 1958,1146,Ã¦â„¢â€šã¤â»â£
# 1959,1146,Ã¨â¿â½ã£?â€žã£?â€¹ã£?â€˜ã£?â¦ã£æ’â¨ã£â€šâ³ã£æ’?...
# 1960,1146,Ã£æ’â­ã£æ’â³ã£æ’âªã£æ’â¼ã£æ’â»ã£â€šâ«ã£æ’å ã£æ’...
# 1961,1146,Ã¦â¯â€ã¥â€˜â€šã©â­â€¦ã¥?â¿ã£?â®ã§å â¯ã§â½âª
# 1962,1146,Ã¦â€žâ€ºã£?â€¢ã£â€šå’ã£â€šâ€¹ã¨å â±Ã¦â€žâ€ºã£?...
# 1963,1146,Ã£?â€ ã£?â€¹ã£â€šå’ã¥â±â€¹
# 1964,1146,Ã¦â°â¸ã©?â ã£?â®ã¥ëœëœã£â€šâ€™ã£?â¤ã£?â€žã£?â¦ã...
# 1965,1146,Ã©â¢â¨ã£?â®ã¥â§â¿
# 1966,1146,Ã¨â€šâ©ã¥â¹â€¦ã£?â®ã¦å“âªã¦?â¥
# 1967,1146,Ã§âªâ€œã£â€šâ¬ã£æ’â©ã£â€šâ¹
# 1968,1146,Ã¦â€¦å¸ã¥â€œâ­
# 2354,1177,Â¤sâ¨â£â¤ã«â©ãº
# 2355,1177,Â²â´â·ãºâ¦yâ¦bâ²nâ²o
# 2356,1177,Â¨ã¢â¤pâµlâªâ¾
# 2357,1177,Â·râ¤â§â¶ã©
# 2358,1177,Ã¨â°âºqâ¦ã±â¬pâªe
# 2359,1177,Ã§ã„â¬pâ°âªâ°ã›
# 2360,1177,Â­ã¬â³â¥âªâºâ§ãš
# 2362,1177,Â¿eâ¬y
# 2363,1177,Â¶xâ¦â¹â¤ã–â¦~â®ã‰
# 2364,1177,Â®ãˆâµ{
# 2365,1177,Â«â°â¥â«â¤â§âºq
# 2391,1180,Ã‘Ãªã°ã ã±ã ã¢ã¨ã¶ã¥ã©Ã¢Ã®ã¡ã­ã¨ã¬ãªã³
# 2392,1180,Ãšã®ã£ã¤ã Ã¬ã­ã¥Ã¡ã»ã«ã®20Ã«ã¥ã²
# 2393,1180,ÃÿÃ²ã ãªÃµã®ã²ã¥ã«...
# 2394,1180,Ã’ã ã­ã¶ã³ã©ã²ã¥,Ã¤ã¥ã¢ã®ã·ãªã¨!..
# 2395,1180,Ãã¿ã²ã¼Ã¬ã¨ã­ã³ã²Ãµã®ã¤ã¼ã¡ã»
# 2396,1180,Ãã®ã¡ã°ã¿ãªã³ã¸ãªã
# 2397,1180,Ãœã¥ã¤ã±ã¥ã±ã²ã°ã¨ã·ãªã
# 2398,1180,Ãã¥ã«ã»ã©Ã¯ã ã°ã®ãµã®ã¤ã¨ãª
# 2399,1180,Ãã²ã®Ã­ã¥Ã«ã¥ã²ã®...
# 2400,1180,ÃÿÃ¢ã»ã¸ã¥ã«Ã¨ã§Ã«ã ã£ã¥ã°ã¿...
# 2401,1180,Ã‚ã ã­ã®,Ã¯ã°ã®ã·ã²ã¨...
# 2402,1180,Ãã ã°ã¨ãªã¬ã ãµã¥ã°
# 2732,1208,Â´ã§â½ã…ã€â»Ã‡ã¢ã‡ã‘Â³ã«â·â¡
# 2733,1208,Â´ã§â½ã…ã€âºÂ»ã§â¶ã»Â¹ãžâ±ã¢Ã€â§ã‡ã˜Ã…ã‚â¾ã...
# 2734,1208,Ãã–â´ã”â²â²â¼â­Ãã–â½ãƒâ´ã‚
# 2735,1208,Ã‡ã¼ãâ¦ã€ã‡Â¸ã°â½ã€Â¼ã“â¿â¡
# 2736,1208,Â¸ã°âµãžÃã–Ã‚ã¹â¾ã§ã‡ã˜
# 2737,1208,Ãã–â¸â¸Â¹ã™â¶ã³Âºâ¼ãã¶â¶ã³
# 2738,1208,Â³ãšâ´ã‚Â½ãƒâ³ãâ°â¡â¿â¡Â½ã‰ã€âºÂ³âªâ¹â«â¶ã³
# 2739,1208,Ãã–ã€ã‡Â»ã§â¶ã»ã€â¸â·ãžÂ»ã§â¶ã»ã‡ã•â´ãâ´ã™
# 2740,1208,Ãƒã âºâ¹ã‡ãâ¼ã’â¼â­
# 2741,1208,Â¿â¹â¼ã¶Â»ã§â¶ã»Â³âªã€ã‡Â»ã§â¶ã»
# 2742,1208,Ãƒã âºâ¹â¼ã›
# 2743,1208,Ã‡ã¢â±ã¢Â¿â¬ãã–â°ã®Â¸ã°ã€â½
# 2859,1217,WeilDasGlãœckUnsterblichIst
# 2861,1217,WeilIchImmerVonDirTrã„ume
# 2864,1217,IchBinFãœrDichDa
# 2941,1223,Ã–verEnKoppIVã¥rBersã¥
# 2944,1223,Ã…retsSkiftningar
# 2997,1228,One/Ãã¡ã±ã¡ã³ãªã¥ãµãžÃ¢ã±ãœã¤ãµ
# 2998,1228,One/Ã„ã¥ã­Ã¬ã°ã¯ã±ã¾Ã·ã¹ã±ãÿã²Ã¥ã³ãã­ã¡
# 2999,1228,One/Ã…ã¤ã¾Ãªã¡ã©Ã´ã¾ã±ã¡
# 3000,1228,One&Ã…ãµã±ãµã¤ãÿãªã§/Ãšã±ãœã´ã¡Ãªã¡ã±ã¤ã©ã...
# 3001,1228,One/Ãã¾ã²!
# 3002,1228,One/Ãœãžã­Ã´ã¯Ãªãœã­ã¥ã©ã²Ã¡ãµã´ã¼
# 3003,1228,One/Ãã©Ãœã«ã«ã¯ã©Ãªã©Ã¥ã£ã¾
# 3004,1228,One/Ã”ã¯Ã¶ã©ã«ãÿ
# 3005,1228,One/Ã‡Ã¡ã£ãªã¡ã«ã©ãœÃ³ã¯ãµ
# 3006,1228,One/Ãã±ã¾ã´ã§Ã¬ã¯ãµÃ¶ã¯ã±ãœ
# 3007,1228,One/Ãšã¡ã«ã¯ãªã¡ã©ã±ã©ã­ãžÃ¬ã¯ãµÃ¡ã£ãœã°ã§
# 3008,1228,One/Ãã©ã³ã¨ãžã³ã¥ã©ã²
# 3242,1248,Rãngala
# 3243,1248,Ãster1
# 3244,1248,KayipKãmlãkVakasi
# 3246,1248,Hã-Ha
# 3248,1248,Ãster2
# 3249,1248,Gãz
# 3250,1248,Gã–rãœãžmeyelãm
# 3251,1248,Sãs
# 3277,1251,Szã¡rnyaskezã»Szeretãµk
# 3281,1251,VetkãµzãµsDal
# 3364,1258,D.Ã‚ngela
# 3440,1264,Ã„lskadeÃ¤ngel
# 3514,1269,Ã”ã¯Ãªã¯ã´ã«ãÃ°ã¡ã­ã´ã¥ã«ã¯ã­ãœãªã©
# 3515,1269,Ãã°ã¼Ã´ã§Ã£ãµã­ã¡ãÿãªã¡Ã£ã©ã¡Ã´ã§Ã£ãµã­ã¡...
# 3516,1269,Ãšãµãªã«ã¯ã¨ãµã¬ã©ãªã¼ã²Ãªã¡ã©ã±ã¼ã²
# 3517,1269,Ã”ã¡Ã¬ãžã«ã¡Ãªã¡ã©Ã´ã¡Ãªã±ãÿã­ã¡
# 3518,1269,Ã„ã¥ãµã´ãã±ã¡Ã®ã§ã¬ã¥ã±ã¾ã¬ã¡ã´ã¡
# 3519,1269,Ã–ãÿã«ã¥Ã¡ã¤ã¥ã«ã¶ãžÃ¸ãµã·ãž
# 3520,1269,Ã“ã¯ãµã®ã¥ã¤ã©ãœã±ã©ãªã¯
# 3521,1269,Ãšãœã­ã¥Ã°ã¹ã²Ã¬'Ã¡ã£ã¡ã°ãœã²
# 3522,1269,Ãã²Ã¥ãÿã­ã¡ã©Ã¯Ãªã¼ã³ã¬ã¯ã²Ã¦ã¼ã±ã©ãªã¯ã²
# 3523,1269,Ãœã¯ãÿã±ã¡Ã¤ã¥ã­Ã¬'Ã¡ã±ã¾ã´ã§ã³ã¥ã²
# 3524,1269,Ã”ã±ã¥Ã¦ã¯ã«ã©Ãªã©Ã¹ã±ã¡ãÿã¡
# 3525,1269,Ãã©Ã¬ãœã£ãªã¥ã²Ã¤ã¥ã­Ãµã°ãœã±ã·ã¯ãµã­Ã°ã©ã¡
# 3526,1269,Ã“ã¡ã­Ã¬ã©ã¡Ã´ã¡ã©ã­ãÿã¡
# 3536,1270,Sã©rgioRicardo/zelã£o
# 3539,1270,Francineth/oraã§ã£o
# 3756,1288,ÃjiNã©pdalok
# 3867,1298,Â±ã¨ãâ¾ãˆâ¯/Ãâ¸ã€ã§ã€ã‡Ã€ãœã€â¯
# 3868,1298,Â±ã¨ãâ¾ãˆâ¯/Â»ã§â¶ã»ã€â»Ã€â§ã‡ãâ¿â©
# 3869,1298,Â°â­ã€ãžâ¿ã¸/Ãâ¦â°â¡Â¸ã•ã€ãºÂ»ã§â¶ã»Ã‡ã’â...
# 3870,1298,Â¹ã©â¿âµâ±ã”/Â½â½ã‡ã‚Â°ã¨ã€ã½â¿â¡Â¸â¸â³âªâ¿ã¤
# 3871,1298,Â¾ã§ã‡ãâ¿âµ/Â°â¡â½ãƒâ¸â®
# 3872,1298,Â¹ã©â¿âµâ±ã”.Â¾ã§ã‡ãâ¿âµ/Â°â¹â¹ã™ã€â§/â¼ã¸ã€...
# 3873,1298,Â¹ãšâ°â­â¼âº/Ã€ã¥â³â­â°â¨Âºâ´ãâ¤
# 3874,1298,Â¹ãšâ°â­â¼âº/Â³â»ã€ãã€â»Â±ã¢â´ã™â·ã
# 3875,1298,Â±ã¨âµâ¿ãˆâ¯/Âºâ½Â¿â©â¸â§Â°â¡ã€â»Â°ãœâ¿ã¯
# 3876,1298,Â±ã¨âµâ¿ãˆâ¯/Â¹â¯â¾ã®â¹ã¶â¸â°Â¾ã†ã‡ã„
# 3877,1298,Â°â­ã€ãžâ¿ã¸.Â±ã¨âµâ¿ãˆâ¯.Â¹ãšâ°â­â¼âº/Âºã±â¿...
# 3878,1298,Ã€ã¥ã€âºâ¾ã†/Ã€ãœâ°ã…â¸â®â¸â¦Â»ã½â°â¢ã‡ã˜â¿ã¤
# 3879,1298,Ã‡ãâ³â²â¼â®/Ããã€âºÃ„â£â±â¸
# 4108,1317,C'estNoã«l!C'estNoã«l!C'estNoã«l!
# 4109,1317,Noã«lD'amour
# 4110,1317,Priã¨reD'unEnfantPourNoã«l
# 4111,1317,LePã¨reNoã«lCountry
# 4116,1317,CeSapinDeNoã«l/BlueChristmas
# 4227,1327,Â¾kâ¦bâ§aãƒhâ¤â¤
# 4228,1327,Â±ãÿãã¸
# 4229,1327,Â¯â«â¯âµâ¤kâ­â¦
# 4230,1327,Â¦nâ¬kâ®d
# 4231,1327,Â§ãšâ¦â³â¤@â¬qâ±â¡
# 4232,1327,Â©]â¨ã“â­â»
# 4233,1327,Â®aâ®aâ¦â³â¥â»ãƒã¸â©ã€âªâºâ¸g
# 4235,1327,Âµâ¥â§aâ¦^â¨ã“
# 4236,1327,Â¥ãƒâ»â·âªâºâ¬kâ¤ã‘
# 4237,1327,Â¦nâ¥ã¼ã€y
# 4238,1327,Â¤ã‘â²pâºqâ¤k
# 4251,1329,Mã¥nskenÃ–verÃ…ngermanã¤lven
# 4267,1330,AbraOCoraã§ã£oEliseuGomes
# 4268,1330,Leã£oDeJudaJosiasBarbosa
# 4270,1330,NaUnã§ã£oDeDeusElizeuGomes
# 4272,1330,SomosCoraã§ãµesValdeciAguiar
# 4412,1341,CaraCarambaSouCamaleã£o
# 4557,1353,Gã¼neã¾Ãžarkã½sã½
# 4618,1358,Nã£oHã¡AmigoIgualACristo
# 4620,1358,Quã£oDoceÃ©s,Jesus
# 4662,1362,Ã…SeckenLitenEn
# 4679,1362,Ã…GubbenHanFor
# 4784,1368,Ãmame
# 4823,1372,Ãˆâªã‹â®â¶â£ãÿã‹ãã¬
# 4824,1372,Ãœâ«ã‘ã´âµâºã‰ã
# 4825,1372,Â¼ã™ãˆã§ã„ã£ã’âªãˆããšâ¶ãžã’
# 4826,1372,Â¾ã¼â¸ã›ã–â®ã’â¹
# 4827,1372,Ã‡ã¥â³â¿â£â¬ãžã’ãƒã‡ãœâ¤ã‰ããâ¡âµã€
# 4828,1372,Ã€ã‹â»â¨ã€ã¯â·ã‰â³ã¶â»â¶ã€ã–âµã„â¸ã¨
# 4829,1372,Ã‹â¼ã„ã®
# 4830,1372,Ãã–ã–ãâµã„ãâ¡ã‚â·
# 4831,1372,Ãã§ãâµ
# 4832,1372,Ã„ã£âºãƒâ°â¡â£â¬ãâ¿â½â­
# 4833,1372,Ãã’â¸â£ã”ãšã„ã„ã€ã¯
# 4834,1372,Â½ã°â·ã§â´âµã€â´âµã„ãšâ±âºã²
# 4835,1372,Ã„ã‘ãã¼â½ã±ãã¼
# 5078,1391,(4)ã–ttermalspolskanAfterSkinnarAlbinLarsson
# 5092,1391,(18)guldmedaljvalsenEfterErikÃ…hl
# 5157,1395,Ã„ã®Ã±ã ã¬ã®ã£ã®Ã­ã¥ã¡ã
# 5158,1395,Ã‚ã¨ã°Ã‚ã¨ã°
# 5159,1395,Ãˆã§-ã¯ã®ã¤Ã±ã¢ã¥ã²Ã§ã ã°ã¿
# 5160,1395,Ã’ã³ã¬ã ã­
# 5161,1395,Ãžã¡ã°ã¿ã¤ã®ã¢ã ã¿
# 5162,1395,Ã‘ã¥ã°ã®ã£ã«ã ã§ã»ã©
# 5163,1395,Ã—ã¥ã°ã¥ã§Ã±ã ã¤ã¨ãª
# 5164,1395,Ãã®ã¤Ãšã¨ã¥ã¢ã®ã¬
# 5165,1395,Ãã ã¡ã¥ã°ã³Ã²ã°ã ã¢ã»
# 5166,1395,Ã‘ã¥ã±ã²ã°ã
# 5167,1395,Ãšã®ã«ã»ã¡ã¥ã«ã¼ã­ã ã¿
# 5168,1395,Ãœã ãª
# 5331,1409,Ãã®ã½ã²ã ã¬
# 5332,1409,Ãœã®ã©Ã¤ã°ã³ã£Ã³ã¥ãµã ã«Ã¢Ãœã ã£ã ã¤ã ã­...
# 5333,1409,Ãã¥ã±ã­ã¿Ã¬ã¨ãªã°ã®ã´ã®ã­ã
# 5334,1409,Ã—ã³ã¦ã ã¿Ãªã®ã«ã¥ã¿
# 5335,1409,Ãƒã®ã°ã¨ã§ã®ã­ã²
# 5336,1409,Ãã¥ã«ã®ã¥Ã¡ã¥ã§ã¬ã®ã«ã¢ã¨ã¥
# 5337,1409,Ãã ã«ã«ã ã¤ã Ã®Ãªã®ã°ã®ã²ãªã®ã©Ã¸ã¥ã¥
# 5338,1409,Ã˜ã²ã®ã°ã¬ã¨ã²Ã¢ã¥ã±ã¼Ã¢ã¥ã·ã¥ã°...
# 5339,1409,Ãã ã­ã¼ãªã Ã¯ã®-ã¡ã¥ã«ã®ã¬ã³
# 5340,1409,Ãã ã­ã¼ãªã Ã¯ã®-ã·ã¥ã°ã­ã®ã¬ã³
# 5341,1409,Ãžã¸ã¨ã¡ãªã Ã¢ã»ã¸ã«ã
# 5342,1409,Ãã¨ãªã ãªã®ã©Ã®ã¸ã¨ã¡ãªã¨
# 5343,1409,Ãˆã±ã²ã®ã°ã¨ã¿Ã¡ã®ã«ã¥ã§ã­ã¨
# 5379,1412,Ingratidã£o
# 5380,1412,Coraã§ã£oDeVioleiro
# 5382,1412,Fogã£oDeLenha
# 5395,1414,Alucinaã§ã£o
# 5541,1426,AgaclarAyaktaÃ–lã¼r
# 5550,1426,HastaneÃ–nã¼ndeIncirAgaci
# 5626,1433,Ã¯ã¥ã±ã¥ã­ãªã Ã¢ã¥ã±ã¥ã«ã®ã£ã®Ã­ã¨ã¹ã¥ã£ã®
# 5627,1433,Ã«ã»ã¦ã­ã ã¿Ã¯ã°ã®ã£ã³ã«ãªã
# 5628,1433,Ã¯ã°ã¨Ã¤ã¢ã®ã°ã¥
# 5629,1433,Ã®ãµã®ã²ã
# 5630,1433,Ã¢ã¨ã¤ã¥ã­ã¨ã¥Ã±ã¬ã¥ã°ã²ã¨
# 5631,1433,Ã¿-Ãµ
# 5633,1433,Ã¯ã®ã±ã«ã¥ã¤ã­ã¨ã©Ã³ã¦ã¨ã­
# 5634,1433,Ã¬ã¥ã¸ã®ãªÃ¨Ã­ã®ã¦
# 5635,1433,Ã¬ã¥ãµã ã­ã¨ã·ã¥ã±ãªã¨ã¥Ã°ã³ãªã¨
# 5636,1433,Ã±ã²ã°ã¨ã¯ã²ã¨ã§Ã¨ã¢ã®ã­ã­ã»
# 5638,1433,Ã¯ã®ã¤Ã¢ã®ã¤ã®ã©
# 5639,1433,Ã´ã¨ã­ã ã«
# 5642,1433,Ã¡ã®ã«ã¼ã¸ã¨ã¥Ã­ã®ã¦ãªã¨Ã­ã Ã¯ã°ã®ã£ã³ã«ãªã¥
# 5643,1433,Ã°ã¥ã¢ã¥ã°ã ã­ã±Â¹1
# 5644,1433,Ã¯ã¥ã±ã¥ã­ãªã Ã£ã ã§ã¥ã²ã­ã®ã£ã®Ã ã¢ã²ã®ã¬ã ã²ã
# 5645,1433,Ãªã«ã³ã¡ã®ãªÃ³ã¯ã ã«
# 5646,1433,Ã±ã¨ã¤ã¿Ã¯ã®ã¤Ã±ã²ã®ã«ã®ã¬
# 5647,1433,Ã¨ã¢ã®ã­ã­ã Ã¯ã°ã®ãµã®ã¤ã¨ã²Ã¬ã¨ã¬ã®
# 5648,1433,Ã¯ã°ã¥ã¤ã·ã³ã¢ã±ã²ã¢ã¨ã¥
# 5649,1433,Ã®ã²ã¯ã³ã±ãªã­ã»ã¥Ã±ã¢ã¨ã±ã²ã³ã­ã»
# 5650,1433,Ã§ã ãªã«ã¾ã·ã¨ã²ã¥ã«ã¼ã­ã»ã©Ã³ã¦ã¨ã­
# 5651,1433,Ã°ã¥ã¢ã¥ã°ã ã­ã±Â¹2
# 5652,1433,Ã¢ã ã«ã¼ã±Ã°ã»ã¡ã ãªã®ã¢
# 5653,1433,Ã¬ã¥ãµã ã­ã¨ã·ã¥ã±ãªã¨ã¥Ã°ã³ãªã¨
# 5694,1435,Â®ã¼â¬v
# 5695,1435,Â¶mâ·t
# 5696,1435,Â§ãšâ­ãœâ¬oâ¦pâ­m
# 5697,1435,Â¬ã¯â¤wâ±mâ­iâ¦ã§
# 5698,1435,Âªã¸â¦ã‘âªâºâ¥mã€{
# 5699,1435,Â¬gâ¶mâ´â¶â±yâºâ¿
# 5700,1435,Â«bâ»pâ§a
# 5701,1435,Â¤]â´â¿â·pã„â±
# 5703,1435,Â¨â«â¬â¡â¶ã‡â²ãž
# 5705,1435,Â¦â­â±ã¡âªâºâ±ãÿãã¸(live)
# 5735,1437,Samã¢`ã®
# 5736,1437,Taqsã®m`ã›d(qã¢driDã¢lal)
# 5737,1437,Mã»washshah(adhdhibã»ni)
# 5738,1437,Qasã®da(ra'aytu-l-hilã¢la)
# 5739,1437,Mã»washshah(tifYã¢Durrã®)
# 5740,1437,Mã»washshah(yã¢Ghazã¢l)
# 5741,1437,Mã»washshah(ilã¢hã®Yã¢Rahmã¢nYã¢Basã®r)
# 5743,1437,Mawwã¢l(hayyã¢kYaMekremEl-qessã¢dWeMwã¢li...
# 5745,1437,Dawr(yã¢Qalbã®Lãªh-Yã¢ManJafã¢WaManRa...
# 5746,1437,Mawwã¢lBayã¢tiMawzã»n
# 5951,1454,DaJeVisnjaÂ·Vranjanka
# 5956,1454,SelomIde...Â·OvoKolo
# 5959,1454,GajdaskoKoloÂ·Oj,SaviceÂ·MimikinoKolo
# 6335,1485,S'alâ·lotaMã©sGarridaDelMã³n
# 6343,1486,Ã£ã¢ã¬ã©
# 6344,1486,Ã¢ã£Ã¢ã¡ã¥ã¸Ã¶ã©ã©ã£
# 6345,1486,Ã¬ã´ã²ã®ã©ã­Ã·ã¥ã¸ã¤Ã¬ã©
# 6346,1486,Ã¤ã¹ã©ã¸Ã¹ã¬Ã£ã¥ã·ã¨ã¥ã¸Ã£ã¥ã·
# 6347,1486,Ãºã¸ã°ã¢ã¥ã¬ãºÃ«ã§ã¥ã¬ã¤
# 6348,1486,Ã ã®ã Ã¹ã¬ã©
# 6350,1486,Ã¡ã²ã¸ã¡Ã¹ã¬Ã±ãºã©ã¥
# 6351,1486,Ã¤ã©ã¬ã£ã¤Ã¤ã«ã©Ã©ã´ã¤Ã¡ã¢ã¯
# 6352,1486,Ã¤ã ã¶ã¡ã²ã¥ãºÃ¤ã¥ã¬ã«ã¥ãºÃ¬ã©ã¹ã¥ã¯
# 6478,1496,GraitManet/SexOpDeBoerderiã«
# 6512,1499,Kã„rleken>JennyÃ–lund&Candela
# 6513,1499,JagVã„ntatMã„ngaDagar>LasseStefanz
# 6514,1499,RingSã…Fã…rDuSvar>Streaplers
# 6515,1499,SomEnOstã„mdTon>BodilHovenlids
# 6516,1499,LivetsStoraGã…ta>MatzBladhs
# 6517,1499,VarjeMorgondag>Helene&Gã¤nget
# 6518,1499,MedDejVillJagLeva>Thorleifs
# 6519,1499,Ã¥retsSã…ng>Grã¶nwalls
# 6520,1499,Nã„staGã…ngDetBlirSommar>DriftersMedMar...
# 6521,1499,Ã„rDuEnsamDuSomJag>Sten&Stanley
# 6522,1499,UnderEken>ChristinaLindbergs
# 6523,1499,Vã…gaTroPã…Kã„rleken>Fernandoz
# 6578,1504,Sã£oJoã£oDoGonzagã£o
# 6580,1504,VocãªEndoideceuMeuCoraã§ã£o
# 6587,1504,Baiã£oDaRua
# 6591,1505,Streaplers/Ã„nglasjã¤l
# 6597,1505,MatsBergmans/MinEgenÃ„ngal
# 6599,1505,ThorGjã¸rans/Ã„lskarDuMig
# 6600,1505,Thorleifs/AttGlã¶mmaÃ„rInteSã¥Enkelt
# 6602,1506,Ãã®ã©ã¤ã¥ã¬ÃªÃ¢ã®ã±ãªã°ã¥ã±ã¥ã­ã¨ã¾
# 6603,1506,\ã‘ã²ã¨ãµã¨ã°ã \.\ã‘ã«ã ã¢ã Ã¢ã»ã¸ã­ã¨ãµÃ¡ã®...
# 6604,1506,\ãã«ã ã£ã®ã±ã«ã®ã¢ã¨Ã¤ã³ã¸ã¥\
# 6605,1506,\ãã«ã ã¦ã¥ã­Ã¬ã³ã¦\
# 6606,1506,\ã‘ã¢ã¥ã²ã¨Ã²ã¨ãµã¨ã©\
# 6607,1506,\ãžã²Ã¾ã­ã®ã±ã²ã¨Ã¬ã®ã¥ã¿\
# 6608,1506,\ã•ã¥ã°ã³ã¢ã¨ã¬ã±ãªã ã¿\
# 6609,1506,\ãžã²ã·ã¥Ã­ã ã¸\
# 6610,1506,\ã„ã Ã¨ã±ã¯ã°ã ã¢ã¨ã²ã±ã¿Ã¬ã®ã«ã¨ã²ã¢ã \
# 6611,1506,\ã‚ã®ã±ãªã°ã¥ã±ã¥ã­ã¨ã¥Ã²ã¢ã®ã¥\
# 6612,1506,Ãˆã°ã¬ã ã±ã»Ãã ã±ãµã¨Ã‚ã¥ã¤ã¥ã«ã¼
# 6613,1506,\ã‡ã¥ã¬ã«ã¥Ãã³ã±ã±ãªã ã¿\.\ãã«ã ã¦ã¥ã­ã¨Ã¬...
# 6614,1506,\ãœã­ã®ã£ã ã¿Ã«ã¥ã²ã \
# 6654,1510,Ã©â­â€ã§â€°â©
# 6657,1510,LiosÃ¯â¼å HereÃ¯â¼å Pleades
# 6659,1510,Ã¦å“ë†ã£?â®ã¨?â€¢
# 6662,1510,Ã¨?â€“ã£?âªã£â€šâ€¹ã£?â€¹ã£?âª
# 6663,1510,Ã¥â·â¦ã£?â®ã¨â‚¬â³ã£?â®ã£?å¸ã£â€š?ã£?â®ã¥â€“å“ã...
# 6667,1511,Adoraã§ã£o
# 6672,1511,Varã£oDeFogo
# 6717,1515,Â³ã«â·â¡ã‡ãâ´ã‚Ã€ãœã€â¯
# 6718,1515,Â¿â¹!Ãã–â´ã”
# 6719,1515,Â³âªã€ã‡Â»ã®ã€â»Âºãžâ¸â£â½ã…Ãã–
# 6720,1515,Â¿ã¬â¸â®â´ã‚Â±âºâ»ã§
# 6721,1515,Â³âªâ´ã‚Ã€ãšã€â¯ã‡ã˜
# 6722,1515,Â³â¯Â¸â¸âµã¥â¼ã’â¼â­Â¸ãžâµã©â¸â®
# 6723,1515,Â¿ã¬â¸â®â´ã‚Ã‚ã¹â¾ã§ã‡ãâ´ã‚Â¹ã©â¼âº
# 6724,1515,Â»ã§â¶ã»ã‡ã’Ã€ãœã€â¯
# 6725,1515,Â±ã¢âµâµã€ã‡Â´ã‰â·ã‚
# 6726,1515,Ã‡ã‘Â»ã§â¶ã·
# 6727,1515,Ãã–Â»ã§â¼ãœâ³ã—
# 6728,1515,Ã€ãš,Âºâ¹ã€â½Âµã©â°ã­Â¼â¼â»ã³ã€â¸â·ãž
# 6894,1527,Â°eâ§ãšâ¤@â¦â·âªâ´âºã€âªã¡
# 6895,1527,Â¥â´â°_â¤ã¢â¹âªâ°ã›â°_âºq
# 6896,1527,Âªã¼â©ã”â¤ã¬â¦â½
# 6897,1527,Â¹fâªoâ«â°âªâºâ©hâ®q
# 6898,1527,Â±ãˆâ°_â§aâªâºã€yâ»\â¨ã“
# 6899,1527,Â·sãƒâ¦â¦n
# 6900,1527,Ãƒhâ©ã€â¾ã”â¤ã
# 6901,1527,Â°â¨â¨ãœâ©ã”
# 6902,1527,Â¦bâ»ãˆâ¦ã¢âªâºâ¤ã«â¥ãºâ¤u
# 6903,1527,Âªã¡â¨ã â¬â°â¤â°â»ã²â³oâ¼ã‹â¬ãµ
# 6904,1527,Â¬ã¼ã„râªâºâ©hâ®q
# 6905,1527,Â¯ã³â­ã¬â¤â§â©]
# 6906,1527,Â¥bâ­ã“â¤ã«â«gâ¥â¶â¤wâ¨ã“
# 6907,1527,Â¦bâ¨âºâ»â»â»â·âªâºâ¦aâ¤ã¨
# 7099,1543,Ãã°ã®ã«ã®ã£
# 7100,1543,Ãã°ã®Ã£ã°ã®ã¡ã®ã¢ã¹ã¨ãªã
# 7101,1543,Ãã°ã®Ã¦ã¥ã­ã¹ã¨ã­
# 7102,1543,Ãã°ã®Ã²ã¥ã°ã¥ã¬ã®ãª
# 7103,1543,Ãã°ã®Ã¢ã®ã°ã®ã¡ã¼ã¿Ã¨Ãªã®ã¡ã»ã«ã³
# 7104,1543,Ãã°ã®Ã¡ã³ã«ã¼ã²ã¥ã°ã¼ã¥ã°ã®ã¢
# 7105,1543,Ãã°ã®Ãã®ã±ã±ã¨ã¾
# 7106,1543,Ãã°ã®Ã¬ã¥ã²ã°ã®
# 7107,1543,Ãã°ã®Ã«ã¾ã¡ã®ã¢ã¼
# 7108,1543,Ãã°ã®Ãªã«ã¾ã·ã¨ãªÃ§ã®ã«ã®ã²ã®ã©
# 7109,1543,Ãã°ã®ã±ã²ã®Ã±ã®ã¢ã¥ã²ã»
# 7110,1543,Ãã®ã­ã³ã±
# 7137,1546,MindenIdãµk
# 7148,1546,MindenIdãµk
# 7322,1560,Ã‘ã ã«ã¬ã
# 7323,1560,Ã‚ã®ã²Ã¬ã»Ãªã ãªã¨ã¥
# 7324,1560,Ã’ã ã­ã¥ã¶Ã”ã«ã ã¬ã¥ã­ãªã®
# 7325,1560,Ãã®ã¶ã¥ã«ã³ã©
# 7326,1560,Ãœã ã°ã¨ã¿
# 7327,1560,Ãžã©,Ã¬ã ã¬ã ,Ã¸ã¨ãªã Ã¤ã ã¬
# 7328,1560,Ã˜ã¥ã«ãªã®ã¢ã ã¿Ã­ã¨ã²ã¼
# 7329,1560,Ã—ã¥ã¬ã¯ã¨ã®ã­
# 7330,1560,Ãã²ã®Ã«ã¥ã²ã®
# 7331,1560,Ãã¥ã¢ã­ã®ã±ã²ã¼
# 7332,1560,Ãžã²Ã«ã¾ã¡ã¢ã¨Ã¯ã®ã¢ã®ã°ã®ã²
# 7333,1560,Ã’ã»Ã±ã®Ã¬ã­ã®ã©
# 7334,1560,Ã„ã¨ã¢ã
# 8318,1635,IntiÃ‘an(caminoAlSol)
# 8547,1653,Various/ÃguaDeCheiro
# 8551,1653,Various/EscreveuNã£oLeu,OPalcoÃ©Meu
# 8642,1660,Ã‡ã âºâ¹ã€ã‡Â³âªâ¶ã³â·ãž
# 8643,1660,Â±ã¢ã…â¸ã‡ãâ³âªÂµâ¿ã€ã¼ã‡ã‘â´ã˜
# 8644,1660,Â²ãžã€ã‡Â´ã«ãˆâ­
# 8645,1660,Â¸ã±ãˆâ­â¹ã§
# 8646,1660,Â±ã—â¸â®â¿ã²â¸â¸Â½ã—ã€ãœâ³ã—
# 8647,1660,Â¿â¬ã€ãžã€ãœâ¿â©
# 8648,1660,Â»ãªâ»ã§â¶ã·
# 8649,1660,Â»ã¯ã†ã·â·ãžÂ°â¡â´ã‚Â±ã¦
# 8650,1660,Ã‡ãâ¾ã¡Â³âªâºã±
# 8651,1660,Â¹â°â¾ãˆâ°â³
# 8652,1660,Â¼ã–â°â³
# 8653,1660,Â¾ã®âµã°â¼â­Â¹â«â¾ã¹ã€ãœÂµã‡â¾ã®Â´ã™â½ãƒÂ¸â...
# 8654,1660,Â»ã§â¶ã»ã€â¸â·ãž
# 8760,1669,Capitã£oDaMeia-noite
# 9077,1689,Â¸ã«ã¡Ã³ã´ã¯ã­Ã°ã¡ã°ã¯ã½
# 9078,1689,Ãˆãã«ã¥ã©ã²Ã¬ã°ã¯ãµã¦ã¯ã½ãªã©ã¡Ã°ãœã¬ã¥
# 9079,1689,Ã”ã¼ã³ã¡Ã·ã±ã¼ã­ã©ã¡Ã³ã¡ã­Ã´ãµã¶ã«ã¼ã²
# 9080,1689,Ãã­ãã¢ã¡Ã³ã´ã¯Ã´ã±ã¡ã°ãã¦ã©Ã¬ã¯ãµ
# 9081,1689,Ã„ã¥ã­Ã¨ãã«ã¹Ã­ã¡Ãªã«ã¡ãÿã²
# 9082,1689,Ãˆã¡Ã¥ãÿã¬ã¡ã³ã´ã¥Ã¬ã¡ã¦ãÿ
# 9083,1689,Ã„ã¥ã­Ã°ã¡Ã­ã¡Ã£ã¡
# 9084,1689,Ãã´ã©ã«ã¡ãºã«ã¡
# 9085,1689,Ãã±ã¯ã³ã¥ãµã·ãž
# 9086,1689,Â¼ã´ã¡ã­Ã·ã¯ã±ã¥ã½ã¥ã©ã²Ã¬ãœã´ã©ã¡Ã¬ã¯ãµ
# 9087,1689,Ã…ã³ã½Ã¶ã´ã¡ãÿã²
# 9088,1689,Ãã¹Ã°ã¹Ãã­ã¡Ã¬ã¡ã­ãœã±
# 9093,1690,Ã–lbackensPolska
# 9209,1698,ÃÿÃã¥Ãã³ã¤ã³Ã†ã¤ã ã²ã¼Ã’ã¥ã¡ã¿Ãã Ãã¥ã...
# 9210,1698,Ã‚Ãã®ã±ã«ã¥ã¤ã­ã¨ã©Ãã ã§
# 9211,1698,Ãã¼ã¿ã­ã ã¿Ã‚ã¨ã¸ã­ã¿
# 9212,1698,Ãÿ,Ãœã®ã±ãªã®ã¢ã±ãªã¨ã©Ãžã§ã®ã°ã­ã®ã©Ãƒã³ã«ã...
# 9213,1698,Ã€ãµ,Ãã²ã®Ãã»ã«ã®...
# 9214,1698,Ã„ã»ã¬Ãšã®ã«ã¼ã¶ã ã¬ã¨
# 9215,1698,Ã“ã«ã¨ã¶ã Ãã ã§ã¡ã¨ã²ã»ãµÃ”ã®ã­ã ã°ã¥ã©
# 9216,1698,Ã‡ã ã©ã·ã¨ãª
# 9217,1698,Ã‘ã ã¬ã®ã«ã¥ã²
# 9218,1698,Ã‡ã Ã’ã³ã¬ã ã­ã ã¬ã¨
# 9219,1698,Ã€ÃÿÃã ã«ã¼ã¾Ã‘ã¥ã¡ã¥Ã‚ã¨ã­ã
# 9220,1698,Ã„ã¥ã¬ã®-ãœã¨ãªã±Ã€ã«ã¼ã¡ã®ã¬ã Ãˆ.Ã‘ã«ã³ã¶ãª...
# 9282,1703,EsSchreitNachZã„rtlichkeit
# 9284,1703,AufEinerWolkeMã–chtIchFliegen
# 9285,1703,InselDerTrã„ume
# 9315,1706,Ã¥â®â€°ã¥â¿æ’
# 9316,1706,Ã£?â¨ã£?â€¹ã£?â€™
# 9317,1706,Ã£â€šâ«ã£æ’å“ã£æ’?ã£æ’â£
# 9318,1706,Ã¥â¤â¢ã£?â®ã¤â¸â­ã£?â®ã¥?â€º
# 9319,1706,Ã¥â­â¦ã§â¿â€™
# 9320,1706,Ã£æ’?ã£æ’â‚¬ã£â€šâ·ã£?â®ã¨â¶â³ã©å¸â³
# 9321,1706,Ã¥â°?ã¨â±â¡ã£?â®ã£æ’â»ã£æ’â»ã£æ’â»
# 9322,1706,Ã£?â€žã£â€š?ã£?â€”ã£?â®ã£?â€œã£â€šâ€šã£â€šå ã£?...
# 9323,1706,Ã£?â€¢ã£â€šë†ã£?âªã£â€šâ€°ã£?å ã£?â²ã£?â€¢ã£?â¾
# 9324,1706,Ã£æ’â©ã£æ’æ’ã£â€šâ¿ã£æ’æ’ã£â€šâ¿
# 9325,1706,Ã£â‚¬å’ã¥â¤?ã£?â§ã£?â„¢ã£â‚¬?ã£?â¨1ã¥â€ºå¾ã¨â¨â...
# 9326,1706,Ã£â€šâ€ ã£â€š?ã£?â¿ã£?â¦ã£?â€žã£â€šâ€¹ã£â€šë†
# 9616,1727,Ã…hHvorJeg,IhHvorJeg,UhHvorJegVil
# 9842,1744,03-Ã–ruggtSkjã³l
# 9960,1753,Ã¥â¼â§ã¥â€¹â€¢
# 9961,1753,Ã¨â¨ëœã¦â€ â¶
# 9963,1753,Ã£â€šâ¤ã£æ’â«ã£â€šâ«
# 9965,1753,Ã¦â€°â€¹ã£?â®ã£?â²ã£â€šâ€°ã£â€šâ€™ã¥â¤âªã©â„¢â½...
# 9968,1753,Ã¥?â€ºã£?â«ã¤â¼å¡ã£?â€žã£?â«
# 9971,1753,Ã¨â¨ëœã¦â€ â¶(acousticVersion)
# ...
# 122033,10210,Ã£?â€šã£?â€žã£?â€œã£?â¨ã£?â°ã£?â¯Be!!
# 122034,10210,Ã¦ë†â€˜ã£?â¯ã£æ’â­ã£æ’å“ã£æ’æ’ã£æ’ë†
# 122035,10210,Ã¦ëœå¸ã§â©âºã£?â®ã£â€šâ»ã£æ’â³ã£æ’?ã£æ’â¡ã£æ’â³...
# 122037,10210,Ã£æ’â€˜ã£â€šâ¹ã£æ’â€ ã£æ’â«ã£?â¨ã£æ’â¯ã£æ’â«ã£æ...
# 122129,10215,Â±â¯ã‡ã©â³ã‡ãšã
# 122130,10215,Ãã‚â²â»ãã‹ã‡ã©
# 122131,10215,Â¹ã°â»â¨ãã¯
# 122132,10215,Ã—â·ãƒãžãˆã‹
# 122133,10215,Ãƒâµâ¹ã¥ãã£
# 122134,10215,Ã”ã¡ãã„
# 122135,10215,Ã—ã®â°â®
# 122136,10215,Â²ã—âºâ£ã’â»ã‰ã¹ãâ¦
# 122137,10215,Ã€ã¨ãƒã·â²â»ã’âªã€â´
# 122138,10215,Âµâ±â°â®ã’ã‘â³ã‰ãã¹ãšã‚
# 122139,10215,Â¹ã¶â¹ã¶âºã¬â³â¾
# 122140,10215,Ã‰â·ãâ·
# 122404,10235,Â°â¨â¸ã´â­^â¶â¯
# 122405,10235,Medley:(â±â¡â¤wâ³u/ã‚ã…â«b/â·râ±oâ¤ã±â§aâ²`/ã€...
# 122406,10235,Â¤ã«â¥bã…s
# 122407,10235,Â¨ã“â¨ã“â¦^â¦^
# 122410,10235,Ã€yâ¾vâ¶ãƒâ¤f
# 122411,10235,Â¯uâ±â¡â¬yã…s
# 122413,10235,Â·râ¬oâ¥ãƒâ«ã­
# 122496,10241,Ã£æ’å¾ã£â€šâ¯ã£æ’â­ã£â€šâ¹
# 122497,10241,Ã©?â€¹ã¥â€˜â½ã£?â®ã§å¸â¢
# 122498,10241,Ã¦â¶â„¢ã£?â®ã£æ’?ã£â€šâ¤ã£â€šâªã£æ’âªã£æ’â³
# 122499,10241,Ã¥â°?ã§â„¢â½ã§â«å“
# 122500,10241,Ã¦â€šâ²ã£?â€”ã£?â¿ã£?â®ã£æ’â¡ã£æ’â­ã£æ’â€¡ã£â€š...
# 122501,10241,Ã¥â¾â€¦ã£?â¡ã¤â¼?ã£?â€º
# 122502,10241,Ã£?â€šã£æ’â»ã£?â€œã£æ’â»ã£?å’ã£æ’â»ã£â€šå’
# 122503,10241,Ã¥?âµã¥â¯å¸
# 122504,10241,Ã©â‚¬â²ã¥â®â„¢ã¥â¼?
# 122505,10241,Ã¦â€žâ€ºã£?â¯ã¦âµ?ã£â€šå’ã£â€šâ€¹
# 122506,10241,Ã£æ’â€°ã£æ’æ’ã£â€šâ°ã£æ’â»ã£æ’â€¢ã£â€šâ¡ã£â€šâ¤...
# 122507,10241,Ã£â€šâ·ã£æ’â«ã£æ’?ã£æ’â¼ã£æ’â ã£æ’â¼ã£æ’â³ã£æ’â...
# 122508,10241,Ã£æ’â€œã£æ’?ã¯â¼?ã£â€šâ¼ã£æ’â³ã£æ’ë†ã£æ’â©ã£æ’â...
# 122509,10241,Ã¦â€šâ²ã£?â€”ã£??ã¥â®â€¡ã¥â®â„¢ã¥â€¦âµ
# 122510,10241,Ã§â·?ã¦â€â»ã¦â€™æ’
# 122511,10241,Ã¥â¹â¼ã¥â¹â´ã¦å“å¸ã£?â®ã§âµâ€šã£â€š?ã£â€šå
# 122513,10241,Ã£â€šâ¢ã£â€šâ¯ã£â€šâ·ã£æ’â§ã£æ’â³
# 122514,10241,Ã¦â€”â€¦ã§â«â€¹ã£?â¡
# 122515,10241,Ã£æ’â©ã£æ’â³ã£æ’å ã£æ’â¼
# 122516,10241,Ã§å¾â€˜ã¦æ’â³
# 122517,10241,Ã£æ’â¦ã£æ’â€¹ã£æ’?ã£æ’â¼ã£â€šâ¹
# 122519,10241,Ã§â§?ã£?â®ã¥â½â¼ã£?â¯ã£æ’â€˜ã£â€šâ¤ã£æ’â­ã£æ’æ’...
# 122520,10241,Ã©?â€™ã¦ëœâ¥ã£?â®ã¨â¡â€”ã¨â§â€™
# 122521,10241,Ã£â€šâ¹ã£æ’å¡ã£â€šâ¯ã£â€šâ¿ã£æ’â«
# 122522,10241,Ã£â€šâ¼ã£æ’â³ã£æ’ë†ã£æ’â©ã£æ’â€¡ã£â€šâ£ã£â€šâ¢ã...
# 122523,10241,Ã£æ’â‚¬ã£æ’â¼ã£æ’â€ ã£â€šâ£ã£æ’â¼ã£æ’â»ã£æ’â€™ã...
# 122524,10241,Ã¥â€šâ·
# 122525,10241,Ã£æ’å½ã£â€šâ¹ã£â€šâ¿ã£æ’â«ã£â€šâ¸ã£â€šâ¢
# 122526,10241,Ã£æ’â¡ã£æ’â­ã£æ’â€¡ã£â€šâ£ã£â€šâ¢ã£â€šâ¹ã£æ’â»ã...
# 122527,10241,Ã£â€šâ¹ã£â€šâ¿ã£æ’â¼ã£æ’â‚¬ã£â€šâ¹ã£æ’ë†ã£æ’â»ã...
# 122528,10241,Ã£â€šâ€žã£?â€¢ã£?â€”ã£?â€¢sayonara
# 122530,10241,Ã£â€šâ«ã£æ’â¼ã£æ’â€¹ã£æ’?ã£æ’â«
# 122531,10241,Ã£æ’â€˜ã£æ’æ’ã£â€šâ·ã£æ’â§ã£æ’â³ã£â‚¬â€š
# 122532,10241,Ã¥â¾â©ã¨ë†ë†ã£?â®ã£?â²ã£?â³ã£??
# 122533,10241,Ã¦â½å“ã¨â¡å’
# 122534,10241,Ã£æ’â€¢ã£â€šâ¡ã£æ’â¼ã£â€šâ¹ã£æ’ë†ã£æ’â»ã£â€šâ³ã...
# 122535,10241,Ã£æ’â©ã£æ’â©ã£æ’?ã£â€šâ¤
# 122536,10241,Ã©?ëœã£?â®ã£?â€šã£â€šâ€¹ã©â¢â¨ã¦â„¢â¯
# 122537,10241,Ã¦å“â€ºã©æ’â·
# 122538,10241,Ã£æ’â­ã£æ’â³ã£â€šâ°ã£æ’â»ã£æ’â€¢ã£â€šâ©ã£æ’â¼
# 122539,10241,Ã¦â²ë†ã§â€”â€º
# 122540,10241,Ã£æ’å¾ã£â€šâ¤ã£æ’â»ã£æ’â€œã£æ’â¥ã£æ’â¼ã£æ’â€ ã£...
# 122541,10242,Ãƒã®ã°ã®ã¤,Ãªã®ã²ã®ã°ã®ã£ã®Ã­ã¥ã²
# 122542,10242,Ã—ã³ã¦ã®ã©
# 122543,10242,Ã’ã¥ã¬ã Ã€ã¤ã¢ã®ãªã ã²ã -Ã½ã¯ã¨ã§ã®ã¤7(ã‘ã...
# 122544,10242,Ã’ã¥ã¬ã Ã€ã­ã²ã¨ã¡ã¨ã®ã²ã¨ãªã Ã­ã Ã²ã¨ã²ã°ã»
# 122545,10242,Ã†ã³ã°ã­ã ã«ã¨ã±ã²-Ã­ã ã·ã ã«ã¼ã­ã»ã¥Ã²ã¨ã²ã°ã»
# 122546,10242,Ã€ã¤ã¢ã®ãªã ã²-Ã½ã¯ã¨ã§ã®ã¤6(ã—ã¥ã«ã¨ã¹ã¥ã¢...
# 122547,10242,Ã€ã¤ã¢ã®ãªã ã²-Ã½ã¯ã¨ã§ã®ã¤5(ãšã ã²ã¿Ã¨Ã‘...
# 122548,10242,Ãã ã­ã¤ã¨ã²ã»-Ã½ã¯ã¨ã§ã®ã¤2
# 122549,10242,Ã€ã¤ã¢ã®ãªã ã²-Ã½ã¯ã¨ã§ã®ã¤3
# 122550,10242,Ã’ã¥ã¬ã Ã°ã ã§ã¤ã³ã¬ã¨ã©Ã—ã¥ã«ã¨ã¹ã¥ã¢ã
# 122551,10242,Ãã°ã®ã¹ã ã­ã¨ã¥Ã‘ã¥ã°ã¥ã£ã¨ã­ã Ã¢Ã‘ã²ã®ãªã£...
# 122552,10242,Ãã¥ãªã¢ã¨ã¥ã¬
# 122553,10242,Ãã ã­ã¤ã¨ã²ã»-Ã½ã¯ã¨ã§ã®ã¤7
# 122554,10242,Ã€ã¤ã¢ã®ãªã ã²-Ã½ã¯ã¨ã§ã®ã¤1
# 122555,10242,Ã„ã°ã³ã§ã¼ã¿(ã—ã¥ã«ã¨ã¹ã¥ã¢Ã¢Ã¤ã¥ã²ã±ã²ã¢ã¥)
# 122556,10242,Ã„ã°ã³ã§ã¼ã¿(ã—ã¥ã«ã¨ã¹ã¥ã¢Ã¨Ã‡ã¢ã ã­ã¶ã¥ã¢...
# 122557,10242,Ãšã°ã¨ã¬ã¨ã­ã ã«
# 122558,10242,Ã€ã­ã²ã¨ã¡ã¨ã®ã²ã¨ãª
# 122559,10242,Ã‚ã±ã²ã°ã¥ã·ã (ã‘ã¥ã°ã¥ã£ã¨ã­Ã¨Ãã ãµã¨ã«ã¼)
# 122560,10242,Ã†ã³ã°ã­ã ã«ã¨ã±ã²(ã‘ã¥ã°ã¥ã£ã¨ã­Ã¢Ã ã¢ã²ã®ã...
# 122561,10242,Ãã ã­ã¤ã¨ã²ã»-Ã½ã¯ã¨ã§ã®ã¤1(ã‹ã¥ã£ãªã®ã¬ã»...
# 122562,10242,Ã‘ã¥ã°ã¥ã£ã¨ã­Ã¤ã³ã¬ã ã¥ã²
# 122563,10242,Ã‘ã«ã¥ã¦ãªã Ã§ã Ãªã¨ã«ã«ã¥ã°ã®ã¬
# 122564,10242,Ã€ã¤ã¢ã®ãªã ã²-Ã½ã¯ã¨ã§ã®ã¤4(ã‘ãªã°ã¨ã¯ãªã¨...
# 122565,10242,Ãã®ã£ã®ã­ã¿
# 122566,10242,Ã’ã°ã¥ã¢ã®ã£ã Ã¢Ã‘ã²ã®ãªã£ã®ã«ã¼ã¬ã¥
# 122567,10242,Ãƒã®ã°ã®ã¤Ã§ã Ã®ãªã­ã®ã¬
# 122568,10242,Ãœã ã«ã¼ã·ã¨ãª,Ã­ã¥ã¯ã®ãµã®ã¦ã¨ã©Ã­ã Ã¬ã¥ã­ã¿
# 122690,10252,<3ãƒâ€”3ã¥??ã¤â½å“ã¥å â€¡ã¥â â´>Ã§â„¢â½ã©â€ºâª...
# 122691,10252,Ã¥â®ë†ã£?â£ã£?â¦ã£?â€šã£?â€™ã£â€šâ€¹
# 122692,10252,<3ãƒâ€”3ã¥??ã¤â½å“ã¥å â€¡ã¥â â´>Ã£æ’â€˜ã£â€šâ¤...
# 122693,10252,NightStory<ã¤â¸â­ã¦?â€˜Version>
# 122694,10252,<3ãƒâ€”3ã¥??ã¤â½å“ã¥å â€¡ã¥â â´>Ã£â€šâ·ã£æ’â³ã...
# 122696,10252,<3ãƒâ€”3ã¥??ã¤â½å“ã¥å â€¡ã¥â â´>Ã£â€šâ¢ã£æ’â«ã...
# 122697,10252,Ã©â¢â¨ã£â€šâ€™ã£?â¤ã£?â€¹ã£?â¾ã£?ë†ã£?â¦
# 122698,10252,<bgm>Ã¥?å’ã§â´å¡ã§â€å¸
# 122699,10252,<bgm>Ã¥â¦â€“ã©â­â€
# 122700,10252,<bgm>Ã¥â€¦â«ã©â€ºâ²
# 122930,10269,Ã“ã¢ã¥ã°ã²ã¾ã°ã
# 122931,10269,Ã‘ã¾ã§ã ã­ã­-Ã”ã¨ã«ã¨ã¯ã¯Ãšã¨ã°ãªã®ã°ã®ã¢
# 122932,10269,Ã€ã°ã¨ã®ã§ã®Ã”ã¨ã£ã ã°ã®-Ãã®ã°ã¨ã±Ã•ã¢ã®ã¸...
# 122933,10269,Ã€ã°ã¨ã¿Ã”ã ã­ã¸ã¥ã²ã²ã»-Ã€ã­ã¨Ã‹ã®ã°ã ãª
# 122934,10269,Ãšã®ã¢ã ã°ã­ã»ã¥Ã¬ã³ã¦ã¨ãªã¨-Ã‘ã®ã´ã¨ã¿Ãã®...
# 122935,10269,Ãã³,Ã¯ã®ã·ã¥ã¬ã³Ã­ã¥ã«ã¼ã§ã¿-Ã‹ã®ã«ã¨ã²ã ...
# 122936,10269,Ãƒã³ã±ã¥ã¢
# 122937,10269,Ãã®ã¬ã ã­ã±Ãšã¥ã°ã³ã¡ã¨ã­ã®-Ã€ã­ã¤ã°ã¥ã©Ã„...
# 122938,10269,Ãœã³ã¦ã·ã¨ã­ã»Ã«ã¾ã¡ã¿ã²Ã­ã ã±Ã­ã¥ã¬ã­ã®ã£ã®...
# 122939,10269,Ãšã°ã»ã¦ã®ã¢ã­ã¨ãª-Ãã®ã°ã¨ã±Ãœã®ã¨ã±ã¥ã¥ã¢
# 122940,10269,Ãœã®ã°ãªã®ã¢ã¼-Ã€ã­ã ã±ã²ã ã±ã¨ã¿Ã‘ã²ã®ã¶ãªã...
# 122941,10269,Ã¢,Ã‹ã®ã«ã¨ã²ã Ãœã¨ã«ã¿ã¢ã±ãªã ã¿
# 122942,10269,Ã€ã°ã¨ã¿Ã‘ã¾ã§ã ã­ã­ã»-Ã€ã­ã ã±ã²ã ã±ã¨ã¿Ã‘...
# 122943,10269,Ãã Ã§ã¥ã¬ã«ã¥-Ã¯ã®-ã¯ã°ã¥ã¦ã­ã¥ã¬ã³Ã¢ã®ã¤ã...
# 122944,10269,Ã‚ã®ã¤ã¥ã¢ã¨ã«ã¼
# 122946,10270,Seleã§ã£oDeSucessos-BethCarvalho
# 122947,10270,Natureza-LeciBrandã£o
# 122953,10270,Auto-estima-LeciBrandã£o
# 122956,10270,Forã§aDaImaginaã§ã£o-YvoneDeLara
# 123024,10276,Nrcunderground/Ã¦â®â€¹ã¥â€¦â€°ã£â‚¬å“g-typeã£â...
# 123025,10276,Nepia/Ã¥â€ºå¾ã¦æ’â³ã©å’â²-ã£?â¼ã£?â£ã£?â€¢-[...
# 123026,10276,Nepia/Ã¦â­â¤ã¥â€¡â¦-ã£?â¡ã£â€šâ€¡ã£?â€œã£?â£ã...
# 123027,10276,FuzukiChihaya/Reincarnation[air]Ã¥â·?-river-
# 123028,10276,FuzukiChihaya/WinterVacation[kanon]Ã¥â€ â¬ã...
# 123029,10276,InitialY/2ndContact-deadMoonNight-[air]ã¯...
# 123197,10287,Â¼â­â¿âµã€âº/Â»ã§â¶ã»ã‡ãâ´ã‚Â³â¯â¿â¡
# 123198,10287,Â±ã¨â´ã«ãˆâ«/Â½ãƒâ³ã±â½ãƒâ½âº
# 123201,10287,Â±ã¨â´ã«ãˆâ«/Ããÿâ¾ã“â¼â±â¿â¡â¼â­
# 123202,10287,Â±ã¨â´ã«ãˆâ«/Â±ã—â¿â¡â°ã”
# 123204,10287,Â±ã¨â´ã«ãˆâ«/Â±ã—â¸â²Â¼ã“ã€â¸â·ãž
# 123205,10287,Â±ã¨â´ã«ãˆâ«/Â°ãºãƒâµÂ°â¡â´ã‚Â±ã¦
# 123206,10287,Â±ã¨â¾ã§ãˆã±/SheIs...
# 123207,10287,Â±ã¨â´ã«ãˆâ«/Â»ã§â¶ã»ã€ã‡Ã€ãžâ»ã§
# 123208,10287,EdwardElgar/Â¹ãœâ¼ãºâ°ã¼Â¿â·Âµâ¿â¹â°â¿ã¸
# 123209,10287,Â±ã¨â´ã«ãˆâ«/Âµâ¿â¹â°Âºâ´â¿ã¸
# 123331,10296,Â±ã¨Â´ã«ãˆâ«/Â»ã§â¶ã»ã‡ãâ´ã‚Â³â¯â¿â¡
# 123332,10296,Â±ã¨Â´ã«ãˆâ«/Â½ãƒâ³ã´â½ãƒâ½âº
# 123333,10296,Â±ã¨Â´ã«ãˆâ«/SheIs...One
# 123334,10296,Â±ã¨Â´ã«ãˆâ«/Â¾ã—ã€ãšâ¼ã“Â¼â¼â»ã³
# 123335,10296,Â±ã¨Â¾ã§ãˆã±/Â°ãºãƒâµâ°â¡â´ã‚Â±ã¦
# 123336,10296,Â±ã¨Â¾ã§ãˆã±/Â»ã§â¶ã»ã€ã‡Ã€ãžâ»ã§((edward...
# 123337,10296,Â±ã¨Â´ã«ãˆâ«/SheIs...Two
# 123338,10296,Â±ã¨Â´ã«ãˆâ«/Â±ã—â¸â²â¼ã“Ã€â¸â·ãž
# 123339,10296,Â±ã¨Â´ã«ãˆâ«/Â¹ãœâ¼ãºâ°ã¼â¿â·Âµâ¿â¹â°â¿ã¸
# 123340,10296,Â±ã¨Â´ã«ãˆâ«/Â±ã›â¿â¡â°ã”
# 123341,10296,Â±ã¨Â´ã«ãˆâ«/Ããÿâ¾ã“â¼â±â¿â¡â¼â­
# 123342,10296,Â±ã¨Â¾ã§ãˆã±/TheTeaTime
# 123343,10296,Â±ã¨Â´ã«ãˆâ«/Âµâ¿â¹â°âºâ´â¿ã¸
# 123344,10296,Â±ã¨Â´ã«ãˆâ«/Â»ã§â¶ã»ã‡ãâ´ã‚Â³â¯â¿â¡(with...
# 123397,10301,Ãœã°ã±ã¡ã¦ã©ã«ãã±ã¯
# 123398,10301,Ãˆãœã«ã¡ã³ã³ã¡Ã¬ã¯ãµÃ³ãªã¯ã´ã¥ã©ã­ãž
# 123399,10301,Â¸ã¶ã¯ã¤ã¯ã²
# 123400,10301,Ã”ã©Ã«ã¥ãÿã°ã¥ã©
# 123401,10301,Ã—ãœã¤ã©
# 123402,10301,Ã‹ã¡ã¨ã±ã¯ã¬ã¥ã´ã¡ã­ãœã³ã´ã¥ã²
# 123403,10301,Ã„ã¥ã­Ã¥ãÿã­'Ã¡ã±ã£ãœ
# 123404,10301,Ãã¡ã¦ãœã±ã©
# 123405,10301,Ãƒãžã°ã¥ã¤ã¯
# 123406,10301,Â¢ã¤ã¥ã©ã¯Ã³ã°ãÿã´ã©
# 123407,10301,Ã”ã±ãã·ã¹,ã´ã±ãã·ã¹,ã´ã±ãã·ã¹
# 123408,10301,Ãšã¡ã«ã¡ã¬ã©ãã²
# 123409,10301,Ã‡Ã£ã©ã¯ã±ã´ãžÃ´ã¹ã­Ã­ã©ãªã§ã¬ãã­ã¹ã­(ã“ã¯...
# 123410,10301,Ã”ãã«ã¯ã²(ã¼ã«ã¡Ã¡ã±ã·ãÿã¦ã¯ãµã­Ã¥ã¤ã¾)
# 123449,10305,ÃžikayetimVar
# 123459,10305,SonÃžarkã½
# 123477,10307,JoãƒoPencaEOsMiquinhosAmestrados/esseMeu...
# 123482,10307,MariaBethã‚nia/explodeCoraã‡ãƒo
# 123485,10307,FãbioJr./euNuncaEstiveTãƒoApaixonado
# 123772,10328,01.Â¹â«ã€ã»Ã„â¸ã†â¾Â»ã§â¿ã¬â¸â£â½âº
# 123773,10328,02.Â°â¡â¿ã€â°â¡ã€ãœâ°ã…
# 123774,10328,03.Â°ã±âµã¥â·â±
# 123775,10328,04.Â¸â¶â¹ã½ãƒâµâ»ã§Â·ã§âºã±I
# 123776,10328,05.Â¿ã¤â¸â®â¿ã•âºã±â·ã¦Main
# 123777,10328,06.Â¸ã­ã…â½ãâ¤Ã„ãšâ³â­
# 123778,10328,07.Â¹ã¶ã…â°â¿ãÃ…ãµã…ãµ
# 123779,10328,08.Â¶ã’âµã¼â¹ãšâ»ã§Ã‡ã‹
# 123780,10328,09.Ãã–â¸â¸ãã¶
# 123781,10328,10.Â°â£ãˆâ£ãƒâµâ»ã§Â¸â®â¸â®ã„â«I
# 123782,10328,11.Â¾ã…â¾ã…ã„â°
# 123783,10328,12.Ãã¶â±â¸ã†â¯â°ã¸â´ã«
# 123784,10328,13.Âºâ£â¸â£â»ã§ã€ãœã€â¯ã€ã‡Ã€ã¥â¹ãœ
# 123785,10328,14.Â³â»ã€ãã€âºÃƒã â±â¸â¿ã•
# 123786,10328,15.Â¸â¶â¹ã½ãƒâµâ»ã§Â·ã§âºã±Ii
# 123787,10328,16.Â¿ã¤â¸â®â¿ã•âºã±â·ã¦Ending
# 123788,10328,17.Â°â£ãˆâ£ãƒâµâ»ã§Â¸â®â¸â®ã„â«Ii
# 123789,10328,18.Â¸â»â°ã½â·â®ã€ãœÂ¾ã˜ãã¶
# 123790,10328,19.Â²ã‰ã€ã‡ãƒâµâ»ã§Â·ã§â·ã§
# 123791,10328,20.Ãã¶â±â¸â¿ã«â»ã§Â¼â±â°â¡âµã¥
# 123792,10328,21.Â½âºã†ã„ã€ãœâ´ãµâ¸ã‡
# 123793,10328,22.Â»ã§ã€ãœâ¹ã¶ã…â½ã‡ã¨â´ã«Ã€ã°â´ãã„ã¹â½âºã†â®
# 123794,10328,23.Ã‡ãâ´ãƒã€ã‡Â¿ã«â»ã§Â½âºã„â«ã€ãœÂ¼â­ã†ã›
# 123795,10328,24.Â²ã™â·â¯â±ã¢Â¼ã¶âºã±â´ã«
# 123796,10328,25.Âµâ¶â¼ã¶â¸â®Â¿ã€ã‡ã¼ãâ¦+âºã±â¹ãã€ã‡ãˆâ­â...
# 123797,10328,26.Â°â³â±â¸â¸â®Â¼ã’â³ã¢Â¿ã•â´â«ã€ãœ+ãã£â¶ã³...
# 123798,10328,27.Ã‡ã‡â³ã«ã…â°â¿ã€+â´ãžã…â¸â³ã‰ã€ã‡Â¸ã°ã‡ã¨+...
# 123799,10328,28.Â»â¡â°â­â¸ã“â¸â®Â¾ã˜+â»ãâ·ãžâ·ã•Â²â¿â¸â¶...
# 123875,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯1
# 123876,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯2
# 123877,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯3
# 123878,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯4
# 123879,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯5
# 123880,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯6
# 123881,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯7
# 123882,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯8
# 123883,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯9
# 123884,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯10
# 123885,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯11
# 123886,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯12
# 123887,10336,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯13
# 123888,10337,Â³âªâ¸â¦Ã‡ã¢ã‡ã‘Ãã–ã€ã‡Â»ã§â¶ã»
# 123889,10337,Ã‡ãâ´ãƒÃ€â§â¿â¡Ãã–â´ã”Â¹ã›â¿â¡
# 123890,10337,Â³âªã€ã‡Â¸ã°â½ã€Â³âªã€ã‡Â¼ã’ã€â¯
# 123891,10337,Â¸ã±â¸â¶â¸â¥Ã€ãšâµã©â¾ã†
# 123892,10337,Â¸â¶ã€â½ã€ãœÂ»ã³ã‡ã‘ã€ãšâ¸â¦
# 123893,10337,Â¸ã°âµã§Â´ã‰â·ã‚â°ãºÂ¸ã°âµã§Â±ã‡â¼â¼
# 123895,10337,Ã€âºã‡ã½â·ãžâ¸â¸
# 123896,10337,Âºâ¸â¸â®â¶ã³(â°ã­ã‡ã¼â¿ã¸)
# 123897,10337,Ãã–ã€ã‡Ã€ãšâºã±â°â¡Â³â»â·ãâ¿ã
# 123898,10337,Âºâ¸ãã‚â¾ã•â¿â¡
# 123899,10337,Â¸â¶ã€â½ã€ãœÂ»ã³ã‡ã‘Ã€ãšâ¸â¦(cello)
# 123912,10339,Ãœã¡ã¦ãÿÃ³ã¯ãµÃªã¡ã©Ã³ã´ã§ã­Ãªã¼ã«ã¡ã³ã§
# 123913,10339,Ãã±ã±ã¹ã³ã´ã¡ãÿã­ã¹
# 123914,10339,Ãã­Ãžã¬ã¯ãµã­ã¡Ã°ã¡ã«ã©ã¼ã°ã¡ã©ã¤ã¯
# 123915,10339,Ã”ã¯Ãªã¯ã¬ãã­ã¯Ã¬ã¯ãµÃ´ã³ã©ã£ãœã±ã¯
# 123916,10339,Ãœã¥Ã·ã¡ã«ãœã¥ã©
# 123917,10339,Ã“ãµã­ã¤ã¥ã´ãžã±ã¥ã²
# 123919,10339,Ãã¡Ã´ã§ã²Ã°ã¥ã©ã²Ã³ãµã£ã­ã¾ã¬ã§
# 123920,10339,Ã„ã¥ã­Ã¬ã¥Ãªã¡ã´ãœã«ã¡ã¢ã¥ã²
# 123921,10339,Ã–ã¯ã¢ãœã¬ã¡ã©
# 123922,10339,Ã”ã¯Ã¬ã¡ã½ã±ã¯Ã¬ã°ã¯ãµã¶ãœã­
# 123923,10339,Ã‘ã¡ã£ã©ã³ã¬ãã­ã¯Ã£ãµã¡ã«ãÿ
# 123963,10343,Ãã²ã„â»
# 123964,10343,Âµã£ããã„ãžâºã¬âµã†
# 123965,10343,Ãã£ã‘ãœãƒã”ãƒã‰ãã‹ã‘ã›â¾â¦
# 123966,10343,Ã”ã™â»ã®ã’â»â±ã©
# 123967,10343,Ãœã˜â±ã°ã€â´â±ã¶
# 123968,10343,Ã„ã£ãšã‡ã—ã®ã€ã¤âµã„ã‡ã©ãˆã‹
# 123969,10343,Ã’â»â¸ã¶ãˆã‹âµã„â³âªâ¸ã¨
# 123970,10343,Ãã„ã‰ããƒâ»ã“ããˆã‹
# 123971,10343,Â¾ã€â²ã¸ã’â»ã‰ãº
# 123972,10343,Ã€ã±ãžã¯
# 123973,10343,Âµâ±â¹ã‚â¶ã€ã“ã¶âµâ½â¼ã…ã„â¯
# 123974,10343,12-ã’â¹ãã¢â¾â°
# 123975,10343,Ã‘â©â¸ã¨
# 123989,10345,Ãœã¥ã«ã¼ã­ã¨ã¶ã Feat.Ãˆ.Ãã¨ãªã®ã«ã ã¥ã¢
# 123990,10345,Ãšã®ã¬ã ã°ã®ã¢ã®Feat.Ãˆ.Ã‘ãªã«ã¿ã°
# 123991,10345,Ã’ã ã£ã ã­ãªã Feat.Ãœ.Ã˜ã³ã´ã³ã²ã¨ã­ã±ãªã¨ã©
# 123992,10345,Ãã ã¡ã³ã¸ãªã¨_ã±ã²ã ã°ã³ã¸ãªã¨Feat.Ã‚.Ã„ã®ã¡...
# 123993,10345,Ã’ã°ã ã¢ã Ã³Ã¤ã®ã¬ã Feat.Ã‡ã¥ã¬ã«ã¿ã­ã¥
# 123994,10345,Ãœã£ã­ã®ã¢ã¥ã­ã¨ã¿Feat.Ã.Ãã ã±ãªã®ã¢
# 123995,10345,Ã„ã®ã¦ã¤ã¨Feat.Ãˆ.Ãšã®ã°ã­ã¥ã«ã¾ãª
# 123996,10345,Ãã³ãªã¥ã²Feat.Ã€.Ãã ã°ã»ãªã¨ã­
# 123997,10345,22Ã¯ã°ã¨ã²ã®ã¯ã Feat.Ã‘.Ãœã¨ã­ã ã¥ã¢
# 123998,10345,ÃÿÃ«ã¾ã¡ã«ã¾Ã¢ã ã±,Ã¤ã¥ã¢ã®ã·ãªã¨Feat.Ã.Ã...
# 124053,10350,Ãã²ã„â»
# 124054,10350,Âµã£ããã„ãžâºã§âµã†
# 124055,10350,Ãã£ã‘ãœãƒã”ãƒã‰ãã‹ã‘ã›â¾â¦
# 124056,10350,Ã”ã™â»ã®ã’â»â±ã©
# 124057,10350,Ãœã˜â±ã°ã€â´â±ã¶
# 124058,10350,Ã„ã£ãšã‡ã—ã®ã€ã¤âµã„ã‡ã©ãˆã‹
# 124059,10350,Ã’â»â¸ã¶ãˆã‹â³âªâ¸ã¨
# 124060,10350,Ãã„ã‰ããƒâ»ã“ããˆã‹
# 124061,10350,Â¾ã€â²ã¸ã’â»ã‰ãº
# 124062,10350,Ã€ã±ãžã¯
# 124063,10350,Âµâ±â¹ã‚â¶ã€ã“ã¶âµâ½â¼ã…ã„â¯
# 124064,10350,Ã’â¹ãã¢â¾â°
# 124065,10350,Ã‘â©â¸ã¨
# 124085,10352,DeMã£osDadas
# 124090,10352,Tã£oDiferente
# 124091,10353,01-â³âªâ¸â¦Ã‡ã¢ã‡ã‘Ãã–ã€ã‡Â»ã§â¶ã»
# 124092,10353,02-ã‡ãâ´ãƒÃ€â§â¿â¡Ãã–â´ã”Â¹ã›â¿â¡
# 124093,10353,03-â³âªã€ã‡Â¸ã°â½ã€Â³âªã€ã‡Â¼ã’ã€â¯
# 124094,10353,04-â¸ã±â¸â¶â¸â¥Ã€ãšâµã©â¾ã†
# 124095,10353,05-â¸â¶ã€â½ã€ãœÂ»ã³ã‡ã‘Ã€ãšâ¸â¦
# 124096,10353,06-â¸ã°âµã§Â´ã‰â·ã‚â°ãºÂ¸ã°âµã§Â±ã‡â¼â¼
# 124098,10353,08-ã€âºã‡ã½â·ãžâ¸â¸
# 124100,10353,10-ãã–ã€ã‡Ã€ãšâºã±â°â¡Â³â»â·ãâ¿ã
# 124101,10353,11-âºâ¸ãã‚â¾ã•â¿â¡
# 124102,10353,12-â¸â¶ã€â½ã€ãœÂ»ã³ã‡ã‘Ã€ãšâ¸â¦(cello)
# 124569,10391,Ãœã¡ã¦ãÿÃ³ã¯ãµÃªã¡ã©Ã³ã´ã§ã­Ãªã¼ã«ã¡ã³ã§
# 124570,10391,Ãã±ã±ã¹ã³ã´ã¡ãÿã­ã¹
# 124571,10391,Ãã­Ãžã¬ã¯ãµã­ã¡Ã°ã¡ã«ã©ã¼ã°ã¡ã©ã¤ã¯
# 124572,10391,Ã”ã¯Ãªã¯ã¬ãã­ã¯Ã¬ã¯ãµÃ´ã³ã©ã£ãœã±ã¯
# 124573,10391,Ãœã¥Ã·ã¡ã«ãœã¥ã©
# 124574,10391,Ã“ãµã­ã¤ã¥ã´ãžã±ã¥ã²
# 124576,10391,Ãã¡Ã´ã§ã²Ã°ã¥ã©ã²Ã³ãµã£ã­ã¾ã¬ã§
# 124577,10391,Ã„ã¥ã­Ã¬ã¥Ãªã¡ã´ãœã«ã¡ã¢ã¥ã²
# 124578,10391,Ã–ã¯ã¢ãœã¬ã¡ã©
# 124579,10391,Ã”ã¯Ã¬ã¡ã½ã±ã¯Ã¬ã°ã¯ãµã¶ãœã­
# 124580,10391,Ã‘ã¡ã£ã©ã³ã¬ãã­ã¯Ã£ãµã¡ã«ãÿ
# 124739,10405,Boa/Ã¥â¥â€¡ã¨â¹å¸(soul'dOutRemix)
# 124812,10410,Howsweetitis{tobelovedbyyou}(1964,holland,dozie...
# 124817,10410,Steamroller[live@universalamphitheatre,losangel...
# 124901,10417,AWeekAgo(feat.Too$hort)
# 125151,10438,Ãœã¥ã«ã¼ã­ã¨ã¶ã Feat.Ãˆ.Ãã¨ãªã®ã«ã ã¥ã¢
# 125152,10438,Ãšã®ã¬ã ã°ã®ã¢ã®Feat.Ãˆ.Ã‘ãªã«ã¿ã°
# 125153,10438,Ã’ã ã£ã ã­ãªã Feat.Ãœ.Ã˜ã³ã´ã³ã²ã¨ã­ã±ãªã¨ã©
# 125154,10438,Ãã ã¡ã³ã¸ãªã¨_ã±ã²ã ã°ã³ã¸ãªã¨Feat.Ã‚.Ã„ã®ã¡...
# 125155,10438,Ã’ã°ã ã¢ã Ã³Ã¤ã®ã¬ã Feat.Ã‡ã¥ã¬ã«ã¿ã­ã¥
# 125156,10438,Ãœã£ã­ã®ã¢ã¥ã­ã¨ã¿Feat.Ã.Ãã ã±ãªã®ã¢
# 125157,10438,Ã„ã®ã¦ã¤ã¨Feat.Ãˆ.Ãšã®ã°ã­ã¥ã«ã¾ãª
# 125158,10438,Ãã³ãªã¥ã²Feat.Ã€.Ãã ã°ã»ãªã¨ã­
# 125159,10438,22Ã¯ã°ã¨ã²ã®ã¯ã Feat.Ã‘.Ãœã¨ã­ã ã¥ã¢
# 125160,10438,ÃÿÃ«ã¾ã¡ã«ã¾Ã¢ã ã±,Ã¤ã¥ã¢ã®ã·ãªã¨Feat.Ã.Ã...
# 125185,10440,PiosenkaKrã³tka,JakSamoÂ¯ycie
# 125186,10440,Â¯yczeniaDlaPrzyjaciã³â³
# 125327,10452,NaPressã£o
# 125329,10452,MeuAmanhã£(intuindootil)
# 125332,10452,AMedidaDaPaixã£o
# 125334,10452,RuadaPassagem(trã¢nsito)
# 125424,10460,Â¹â«ã€ã»Ã„â¸ã†â¾Â»ã§â¿ã¬â¸â£â½âº
# 125425,10460,Â°â¡â¿ã€â°â¡ã€ãœâ°ã…
# 125426,10460,Â°ã±âµã¥â·â±
# 125427,10460,Â¸â¶â¹ã½ãƒâµâ»ã§Â·ã§âºã±I
# 125428,10460,Â¿ã¤â¸â®â¿ã•âºã±â·ã¦Main
# 125429,10460,Â¸ã­ã…â½ãâ¤Ã„ãšâ³â­
# 125430,10460,Â¹ã¶ã…â°â¿ãÃ…ãµã…ãµ
# 125431,10460,Â¶ã’âµã¼â¹ãšâ»ã§Ã‡ã‹
# 125432,10460,Ãã–â¸â¸ãã¶
# 125433,10460,Â°â£ãˆâ£ãƒâµâ»ã§Â¸â®â¸â®ã„â«I
# 125434,10460,Â¾ã…â¾ã…ã„â°
# 125435,10460,Ãã¶â±â¸ã†â¯â°ã¸â´ã«
# 125436,10460,Âºâ£â¸â£â»ã§ã€ãœã€â¯ã€ã‡Ã€ã¥â¹ãœ
# 125437,10460,Â³â»ã€ãã€âºÃƒã â±â¸â¿ã•
# 125438,10460,Â¸â¶â¹ã½ãƒâµâ»ã§Â·ã§âºã±Ii
# 125439,10460,Â¿ã¤â¸â®â¿ã•âºã±â·ã¦Ending
# 125440,10460,Â°â£ãˆâ£ãƒâµâ»ã§Â¸â®â¸â®ã„â«Ii
# 125441,10460,Â¸â»â°ã½â·â®ã€ãœÂ¾ã˜ãã¶
# 125442,10460,Â²ã‰ã€ã‡ãƒâµâ»ã§Â·ã§â·ã§
# 125443,10460,Ãã¶â±â¸â¿ã«â»ã§Â¼â±â°â¡âµã¥
# 125444,10460,Â½âºã†ã„ã€ãœâ´ãµâ¸ã‡
# 125445,10460,Â»ã§ã€ãœâ¹ã¶ã…â½ã‡ã¨â´ã«Ã€ã°â´ãã„ã¹â½âºã†â®
# 125446,10460,Ã‡ãâ´ãƒã€ã‡Â¿ã«â»ã§Â½âºã„â«ã€ãœÂ¼â­ã†ã›
# 125447,10460,Â²ã™â·â¯â±ã¢Â¼ã¶âºã±â´ã«
# 125448,10460,Âµâ¶â¼ã¶â¸â®Â¿ã€ã‡ã¼ãâ¦+âºã±â¹ãã€ã‡ãˆâ­â¿ã¸+...
# 125449,10460,Â°â³â±â¸â¸â®Â¼ã’â³ã¢Â¿ã•â´â«ã€ãœ+ãã£â¶ã³â±ã¢...
# 125450,10460,Ã‡ã‡â³ã«ã…â°â¿ã€+â´ãžã…â¸â³ã‰ã€ã‡Â¸ã°ã‡ã¨+â²â¿...
# 125451,10460,Â»â¡â°â­â¸ã“â¸â®Â¾ã˜+â»ãâ·ãžâ·ã•Â²â¿â¸â¶â¸â¶...
# 125472,10462,Â¿porquã©NoTeHacesParaAllã¡?...AlMasAllã¡
# 125504,10464,Senhor,PãµeTeusAnjosAqui
# 125505,10464,Mã£e,Mã£e,Mã£e
# 125512,10464,ErgueiAsMã£os-SenhorTemMuitosFilhos
# 125558,10468,DeMã£osDadas
# 125563,10468,Tã£oDiferente
# 126709,10561,Boa/Ã¥â¥â€¡ã¨â¹å¸(soul'dOutRemix)
# 127153,10597,Ã§â â€šã¦âµå“
# 127154,10597,Oneã£â‚¬å“ã¦â€žâ€ºã£?â¯ã£?âµã£?å¸ã£â€šå ã£?â®ã£...
# 127155,10597,Ã©å“â§ã©â€ºâ¨ã£?â«ã¦â¶ë†ã£?ë†ã£?â¦ã£â€šâ€ ã£??
# 127160,10597,Kaniã£â‚¬å“havenlyGardenã£â‚¬å“
# 127161,10597,Ã¦â„¢â©ã¥â¤?ã£?â®ã¦?â€¹ã¤âºâºã£?å¸ã£?â¡ã£?â¸
# 127165,10597,Ã£?â€¢ã£â€šë†ã£?âªã£â€šâ€°ã£?â€”ã£â€šâ€œã£??ã£â...
# 127940,10660,Â¿porquã©NoTeHacesParaAllã¡?...AlMã¡sAllã¡
# 128208,10682,Â©_ã‚ã(soul'dOutRemix)/RemixedBySoul'dO
# 128876,10735,Mã£eMaeMae
# 128883,10735,ErgueiAsMã£os
# 128957,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯1
# 128958,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯2
# 128959,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯3
# 128960,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯4
# 128961,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯5
# 128962,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯6
# 128963,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯7
# 128964,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯8
# 128965,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯9
# 128966,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯10
# 128967,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯11
# 128968,10742,Â¥ãˆâ¥ã©â¥ãƒâ¥â¯12
# Data removed: 331 rows
# Tracks removed: 5135 rows

# %%
# before
print(len(clean_data))

## remove indexes from dataframes according to rr1 and rr2
clean_data.drop(clean_data.index[rr1], inplace=True)
clean_tracks.drop(clean_tracks.index[rr2], inplace=True)

#after
print(len(clean_data))
# Out:
# 7663
# 7332

# %%
# renaming tracks column to album_id for uniformity
clean_data.rename(columns={"tracks": "album id"})
# Out:
#                               artist                category
# 0                    Backstreet Boys                   Blues  \
# 1                          No Return                    Data
# 3                            Emanuel  Classic Portuguese Pop
# 4                   Luv Lite Massive              Electronic
# 5                    Various Artists              Electronic
# ...                              ...                     ...
# 7658  Various Artists - Notting Hill                   Blues
# 7659                          Lenine                   Blues
# 7660                      Ben Harper                   Blues
# 7661                       Alvin Lee                   Blues
# 7662                 Manuel Barrueco                   Blues
#
#                        genre               title  album id  year      id
# 0                        Pop          Millennium      1000  1999   10000
# 1                       Data     Self Mutilation      1002  2019  100002
# 3     Classic Portuguese Pop          Felicidade      1004  1998  100004
# 4                 Electronic            One Love      1006  2014  100006
# 5                 Electronic           Nop Pop 2      1007  2002  100007
# ...                      ...                 ...       ...   ...     ...
# 7658              Soundtrack        Notting Hill     10758  1999    9838
# 7659                   Samba          Na Pressao     10759  1999    9863
# 7660                   Blues    The Will To Live     10760  1997    9868
# 7661                   Blues  I Hear You Rockin'     10761  1993    9876
# 7662                    Jazz       Nylon & Steel     10762  2001    9969
#
# [7332 rows x 7 columns]

# %% [markdown]
# ## Export to TSV

# %%
clean_data.to_csv('../../cleaning_stages/7_unit_code_repair/cddb_5.tsv', sep="\t", index=False)
tracks.to_csv('../../cleaning_stages/7_unit_code_repair/cddb_tracks_2.tsv', sep="\t", index=False)
