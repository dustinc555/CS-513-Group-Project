# %% [markdown]
# ## load in cddb table

# %%
import numpy as np
import pandas as pd
import re
 

data = pd.read_csv("../../cleaning_stages/6_openrefine_drop_bad/cddb-4-drop.tsv", sep='\t')
tracks = pd.read_csv("../../cleaning_stages/6_openrefine_drop_bad/cddb-tracks.tsv", sep='\t')


# printing data
print(data)
# Out:
#                               artist                category
# 0                    Backstreet Boys                   Blues  \
# 1                          No Return                    Data
# 2          Ã¤â¸â­ã¦?â€˜ã©â€ºâ€¦ã¤â¿å                     Pop
# 3                            Emanuel  Classic Portuguese Pop
# 4                   Luv Lite Massive              Electronic
# ...                              ...                     ...
# 7658  Various Artists - Notting Hill                   Blues
# 7659                          Lenine                   Blues
# 7660                      Ben Harper                   Blues
# 7661                       Alvin Lee                   Blues
# 7662                 Manuel Barrueco                   Blues
#
#                        genre                                         title
# 0                        Pop                                    Millennium  \
# 1                       Data                               Self Mutilation
# 2                        Pop  Ã¦æ’â³ã£?â€žã¥â€¡âºã£?â®ã£?â€¹ã£?â€˜ã£â€šâ€°
# 3     Classic Portuguese Pop                                    Felicidade
# 4                 Electronic                                      One Love
# ...                      ...                                           ...
# 7658              Soundtrack                                  Notting Hill
# 7659                   Samba                                    Na Pressao
# 7660                   Blues                              The Will To Live
# 7661                   Blues                            I Hear You Rockin'
# 7662                    Jazz                                 Nylon & Steel
#
#       tracks  year      id  merged_values
# 0       1000  1999   10000            NaN
# 1       1002  2019  100002            NaN
# 2       1003  1989  100003            NaN
# 3       1004  1998  100004            NaN
# 4       1006  2014  100006            NaN
# ...      ...   ...     ...            ...
# 7658   10758  1999    9838            NaN
# 7659   10759  1999    9863            NaN
# 7660   10760  1997    9868            NaN
# 7661   10761  1993    9876            NaN
# 7662   10762  2001    9969            NaN
#
# [7663 rows x 8 columns]

# %%
# Removing merged_values column becasue it is all null
data.drop('merged_values', axis=1, inplace=True)

# outpus test
print(data)
# Out:
#                               artist                category
# 0                    Backstreet Boys                   Blues  \
# 1                          No Return                    Data
# 2          Ã¤â¸â­ã¦?â€˜ã©â€ºâ€¦ã¤â¿å                     Pop
# 3                            Emanuel  Classic Portuguese Pop
# 4                   Luv Lite Massive              Electronic
# ...                              ...                     ...
# 7658  Various Artists - Notting Hill                   Blues
# 7659                          Lenine                   Blues
# 7660                      Ben Harper                   Blues
# 7661                       Alvin Lee                   Blues
# 7662                 Manuel Barrueco                   Blues
#
#                        genre                                         title
# 0                        Pop                                    Millennium  \
# 1                       Data                               Self Mutilation
# 2                        Pop  Ã¦æ’â³ã£?â€žã¥â€¡âºã£?â®ã£?â€¹ã£?â€˜ã£â€šâ€°
# 3     Classic Portuguese Pop                                    Felicidade
# 4                 Electronic                                      One Love
# ...                      ...                                           ...
# 7658              Soundtrack                                  Notting Hill
# 7659                   Samba                                    Na Pressao
# 7660                   Blues                              The Will To Live
# 7661                   Blues                            I Hear You Rockin'
# 7662                    Jazz                                 Nylon & Steel
#
#       tracks  year      id
# 0       1000  1999   10000
# 1       1002  2019  100002
# 2       1003  1989  100003
# 3       1004  1998  100004
# 4       1006  2014  100006
# ...      ...   ...     ...
# 7658   10758  1999    9838
# 7659   10759  1999    9863
# 7660   10760  1997    9868
# 7661   10761  1993    9876
# 7662   10762  2001    9969
#
# [7663 rows x 7 columns]

# %%
# Pre processing tracks step
# tracks table seems to have a lot of values that start with "???/" In "Name" column
# the rest of the string seems okay, so we will just strip them out here
for i, row in tracks.iterrows():
        # 1. get name as string
        name = tracks["Name"][i]
        if "??? /" in name:
              name.replace("??? /", "")

# %% [markdown]
# ## Methods

# %%
# this method is a custom value checking
# returns true if input is not unit code
# returns false if input should be deleted
def check_mangled_code(string):
    check_string = string.lower().strip()

    # accptable characters
    # mainly want to catch mangled unit code
    # for this we are looking for four non-alphanumeric characters in a row
    reg = "[^a-zA-Z0-9_][^a-zA-Z0-9_][^a-zA-Z0-9_][^a-zA-Z0-9_]"
    p = re.compile(reg)

    # check if ?????
    # two ?? in a row is mangled code
    if "??" in check_string:
        return True
    
    # check if mangled
    else:
        return bool(p.match(check_string))

# %%
good_test = "BackstreetBoys,Blues,Pop,Millennium,1000,1999,10000"
bad_test = "Ã¤â¸â­ã¦?â€˜ã©â€ºâ€¦ã¤â¿å,Pop,Pop,Ã¦æ’â³ã£?â€žã¥â€¡âºã£?â®ã£?â€¹ã£?â€˜ã£â€šâ€°,1003,1989,100003"
another_test = "LesjaskogTrekkspillklubb,Folk,Gammeldans,TrekkspilltreffISã¸ristua,1273,1998,100282"
print(check_mangled_code(good_test))
print(check_mangled_code(bad_test))
print(check_mangled_code(another_test))
# Out:
# False
# True
# False

# %%
def unit_code_repair(df):
    rows_to_drop = []
    
    for i, row in df.iterrows():
        # 1. get row values as string
        row_str = df.iloc[i,:].to_string(header=False, index=False)
        row_str = row_str.replace(" ", "").replace('\n', ',').replace('\r', ',').replace('\t', '').strip()
        
        # 2. condition checking
        if check_mangled_code(row_str) == True:
            # 3. remove from df - add to dictionary
            rows_to_drop.append(i)
            print(row_str)

    return df, rows_to_drop

# %% [markdown]
# ## running method

# %%
# test_data = data.head(3)
# clean_data_test, rr1_t = unit_code_repair(test_data)
# # output below shows what was cleaned
# print("Test Data removed: " + str(len(rr1_t)) + " rows")

clean_data, rr1 = unit_code_repair(data)
print("------------------------------------------------")
clean_tracks, rr2 = unit_code_repair(tracks)

# output below shows what was cleaned
print("Data removed: " + str(len(rr1)) + " rows")
print("Tracks removed: " + str(len(rr2)) + " rows")
# Out:
# Ã¤â¸â­ã¦?â€˜ã©â€ºâ€¦ã¤â¿å,Pop,Pop,Ã¦æ’â³ã£?â€žã¥â€¡âºã£?â®ã£?â€¹ã£?â€˜ã£â€šâ€°,1003,1989,100003
# Ã¥â±â±ã¥?â£ã§â„¢â¾ã¦?âµ,Jpop,Jpop,Disc13Ã¨å â±ã£?â€“ã£?â€¹ã£â€šå,1027,2003,100030
# Ã¥?â€šã¦å“â¬ã§å“å¸ã§â¶â¾,Pop,Pop,Lucy,1030,2001,100034
# Ã¥â±â±ã¥â´å½ã£?â¾ã£?â€¢ã£â€šë†ã£?â€”,Jpop,Jpop,Home,1047,1997,100051
# Ã¤ã®ã«ã¥ã°ã¤Ã¹ã¬Ã¤ã¢ã¸ã¥ã¡,Data,Data,Ã¤ã£ã¢Ã°ã§ã¹,1049,2019,100054
# Ã©ë†â´ã¦å“â¨ã£?â€šã£?â¿,Jpop,Jpop,InfinityEighteenVol.1,1052,2000,100057
# Ã§å¸â¢ã¦â²â¢ã¦â°â¸ã¥?â€°,Rock,Rock,SuperLiveÃ¦â€”â¥ã¦å“â¬ã¦â­â¦ã©?â€œã©â¤â¨Disc1,1054,1990,100059
# Â¿ã€ããÿâ±ã¢ãˆâ¹,ContemporaryChristianMusic,ContemporaryChristianMusic,Â»ãµâºâ®â±ã¢âµâµâ¸â¦Ã€â§ã‡ã‘Â°ã¦ã€â½â¾ã‡6,1065,2002,100071
# Ã±ã¡ã®ã°ã­ã¨ãª,Pop,Pop,Absolutãã›ã‰Ã•ãˆã’2,1068,2003,100074
# Ã£?â€¢ã£?â ã£?â¾ã£?â€¢ã£?â€”,Folk,Folk,Ã¤â¸â‚¬ã¤âºâºã§â„¢â¾ã¦â­å’Ã¥â·â»ã¤âºå’,1113,2019,100120
# VariousArtists,Folk,Folk,Ã¤â¸â­ã¥â³â¶ã£?â¿ã£â€šâ€ ã£??SongLibrary1,1146,1997,100153
# Â°ãâ·ã§â±j,Folk,Folk,Â¤sâ¨â£â¤ã«â©ãº,1177,1981,100184
# Ã€ã«ã¥ãªã±ã ã­ã¤ã°Ãã®ã¢ã¨ãªã®ã¢,Folk,Chanson,Ã‘Ãªã°ã ã±ã ã¢ã¨ã¶ã¥ã©Ã¢Ã®ã¡ã­ã¨ã¬ãªã³,1180,1996,100187
# Â¿â¹â¼ã¶ã€ã¼âµâµâ´ãœ,Folk,Gospel,Ã‡ã¢â±ã¢,1208,1999,100216
# Â½â²âµ^,Folk,Jazz,Â½â²âµ^âªã·â¤ã¹â¤lâ¡]â³ã¼â¡^â¤ã‘â²pâºqâ¤k,1327,2001,100338
# Ãƒâ«â®dâ¡â¢ã‘ã®ãâ¼â¡â¢ã€ã®ã¨âªâ¡â¢ã‚ãžâºâ£ã“â¢,Folk,Folk,Ã”ã§â´âºâµã„ã’ã´â·ã»,1372,1999,100385
# Ã‚ã«ã ã¤ã¨ã¬ã¨ã°Ã‚ã»ã±ã®ã¶ãªã¨ã©,Folk,Folk,Ã‚ã«ã ã¤ã¨ã¬ã¨ã°Ã‚ã»ã±ã®ã¶ãªã¨ã©Ã¢Ã§ã ã¯ã¨ã±...,1409,2023,100422
# Ãžã«ã¥ã£Ãšã®ã±ã²ã°ã®ã¢,Folk,Folk,Ãˆã¢ã®ã­ã­ã,1433,2021,100446
# Â³â¯â«ã˜â¦~,Folk,Folk,Â®ã¼â¬v,1435,2017,100449
# Ã ã¸ã©ã·Ã ã©ã©ã°ã¹ã¨ã©ã©ã¯,Folk,Ã©ã¬ã£ã©ã­,Ã¤ã ã¸ã©ã¤,Ã¤ã©ã¥ã°ã¤Ã¥ãºã¸ã°ã¢ã¥ã¬ãºÃ«ã§ã¥ã¬ã¤,1486,1992,100500
# Ãã ã¤ã¥ã¦ã¤ã Ãã ã¡ãªã¨ã­ã,Folk,Folklore,Ãã³ã±ã±ãªã ã¿Ã¯ã¥ã±ã­ã¿3/3,1506,1995,100521
# Ã©â»â€™ã§â„¢â¾ã¥?ë†ã¥â§â€°ã¥â¦â¹,Folk,Gothic,Ã¦å“ë†ã£?â®ã¨?â€¢,1510,1993,100525
# Â³â¶â¸â¸ã€ã‡Ã…ã«â±ã¢ã…â¸,Folk,Folk,Â¹ãœâ»ã§â¸â®ã¦ã‡ãšâ°1,1660,2001,100679
# Ãšã®ã°ã®ã«ã¥ã¢Ã‚ã¨ãªã²ã®ã°,Folk,Chanson,Ãã¼ã¿ã­ã ã¿Ã‚ã¨ã¸ã­ã¿,1698,2000,100717
# Ã£?å¸ã£?â¾,Folk,Folk,Ã¦?â±ã¤âºâ¬ã£æ’â€¢ã£æ’â«ã£æ’â¼ã£æ’â€ž,1706,2000,100726
# Ã£â€šâµã£â€šâ¤ã£â€šâ²ã£æ’â³ã£â€šâ¸,Folk,Indie,Saigenji,1753,2002,100775
# Ãœã¥ã«ãœã²Ã†ã¡ã¶ã¥ãÿã±ã§ã²,Folk,Folk,Ã†ã¹ãžÃ°ã¡ã±ã¡ã¬ãµã¨ãã­ã©ã¡,1785,2003,100808
# Ã’ã ã²ã¼ã¿ã­ã Ãã³ã«ã ã­ã®ã¢ã,Jazz,Pop,Ã‡ã®ã«ã®ã²ã®Ã«ã¾ã¡ã¢ã¨,1833,2001,100856
# Ã¥â²â¡ã¥â®â€°ã¨å â³ã¦ëœå½,Jazz,Jazz,Dear,1862,2001,100885
# Â¥ã‰â¸mâ¯eâ¤g(kojiTamaki),Jazz,Pop,Â°sâ¬ãµâ¦ã¢âªâºâ¤ãÿ,1949,1999,100974
# Ã‹ãœã­ã´ã³ã©ã¡ã²Ã“ã´ã¡ã½ã±ã¯ã²,Jazz,Jazz,Ã…ã°ã©ã³ã´ã±ã¯ã¶ãž,1992,1999,101021
# Ã¦?â¾ã¥â±â€¦ã¦â€¦â¶ã¥â­?,Jazz,Jazz,Ã¦å’â€¡ã§â€™â°ã£â‚¬å“yubiwaã£â‚¬å“,2071,2002,101101
# Ã¦?â¾ã¥â±â€¦ã¦â€¦â¶ã¥â­?,Jazz,Jazz,Ã£æ’â€¢ã£æ’â«ã£æ’â ã£æ’â¼ã£æ’â³ã£æ’â»ã£â€šâ¢ã£æ...,2191,2002,101222
# Â³âªã€â±â¼â±,Jazz,Jazz,Reflect,2357,2001,101397
# Ãã…ããÃ‚ã…ãã…ã”ã“ãããã•,Misc,Other,Ãã…ãÃƒã‡,2438,1996,101480
# Ã¨ã ã¨ã¥,Misc,Rock,Ã§ãºã¥ãªÃºã¥ã«ã¯,2459,1988,101502
# Â³â¯â¼zâ¼_,Misc,Pop,Â¥ãƒâ»â·â¬oâ§aâªâºâªbâ¤ã,2462,1989,101505
# Ã©?å ã¤â½?ã¦å“âªã¦â£â®,Misc,JapanesePop,Ã§â©âºã¨â‚¬â³ã£?â®ã¤â¸ëœ,2474,1991,101517
# Ã‘ã¬ã»ã±ã«ã®ã¢ã»ã¥Ã£ã ã«ã«ã¾ã¶ã¨ã­ã ã¶ã¨ã¨,Misc,Misc,Ã‹â¸ã¤9,2480,2001,101523
# Ã£?â€¢ã£?â ã£?â¾ã£?â€¢ã£?â€”,Misc,J-pop,Ã£æ’â„¢ã£â€šâ¹ã£æ’ë†ã¯â¼â€ ã£æ’â„¢ã£â€šâ¹ã£æ’ë†,2506,2003,101549
# Ã¦â¸â€¦ã¨â²â´,Misc,Pop,I'llBeThere,2549,2001,101595
# Ã¤â¸â­ã¥â³â¶ã£?â¿ã£â€šâ€ ã£??,Misc,Jpop,Ã¦â­å’ã£?â§ã£?â€”ã£?â€¹ã¨â¨â‚¬ã£?ë†ã£?âªã£?â€ž,2572,1991,101618
# Â¹ãšãâ¤ã‡ã¶,Misc,Pop,Forever,2632,2001,101679
# Â«â¸â¨|â«ã­,Misc,Â°ãªâ»yâ¬yâ¦ã¦,Â·râ§ãšâ§aâ©ãˆâ¤fâ¶ãœ,2697,2000,101747
# Ãƒã“âµãºã…ã¯,Misc,Â°ãªâ»yâ¬yâ¦ã¦,Â¥bâ¹ãšâ¥bâ¿ã´â¤â§â¶â¡,2712,1988,101762
# Ã¤â¸â­ã¥â³â¶ã§â¾å½ã¥ëœâ€°,Misc,Newage,True,2740,2002,101790
# Ã•ã…â¹ãºãˆã™,Misc,Pop,Leslie,2827,1984,101879
# Â±ã¨â¿âµâµâ¿,Misc,Â±â¹â¾ã‡,Â¹ã™â¶ã·ã€ã‡Â¼ã’â¸â®(windsongs),2893,1999,101947
# Ã¥â·?ã¦â¾â€žã§â¶â¾ã¥â­?,Misc,Misc,Ã£?â¾ã£?â»ã£â€š?ã£?â¾ã£?â¦ã£?æ’ã£?â£ã£??ForÃ¥...,3004,2003,102062
# Ã ã©ã´ã¤Ã¤ã©ã¬ã£,Misc,Ã©ã¹ã¸ã ã¬ã©,Ã¦ã®ã¯Ã±ã¥ã«ã¸,3062,1993,102120
# Â¼ã’ã‡ã¢,Misc,ContemporaryChristian,Â¼ã’ã‡ã¢Special,3072,2001,102131
# Ã¥?â¤ã¥â€ â€¦ã¦?â±ã¥â­?,Misc,Pop,Distance,3110,1993,102169
# Ã£â€šâ¦ã£æ’â«ã£æ’â€¢ã£æ’â«ã£â€šâº,Misc,JapaneseRock,Stupid&Honest,3135,1999,102196
# Ãƒã¶â²qâ©ã‰,Misc,Pop,TheStoryOfShirley,3221,1993,102282
# Â¡ã‘â¹âµãÂ¡ã‘ã…ã‚ã¬â¨ã’ã„â¡,Misc,Pop,Ã ãšã©â¹â¢ãâºâ¿ã©ã’,3263,2000,102325
# Ã‚ãã“ã‰ã‹ã‡ã“Ã”ã…ã‘ã‹ã…ãƒãšãã“,Misc,Misc,ÃÃšãã‹ã•ã”ã…ã‘ãã“,3288,2010,102352
# Â¤ã½â¤oâ§â»,Misc,Pop,Â°ãÿâ¤@,3319,2001,102386
# Ãˆã¢ã ã­Ãšã³ã·ã¨ã­,Misc,Chanson,Ã•ã°ã³ã±ã²ã ã«ã¼ã­ã ã¿Ã¢ã ã§ã,3408,1995,102477
# Â·â¨â¨â¼â©g,Misc,Misc,Ã‚ã·â§oâ¤â§â«e,3426,2000,102499
# Ã©â«ëœã¦â©â€¹ã¥â¹â¸ã¥â®?,Misc,Pop,TheBestWay,3436,1993,102510
# Ã¦?â€°ã¥â±â±ã¦â¸â€¦ã¨â²â´,Misc,Misc,Ã¥â½â¼ã¦â€“â¹ã£?â€¹ã£â€šâ€°ã£?â®ã©â¢â¨,3449,2020,102523
# Â±ã¨ã€â±â¾ã†,Misc,Vocal,Â¼â¨âµâµâ¿ã¬Â¿ã€âºãªÃ€â¯â¾ã®Â½âºâ¸â¶ã€ã,3461,2001,102534
# Ã§å“å¸ã¥â³â¶ã¦ëœå’ã¥ë†â©,Misc,JapaneseRock,Ã¥â¤?ã£?â®ã£?â¬ã£?â€˜ã£?å’ã£â€šâ€°,3464,1989,102537
# Ã£æ’?ã£â€šâ«ã£æ’â»ã£æ’â€“ã£æ’â¼ã£æ’â³,Misc,J-pop,Ã¦ëœâ¥ã¥â¤?ã§â§â€¹ã¥â€ â¬,3466,1994,102539
# Ã§â€¢â ã¥â±â±ã£â‚¬â‚¬ã§â¾å½ã§â€â±ã§â´â‚¬,Misc,Pop,WildAndGentle,3481,2003,102556
# Ã‡ã‘â±â¹â¿â¹â¹ã¨ã€ãžâµâµã€ãšâ¸ã°ã€ã“,Misc,Ccm,Ãã–Ã€ã“ã€ã§Â¾ãˆâ¿â¡â¼â­-WorshipCampLive...,3657,2004,102741
# Ã¦â€“â°ã¤â¸â€“ã§â€¢å’ã¦â¥â½ã¦â€ºâ²ã©â€ºâ€˜ã¤â¼å...,Misc,Game,Ã©â¢â¨ã©â€ºâ²ã£â€šâ¹ã£æ’â¼ã£æ’â€˜ã£æ’â¼ã£â€šâ¿ã...,3739,1996,102828
# Ã£â€šâ¹ã£æ’?ã£æ’â£ã£æ’â‚¬ã£æ’â©ã£æ’â€˜ã£æ’â¼,Misc,Ã£æ’â€™ã£æ’æ’ã£æ’â€”Ã£æ’â€ºã£æ’æ’ã£æ’â€”(ã¤â¸...,Ã¥?â¶ã§â€žâ¶ã£?â®ã£â€šâ¢ã£æ’â«ã£æ’?ã£æ’â,3788,1996,102879
# Ã¦â¸â¡ã¨â¾âºã£â‚¬â‚¬ã§â¾å½ã©â€¡å’,Misc,Rock,TheLegendMisatoWatanabe,3850,2002,102945
# Ãˆã¢ã ã­Ãšã³ã¯ã ã«ã,Misc,Folk,Ãšã®ã±ã²ã°ã®ã¬ã,3891,1999,102987
# Â¢ã«ãªã§ã³ã´ã©ã²Ãã±ã¹ã´ã¯ã¸ãœã«ã´ã§,Misc,Ã…ã­ã´ã¥ã·ã­ã¯,Ãšãµãªã«ã¯ã¶ã¯ã±ã¾Ãªã©Ã¯ã°ã«ã¯ã¶ã¯ã±ã¾,3906,1989,103002
# [â¹ã©â´ãœã‡ã¢]Ã€ãœâ±ã¢ã‚ã¹5ãã½,Misc,Ballad,NewStory,3936,2001,103032
# Ãšã˜â¹ã”âµã’Ã…ã•âµã”â¡ã˜ã…,Misc,Acoustic,Beau-NonElectricProject,3944,2001,103040
# Ã¥â°â¾ã¥â´å½ã¤âºå“ã§â¾å½,Misc,Pop,AmiiCmNetwork,3957,1987,103055
# Ãƒã‰ãããã‡ã“Ããã‘ã‰ãã“,Misc,Ã…ã‹ã‹ã‡ãã‰ãšã,Ã”ã•ã˜ã…ã‰ã“,3958,1997,103056
# Ã€ã­ã­ã Ãƒã¥ã°ã¬ã ã­,Misc,Vocal,Ã‘ã¯ã ã±ã¨ã¡ã®Ã²ã¥ã¡ã¥,Ã¬ã®â¸Ã±ã¥ã°ã¤ã¶ã¥,3971,2003,103069
# Ã©?å ã¤â½?ã£â‚¬â‚¬ã¦å“âªã¦â£â®,Misc,Pop,StillLife-ã©?â„¢ã£?â€¹ã£?âªã§â€å¸ã¦â´â»-,3985,2001,103084
# Ãâ¶â±ã”ã‚ã¹,Misc,Misc,The3rdSeason,4129,1996,103234
# Â¼ã•â¿âµãã¸,Misc,Gospel,Collection1983-2000,4132,2000,103237
# Â¶ã€âµãžã‚@,Misc,Male,Â°â¨â¤â£â°â±â¿ã¡âªâºâ¼~â¶ã‹,4188,1988,103294
# Ãã³ã²ã»ã°ãªã,Misc,Chanson,Ãã¥ã°ã¢ã»ã©Ã ã«ã¼ã¡ã®ã¬,4289,2003,103398
# Ã‘ã¥ã²ã¨,Misc,Pop,Ãã¥ã¡ã®Ã­ã Ã§ã¥ã¬ã«ã¥,4295,2002,103406
# Ã¦â€“â€°ã¨â€”â¤ã¥â€™å’ã§â¾â©,Misc,Pop,WonderfulFish,4328,1997,103440
# Ã’ã®ã­ã¨ãªã,Misc,Pop,Ãšã®ã­ã¶ã¥ã°ã²-Ã¡ã¥ã­ã¥ã´ã¨ã±'1994Ã’ã®ã­ã¨ã...,4336,1994,103448
# Â°ã¦â¹ã¨â¿ãã‚ã¹â¾ã§,Misc,ChristianGangsta,Ã€ã¼ã‡ãâ¼â¼â¿â¹â¼ã¶1,4450,1972,103565
# Ã©âºâ€”ã§â¾å½,Misc,J-pop,ReimyDisc1,4501,1990,103619
# Ã¦â²â¢ã§â€â°ã§â â€ã¤âºå’,Misc,Pop,Ã¦â²â¢ã§â€â°ã§â â€ã¤âºå’SuperBestDisc1,4639,1989,103762
# Ã„ã¥ã¬ã®,Misc,Misc,Ã‘ã®ã«ã­ã»ã¸ãªã®,4706,2019,103830
# Ã£â€šâªã£æ’âªã£â€šâ¸ã£æ’å ã£æ’â«ã£æ’â©ã£æ’â€“,Misc,Pop,SunnySideOfOrignalLove,4756,1995,103882
# Ã¥â·?ã¤âºâ€¢ã¦â€ â²ã¦â¬â¡,Misc,Anime,Patlabor2TheMovie,4827,1993,103957
# Â³ã‚â¹ãºã†â½,Misc,Instrumental,Ã£â«ã’ã¢,4851,1999,103983
# Ã€â¯â½ã‚ãã˜,Misc,Misc,ForSale,4854,2017,103987
# Ã£?â€¹ã£?â¾ã£?â€žã£?å¸ã£?â¡,Misc,JapaneseRock,Ã£?â¯ã£?â¡ã£â€šæ’ã£â€š?ã£?â¡ã£â€šæ’ã§â€¹â€š,4943,2012,104079
# Ãƒã‰ãããã‡ã“Ããã•ã‹ãããã•ã‹ãã“,Misc,Â¸ã­ã´ã¥ã·ã­ã¯,Ã…ã°ã©ã´ãµã·ãÿã¥ã²,4979,1997,104117
# Â³\â¼ã–-â³â¯â¼ã¤ã„r,Misc,Pop,Â¶â¢â±â¡â¶â®â¼ã–,5028,2023,104167
# Ãã¯ãµã«ã¼ã°ã¯ãµã«ã¯ã²Ãƒã©ãœã­ã­ã§ã²,Misc,Other,Ãƒã‰ãããã‡ã“Ããã•ã‹ãããã•ã‹ãã“1,5149,1997,104289
# Ãžã•ã„ã‰ãã“Ãˆãã„ã™ã‘ã‡ã“,Misc,Other,Ã—ã™ã‘ã‰ã“Ããã‘ã…ã,5169,2003,104310
# Ã£â€šâ·ã£æ’â¢ã£æ’â³ã£â€šâº,Misc,J-pop,Ã©â¢â¨ã£?â®ã£?â€œã£?â¨ã£?â¥ã£?â¦,5171,1990,104312
# Ãƒã‰ããƒãšãã•ã“ã‡Ã‹ã‰ã”ã“ã,Misc,Ã‹ãã‰ãšã,2000-ãšãã‰Ã“ã”ãÃ…ãžã‡ã“,5201,2000,104343
# Ã—ã ã©ã´,Misc,Rock,Ã˜ã¥ãªã®ã£ã ã«ã¨,5252,1999,104396
# Âºã‚â©g,Misc,Misc,Âºã‚â©g'88Âºtâ°ã›â·|,5258,1988,104402
# Ãšã ã©Ãœã¥ã²ã®ã¢,Misc,Pop,Ã‚ã±ã¯ã®ã¬ã­ã¨Ã¬ã¥ã­ã¿,5266,1995,104410
# Â¶ã€â°â¶â©ãº,Misc,InstrumentalPop,Â´â£âµ^â±â¡â¸ã–,5273,1997,104418
# Ãã½ã°ã°ã¨ã¬ã®ã°,Rock,Punk,Ã‚ã±â¸Ã½ã²ã®Ã¤ã«ã¿Ã²ã¥ã¡ã¿,5354,2002,104500
# Ã‰ã¹ã¡ã­ã­ãÿã¤ã§ã²Ãã«ãªãÿã­ã¯ã¯ã²,Rock,EasyListening,Ãã©Ã°ã¥ã±ã©ã°ãã´ã¥ã©ã¥ã²Ã¥ã­ã¼ã²Ã°ã±ã¯ã³ãª...,5385,2003,104533
# Ã¶'ã¸ã¶'ã©ã¬ã©ã­,Rock,ProgressiveRock,Ã¶'ã¸ã¶'ã©ã¬ã©ã­,5399,1968,104548
# Â¤ã¨ã€aã€s,Rock,Instrumental,Âµ\âµ]â¦ã¦,5476,2000,104633
# Ã‹ã¥ã®ã­ã¨ã¤Ã‘ã¥ã°ã£ã¥ã¥ã¢,Rock,Ballad,Ã”ã ã°ã´ã®ã°ã®ã¢ã ã¿Ã‘ã¢ã ã¤ã¼ã¡ã,5547,2000,104704
# Ã¥â®â€°ã¨â¥â¿ã£?â²ã£â€š?ã£?â€œ,Rock,Jpop,TrueLove,5592,2000,104751
# Ã€â±âµâµã‡ã¶â¹ãªâµã¥,Rock,Rock,AnUrbanite,5625,2001,104786
# Ãã ã§ã­ã»ã¥Ã¨ã±ã¯ã®ã«ã­ã¨ã²ã¥ã«ã¨,Rock,Retro,Ãã…ã‘ããˆÃžÃ‘ã’ã€ã‹ãˆãã…,5680,2003,104842
# Ã¤â¸â€°ã©â€¡?ã©â€¡å½ã§å¾â³,Rock,Jpop,BabyLeaf,5775,2020,104947
# Ã€ã«ã¥ãªã±ã ã­ã¤ã°Ã‹ã ã½ã°ã²ã±ãªã¨ã©,Rock,Rock,Ã†ã¥ã­ã¹ã¨ã­ã Ã±\ã²ã°ã³ã¡ã®ã©\,5883,1993,105066
# Ã‘ã¥ãªã²ã®ã°Ãƒã ã§ã,Rock,PunkRock,Ãƒã³ã«ã¿ã©Ã¬ã³ã¦ã¨ãª!,5893,1992,105076
# Ãã¯ã¨ã²ã ã´ã¨ã¿,Rock,HardRock,Ãã®ã·ã¥ã¬ã³Ã«ã¾ã¡ã®ã¢ã¼...,5915,2004,105098
# Ã‡ã¨ã­ã·ã³ãª,Rock,InstrumentalRock,Ãžã¤ã¨ã­ã®ãªã¨ã©Ã‚Ãã®ã·ã¨,5944,2002,105131
# Ãšã®ã«ã¨ã¡ã°ã¨,Rock,Electronic,Ãã¥ã¬ã¨ãªã±ã»,5965,1998,105156
# Â³â¯â¦ãšâ±j,Rock,Pop,Â´xâ¤ã€ã„ãâªâºâ¬ã¹â·|,6077,1980,105276
# Ãœâ·ã“â½ã·ã«,Rock,Pop,Â±â©â·ã§ã…â®ã‰ã±lorelei,6091,1985,105292
# Ãã­ãžâº,Rock,Rock,Ã„ã‡ã’â»ã„ãª(cd2),6130,2002,105334
# Ã†ã ã±ã¬ã¨ã­,Rock,Pop,Ã„ã®ã«ã£ã¨ã¥Ã„ã­ã¨,6144,2000,105349
# Ã€ã­â³Ã‹ã®ã°ã ãª,Rock,Pop,Ã’ã ã¬Ã¤ã¥Ã²ã¨Âº,6360,2002,105585
# Ã¥â¼âµã¥â­â¸ã¥?â€¹,Rock,Soundtrack,1999ã¥?â€¹ã¥â‚¬â€¹ã¤âºâºã¦â¼â€ã¥â€â±ã¦å“æ’[d...,6512,1999,105750
# Ã§â±â³ã§â±â³ã¯â¼â£ã¯â¼â¬ã¯â¼âµã¯â¼â¢,Rock,Jpop,PhiIi,6514,1994,105753
# Ã¸ã©ã·ã©Ã¢ã¬,Rock,Pop,Ã§ã´ã¹Ã¡ã©,6521,1993,105760
# Ã¦â²â³ã§â€â°ã§â´â€ã¥â­?,Rock,Jpop,Prologue,6656,1991,105908
# Ã¦â¸â¡ã¨â¾âºã£â‚¬â‚¬ã§â¾å½ã©â€¡å’,Rock,Pop,Spirits,6689,1996,105946
# Ãã³ã«ã ã­ã®ã¢ã Ã’.,Rock,Pop,Ãã²ã®Ã¨ã£ã°ã,6698,2002,105956
# Â½ã…ãˆâ­[shinhwa],Rock,Rock,6-Â³ãšã€ã‡Â°ã¡ãˆâ¥â½ã„(wedding),6857,2002,106127
# Â§ã…â±ã’â½ã¥,Rock,Other,Â´mâ½ã¥â±ã’â¨ã†Disc1,6875,1999,106146
# Ã£æ’â€”ã£æ’â¬ã£â€šâ¤ã£â€šâ°ã£â€šâ¹,Rock,Rock,Ã©â®â«ã£?â¨ã£æ’?ã£â€šâ¤ã£æ’â€œã£â€šâ¹ã£â€šâ«ã£â...,7000,2000,106278
# Â¾â¤â©ãº,Rock,Pop,4in1â¬ãƒã‚ãƒâ¶â°,7038,2003,106316
# Ã¦âµå“ã¥â´å½ã£?â€šã£â€šâ€ ã£?â¿,Rock,Jpop,Ayu-mi-xIiVersionAcousticOrchestra,7059,2000,106342
# Ã¥â¤â§ã§â‚¬â§ã¨â©â ã¤â¸â‚¬,Rock,Jpop,B-eachTimeL-ong,7085,1985,106370
# Ã€ãã†ã…ã‹ãˆãšã€Ã‚ã€ãã“ãœ,Rock,Pop,Ã‘ã’ãžã,Ã‹ãžããžãã›ã’ã‘ã’ã‚ãž,7156,2002,106443
# .............,Rock,Metal,SuperDancing,7204,1995,106495
# Ã€ã«ã¥ãªã±ã ã­ã¤ã°Ãœã ã«ã¨ã­ã¨ã­,Rock,Retro,Ã‹ã¾ã¡ã¢ã¨Ã¦ã¥ã«ã ã­ã­ã ã¿Ã¯ã®ã°ã,7217,1994,106511
# Â³â¯â¬ã•â¼ã¤,Rock,Techno,Â¥xâ»yâªã·â¦â±2,7308,2023,106608
# Ãã®ãªÃžã±ã²ã°ã®ã¢ã,Rock,Rock,Ãã ã¸ã¨,7375,1995,106684
# Ã¤â¸â­ã¦?â€˜ã£?â€šã£â€šâ€ ã£?â¿,Rock,Jpop,HeartOfDiamondsIi-bestAlubum-,7533,1992,106855
# Â³â¯â¼zâµy,Rock,Rock,Â­â¸â¤ã‘â»râ·|,7634,2002,106966
# Ã€ãªã¢ã ã°ã¨ã³ã¬,Rock,Folk/rock,Ã‚ã¨ã§ã¨ã²Ã¢Ãœã®ã±ãªã¢ã³,7716,1993,107056
# Ã‚ã«ã ã¤ã¨ã¬ã¨ã°Ãšã³ã§ã¼ã¬ã¨ã­,Rock,Pop,TheGreatestHitsIv,7745,1997,107087
# Ã¥â°?ã¦â¯â€ã©â¡å¾ã¥â·â»ã£?â€¹ã£?â»ã£â€šâ€¹,Rock,Rock,SilentFictionTour1991,7747,1992,107089
# Ã£â€šâ·ã£æ’â§ã£æ’æ’ã£â€šâ¯ã£â€šâ·ã£æ’â€ ã£â€šâ£...,Rock,Punk,Ã£â€šâªã£æ’â¼ã£â€šâªã£â€šâ¦ã£æ’â»ã£â€šâ¢ã£â€šâ¤...,7772,2001,107119
# Ã¥â°?ã¦å¾â€”ã¦â€”â­,Rock,Pop,Ã£â€šâ¢ã£â€šâ­ã£æ’â©4ã£â‚¬å“ã£æ’â¦ã£æ’â¼ã£æ’â¢ã...,7829,2002,107177
# Ã¤â¸å ã¥å½å¸ã£?â€šã£?å¡ã£?â¿,Rock,Jpop,Ã§â€žâ¡ã¨â€°â²,7842,2002,107190
# Ãâ¤ã€ã§ã€ã,Rock,Ballad,Â´â«â¹â°â²ã‰,7986,2022,107347
# Ã§â€°â¹ã¦â€™â®,Rock,Rock,Agitator,7990,2001,107351
# Ã¦?â¾ã§â€â°ã¨?â€“ã¥â­?,Rock,Jpop,SeikoAvenue,8015,1984,107379
# Ã¨â¦â³ã¦å“ë†ã£?â€šã£â€šå ã£?â€¢,Rock,Jpop,History-singleCollection-,8070,2004,107438
# Ãã®ã£ã³Ã‘ã¢ã¥ã«ã®,Rock,Rock,Ãšã ã«ã«ã»,8077,2019,107445
# Â²ãœã“ã±ãˆã™,Country,Country,Âºãºãã’ã‚ã›ã“ãª,8151,2002,107521
# Ã‚ã«ã ã¤ã¨ã¬ã¨ã°Ã€ã±ã¬ã®ã«ã®ã¢,Country,Chanson,Ã’ã ãªã®ã¢ã Ã±ã¥ã«ã¿ã¢ã¨Ã¨ã«ã¨SexÃ¯ã®Ã°ã³ã...,8246,2000,107620
# Ã—ã¥Ã²ã¥Ã­ã ã¤ã®,Country,Country,Ã—ã¥Ã²ã¥Ã­ã ã¤ã®,8351,2016,107730
# Ã‘ã¥ãªã²ã®ã°Ãƒã ã§ã,Country,PunkRock,Ã‘ã¥ãªã²ã®ã°Ãƒã ã§ã,8355,1987,107734
# Ã—ã¨ã¦&Co,Blues,Rock,Ãã¥ã°ã¥ãªã°ã¥ã±ã²ã®ãª,8370,1994,107750
# Ã¤â½?ã©â€¡å½ã¥â€¦æ’ã¦ëœâ¥,Blues,Jpop,Someday,8373,2002,107753
# Ãƒã“âµãºã…ã¯,Blues,Pop,Â·râ±â¡â³â´â¨ã€,8398,1985,107779
# Ã¦â°â´ã¦â¨â¹ã¥â¥ë†ã£â‚¬â€¦,Blues,Jpop,SupersonicGirl,8412,2001,107794
# Ã§å¸â³ã¥å½å¸ã¦â€¦å½ã¤â¸â‚¬,Blues,Blues,I-sing,8467,2018,107852
# Ã§å¡â€ ã¥â·?ã§â´â€ã¥â­?,Blues,Jpop,FutureOfBlue,8498,2003,107886
# ????,Blues,Blues,Hope,8543,1990,107934
# Â¸ã°â¸â§,Blues,Blues,Â¸ã°â¸â§,8559,2019,107951
# Ã§å¸â³ã¥â·?ã£â€šâ»ã£æ’âª,Blues,Pop,Ã§â¿â¼Ã£â‚¬å“Ã¦â­â¦ã¦âºâ‚¬ã¥â¾â¹ã£æ’?ã£æ’æ’ã£...,8588,1995,107982
# Ã£?â¤ã£â€šâ€œã£??,Blues,Jpop,Take1,8590,2004,107984
# Ã¤â¸â­ã¥â³â¶ã£?â¿ã£â€šâ€ ã£??,Blues,Oldies,Ã¥â¤â§ã©å â‚¬ã¥â¹â€¢,8624,1999,108023
# Âµâ´â§â®âºqâ¤ã¢,Blues,ACappella,Â°ãªâ»yâ±ã†â¦ã¦âº]â¤t,8772,1999,108176
# Â³â³ã»f,Blues,Pop,Â³â³ã»f,8798,1997,108202
# Â¾ã°â´ãâ³ã—Ã€ãœâ¹ãÿâ°ã¼,Newage,Rock,Âºã±âµã‘â±ã¢â´ã‚Ã‡ãâ´ãƒã€ã‡Ãã£,8844,2000,108249
# Ã¦??ã©â€¡å’,Newage,Pop,MoonlitSummerTales,8848,1998,108253
# Ã§å¸â³ã¤âºâ€¢ã§â«å“ã¤â¹å¸,Newage,NewAge,Ã¦âµâªã¦â¼â«,8850,2002,108255
# Ã¥?â€šã¦å“â¬ã£â€šâµã£æ’ë†ã£æ’â«,Newage,Jpop,Ã§âµâ€šã£â€š?ã£â€šâ€°ã£?âªã£?â€žã¦â­å’,8864,2000,108271
# Ã¤â¸â­ã¨â¥â¿ã¥å“â­ã¤â¸â€°,Newage,NewAge,Songs,8866,1998,108273
# Ã£â€šâ¢ã£æ’â«ã£æ’â€¢ã£â€šâ£ã£æ’â¼,Newage,NewAge,LiveInProgressDisc1,8897,1995,108306
# Ã£æ’?ã£æ’â¥ã£æ’â¼ã£æ’âªã£æ’æ’ã£æ’â€”,Newage,NewAge,Ã£æ’?ã£æ’â¥ã£æ’â¼ã£æ’âªã£æ’æ’ã£æ’â€”ã£æ’â»ã£â€š...,9022,2000,108435
# Ã¦âµâ·ã¦?â´ã©å¡å,Newage,NewAge,Ã¦å“â±ã¥â¤?ã£â€šâ€™ã©?å½ã£?å½ã£?â¦ã§â„¢â½ã§â§â€...,9031,2001,108445
# Ã§â«â¹ã¥â€ â€¦ã£?â¾ã£â€šå ã£â€šâ€ž,Newage,NewAge,Beginning,9093,1997,108510
# Ã¨?â€™ã¤âºâ€¢ã§â€â±ã¥â®å¸,Newage,NewAge,Ã£æ’â¦ã£æ’â¼ã£æ’å¸ã£æ’â³ã£æ’â»ã£â€šâ³ã£æ’â¬ã£â€...,9099,1992,108518
# Ã¦??ã©â€¡å’,Newage,Pop,MindCruisin',9100,1990,108519
# ????,Newage,Polka,A.I.R,9105,2003,108525
# Ã¦?â¾ã¦âµâ¦ã¦å“â€°ã¥â¸å’,Newage,Jpop,InvisibleCircle,9119,1999,108539
# Ã„ã ã°ã¨ã£ã Ãã ã§ã ã°ã¡ã ã¥ã¢ã,Classical,Vocal,Ãã®Ã¿Ã‚ã ã±Ã¢ã±â¸-ã²ã ãªã¨Ã«ã¾ã¡ã«ã¾...,9424,2001,108851
# Â¶ã€ãƒã½â¬ã‚+â¶ã€â¹ã…â¤d,Classical,ClassicRock,Â¥|â¤ã¢ãpâ¼uâ¤â§â¥â´ã‚â½â­âµâ¼ã–â²â°,9432,2002,108860
# Â»ã§â¶ã»ã€ã‡Â³â¯â°â³,Classical,Ccm,FlyToTheDream,9581,2002,109012
# Ã“ã¡â²â®ãâ¥,Classical,Classical,Ãšã±ã–ãã‡ã™ã”ãCd2-1,9586,2000,109017
# Â³\\â´âºâ²e,Classical,AcidPunk,Â¤ã‘â³â»âªâºâ¤ã«â®qâ°ãš,9612,1996,109044
# Ã£â€šâ¢ã£æ’â³ã£æ’â€°ã£æ’â¬ã£æ’â»ã£â€šâ®ã£æ’â£ã£...,Classical,Classical,Ã£æ’â€ã£â€šâ¢ã£æ’å½ã£æ’â»ã£æ’â¡ã£æ’æ’ã£â€šâ»ã£...,9791,1997,109228
# Â®]â«ã˜â¥â­&sweetStyle,Classical,Pop,Â­âµâ¼ã–âºãâ³ãµâ¬yâ¦ã¦âªã·â¦â±(â¥|),9889,1992,109327
# Ã‚ã¥ã°ãªã Ã‘ã¥ã°ã¤ã¾ã·ãªã,Classical,Pop,Ã•ã -ãã -ã˜ã®!,9984,2003,109426
# Ivory,Soundtrack,Soundtrack,Ã£?â¨ã£â€šâ€°ã£?â€žã£?â€šã£â€šâ€œã£??ã£â€šâ€¹ã£...,10065,2000,109507
# Ã£æ’â€°ã£æ’â©ã£æ’å¾cd,Soundtrack,Soundtrack,Cdã£æ’â€°ã£æ’â©ã£æ’å¾Ã£?â¨ã£??ã£â€š?ã£??ã£æ’â¡...,10091,1995,109533
# Ã£æ’â¦ã£æ’â€¹ã£â€šâ¾ã£æ’â³ã£â€šâ·ã£æ’â€¢ã£æ’ë†,Soundtrack,Soundtrack,Ã¥â¿ëœã£æ’â¬ã£æ’å ã¨?â€°Forget-me-notÃ£â€šâªã...,10093,2002,109535
# Ã¤â¹â€¦ã§å¸â³ã¨â­â²,Soundtrack,Soundtrack,Ã©â¢â¨ã£?â®ã¨â°â·ã£?â®ã£æ’å ã£â€šâ¦ã£â€šâ·ã£â€š...,10146,1987,109588
# Â°ã»â»ã³â¿â±,Soundtrack,Gospel,Ãƒâ¹â¹ã¸ã‚â°Â¿â¹â¼ã¶Ã€ãœâ¾ãÿâ±ã¢-Â°ã¸â»ã½â¾ã–,10183,2001,109626
# Â¢ã­ã­ã¡Ã‚ãÿã³ã³ã§,Soundtrack,Ãã¯ãã¥,Ãã¡ã±ãœã®ã¥ã­ã¥ã²Ã¥ã©ãªã¼ã­ã¥ã²,10207,2004,109651
# Ãšã®ã°ã­ã¥ã«ã¾ãªÃˆã£ã®ã°ã¼,Soundtrack,Soundtrack,Ãã ã­ã¤ã¨ã²ã±ãªã¨ã©Ãã¥ã²ã¥ã°ã¡ã³ã°ã£(ã¬ã³ã§...,10242,2001,109687
# Ã¥â€™å’ã§â€â°Ã¨â€“â«,Soundtrack,Anime,3ãƒâ€”3EyesÃ§â¬â¬ã¥â¼?ã§â«â,10252,1991,109697
# Â±ã¨Â´ã«ãˆâ«,Soundtrack,Soundtrack,Â¹ãœâ¼ãºâ°ã¼â¿â·Âµâ¿â¹â°â¿ã¸,10296,2000,109743
# Ããÿãªã¯ã²Ãã¯ã±ã´ã¯ãªãœã«ã¯ã£ã«ã¯ãµ,Soundtrack,Soundtrack,Ãœã°ã±ã¡ã¦ã©ã«ãã±ã¯Ost,10301,2001,109749
# Â¼ã’â¸â®â¿â¤,Ccm(contemporaryChristianMusic),Ccm(contemporaryChristianMusic),ModernWorshipShema(â½â¦â¸â¶),10337,2002,1866
# Ãœã³ã°ã§ã¨ã«ãªã¨International,Folk,RussianPop,Ãœã³ã°ã§ã¨ã«ãªã¨+,10345,2003,2252
# Â²ãœã‡ã™,Folk,Pop,Ãžã§ã’â¹â³â¡,10350,1995,2418
# Ãœã³ã°ã§ã¨ã«ãªã¨International,Misc,RussianPop,Ãœã³ã°ã§ã¨ã«ãªã¨+,10438,2003,4733
# Ã¦??ã©â€¡å’,Rock,Pop,Opus21Disk1,10597,1995,7605
# ------------------------------------------------
# 180,1015,????????
# 181,1015,???????
# 182,1015,?????
# 183,1015,???????????
# 184,1015,???????
# 185,1015,???????????????
# 186,1015,???????
# 187,1015,????????
# 188,1015,?????
# 189,1015,???????
# 190,1015,????????
# 191,1015,??????
# 192,1015,??
# 193,1015,????????
# 675,1047,Ã¥??ã¥â€°?ã£?â®ã£?âªã£?â€žã©â³â¥
# 14695,2136,???/TakeTheA-train
# 14696,2136,???/GirlFromIpanema
# 14697,2136,???/AllTheThingsYouAre
# 14698,2136,???/Bluesette
# 14699,2136,???/LullabyOfBirdland
# 14700,2136,???/SummerSamba
# 14701,2136,???/HowHighTheMoon
# 14702,2136,???/Desafinado
# 14703,2136,???/TakingAChanceForLove
# 14704,2136,???/MoonRiver
# 14705,2136,???/SatinDoll
# 14706,2136,???/ThisOne'sForCharlie
# 18945,2474,Ã©â¢â¨ã£?â®ã¥?â¹ã£??ã¤â¸ëœ
# 18949,2474,Ã¥å“â°ã¥â€ºâ³ã£â€šâ€™ã£??ã£?â ã£?â€¢ã£?â€ž
# 19340,2506,Ã£?â»ã£?å ã£?å¡ã£??
# 19716,2536,Ã¨â‚¬â³ã£?â®ã§â€”â€ºã£??ã£?âªã£â€šâ€¹ã£â€šë†ã£?...
# 19717,2536,Ã¤âºå’ã¥??ã¥â€ºâ€ºã¦â„¢â€šã©â€“â€œã¥â¯?ã£?âªã£?...
# 22523,2745,Ã§â€å¸ã£??ã£?å’ã£?â€ž
# 26039,3004,Ã£??ã£æ’â»ã£â€šå’ã£æ’â»ã£?â€žã£æ’â»ã£â€šâ€
# 26041,3004,Ã£??ã£?â£ã£?â¨ã£æ’â¢ã£æ’â¼ã£æ’â€¹ã£æ’â³ã£â€šâ°
# 26043,3004,Ã§â´â«ã©â„¢â½ã¨å â±ã£?â®ã¥â€™â²ã£??ã¥âºâ­ã£?â§
# 27364,3110,Ã£??ã£?â£ã£?â¨
# 27674,3135,Ã£æ’?ã£æ’â³ã£â€šâ¶ã£â€šâ¤ã£â‚¬å“ã¥â¥â½ã£??ã£?â§...
# 27675,3135,Ã£??ã£?â¿ã£?â ã£?â€˜ã£â€šâ€™
# 27677,3135,Ã£?â€žã£?â€žã£?å¸ã£?â€žã¤âºâ€¹ã£?â¯ã£??ã£â€šå’ã...
# 31826,3436,Ã¦â³â£ã£??ã£?å¸ã£?â€žã¦â°â€”ã¦å’?ã£?â¡
# 31976,3449,Ã¦â½â®ã©â¢â¨ã£?â«ã©â‚¬â¢ã£?â€žã£?â«ã£??ã£â€šå’ã...
# 33289,3540,Ã¥â®â€¡ã¥â®â„¢ã£â€šâ€™ã§â¶â„¢ã£??ã¨â‚¬â€¦
# 35907,3739,Ã¥â§â€œã¥??(ã£æ’?ã£æ’â¼ã£æ’â ã£â€šâ¨ã£æ’â³ã£æ’ë...
# 37345,3844,???/FastForward(kaiserSouzaiMix)
# 37352,3844,???/Promo
# 37418,3850,Ã£?â„¢ã£??
# 38827,3957,Ã£??ã£?â°ã£?â€¹ã£?â„¢ã£?â€ ã£?â€¢ã£?å½
# 38828,3957,Ã£??ã£?â£ã£?â¨ã¢â‚¬å“iLoveYouã¢â‚¬?
# 39175,3985,Ã£?â¤ã£â€šâ€ ã£??ã£?â€¢ã¯â¼ë†ã¥â°?ã¥â¤å“ã¦â€ºâ²...
# 42317,4218,YourLoveMyExecutioner/???
# 43803,4328,Ã¤â½â€¢ã£?â¨ã£?âªã£??ã¥â«å’ã£?âªã¥â¤å“
# 45801,4475,06Ã£??ã£â€šâ€°ã£?â¨ã£?â¶ã£æ’?ã£â€šâ±ã£æ’â¢ã£æ’...
# 46125,4501,Ã¦â„¢â€šã£?â®ã£â€š?ã£??ã£â€šå ã£?â€šã£?â€ž
# 48016,4639,Ã¦â„¢â€šã£?â®ã©?å½ã£?å½ã£â€šâ€ ã£??ã£?â¾ã£?â¾ã£?â«
# 50895,4843,Ã¨â¨â‚¬ã¨â€˜â€°ã£?â«ã£?â§ã£??ã£?âªã£?â€ž
# 51484,4888,??-????
# 52268,4943,Ã¥â¤â¢ã£?â®ã£?â¤ã£?â¥ã£??
# 52270,4943,Ã£?â¿ã£?â«ã£??ã£?â€žã£?â€šã£?â²ã£â€šâ€¹ã£?â®ã£?â€œ
# 55432,5171,Ã¦â½â®ã©â¢â¨ã£?â«ã£?â€¢ã£??ã£â€š?ã£â€šå’ã£â€šâ€...
# 55442,5171,Ã¥?â€“ã¦â¶ë†ã£?â€”ã£?â¦ã£??ã£?â ã£?â€¢ã£?â€ž
# 56279,5233,Ã¥??ã¥â­â€”ã¨â·â¯
# 56284,5233,Ã£??ã£?â€”ã£?â¦ã£æ’â€˜ã£æ’â¬ã£æ’â¼ã£æ’â€°ã£?â¯ã...
# 56678,5264,GofankeÃ£â‚¬å“ã£?â€ã£?âµã£??ã£â€šâ€œã£?â€˜ã£â...
# 60901,5594,Ã¦å“ë†ã£?â«ã¥â€™â²ã£??ã¨å â±
# 60906,5594,Ã¦â¶â„¢ã£?â®ã£â€šë†ã£?â€ ã£?â«ã£??ã£â€šå’ã£?â€ž...
# 60973,5600,Ã§â½âªã¦â·â±ã£??ã¦â€žâ€ºã£?â€”ã£?â¦ã£â€šë†
# 60980,5600,Ã£?â€ ã£??ã£?â¤ã£??ã£?â®ã£?â«ã¦â€¦â£ã£â€šå’ã£?â...
# 63212,5775,Ã¥??ã¤âºå’ã¦å“ë†ã£?â®ã£â€šâ¢ã£æ’æ’ã£æ’â€”ã£æ’â«...
# 63221,5775,Ã£â€šâ€ ã£?â£ã£??ã£â€šå
# 65868,5984,Ã£â€šâ€šã£?â€ ã£?ëœã£??ã¥â€ â¬ã£?å’ã¦?â¥ã£â€šâ€¹
# 67083,6073,???/JohnWayneGacey
# 67084,6073,???/TheClownWhoKilledBoys
# 67085,6073,???/KennethBianchi
# 67086,6073,???/KennethBianchiWhinges
# 67087,6073,???/DennisNilsen
# 67088,6073,???/IncidentAt23CranleyGardens
# 67089,6073,???/HaroldShipman
# 67090,6073,???/HaroldShipmanTellsLies
# 67091,6073,???/HenryLeeLucas
# 67092,6073,???/HenryLeeLucas,WhiteTrashMotherfucker
# 67093,6073,???/NewsOfMoorsMurderersSentenceIsAnnou...
# 67094,6073,???/IanBrady&MyraHindley
# 67095,6073,???/SeddleworthMoor
# 68607,6196,Ã£?å“ã£?â£ã£?å¸ã£?â€žã£??ã£?â€ ã£?â«ã¦â±âºã£?â¾...
# 69760,6281,Ã£æ’â€¡ã£â€šâ¤ã£â€šâ´ã£?â®ã¨âµâ¤ã£?â®ã¨â¼?ã£??ã...
# 70908,6374,Ã£?â´ã£?â€šã£?â®(ã§â´â€ã¥??ã§?â€ ã¦â²â„¢&joe's...
# 70914,6374,Ã¥â¤â§ã£??ã£?âªã©â¢â¨(ã©ëœâ¿ã¦â³â¢ã¦â â¹ã§â¶â¾ã...
# 72700,6514,Ã¤â¿âºã¨â€°â²ã£?â«ã£??ã£?â¾ã£â€šå’
# 72705,6514,Ã£??ã£â€šå’ã£?å¾ã£â€šå’ã£?â®ã§?â€ ã§â€â±
# 74917,6689,Ã£â€šâ°ã£æ’æ’ã£?â¨ã£??ã£â€šå’ã£?â€žã£?â«ã£?âªã£...
# 75373,6724,Ã£?å ã£?â€¢ã£?ë†ã£??ã£â€šå’ã£?âªã£?â€žÃ£?â€œã£...
# 75381,6724,Ã©â€ºâ¢ã£?â€”ã£?å¸ã£??ã£?â¯ã£?âªã£?â€ž
# 78675,6974,???
# 78993,7000,Ã¦â³â¢ã£?â®ã£â€šâ€ ã£??ã£?ë†
# 79646,7051,Ã£?â¼ã£??ã£â€šâ€°ã£?âªã£â€šâ€°
# 79653,7051,Ã¤â¼å¡ã£?â€žã£?â«ã£?â€žã£??
# 80092,7086,????
# 82107,7236,Ã¥â€ºâ½ã¥??ã¦â€â¹ã¦â­â£ã¨â«â€“(ã£â‚¬å½ã©â‚¬æ’ã...
# 84327,7408,Ã£?å¸ã£â€š?ã£?â€žã£??
# 88066,7690,???
# 88067,7690,???
# 88068,7690,???
# 89928,7827,DevilSpeak(ã¥â°å½ã£??)
# 89952,7829,Ã£?â»ã£â€šâ€°ã£?âµã£??ã£æ’å¾ã£æ’â€°ã£æ’â­ã£â€šâ¹
# 89955,7829,Ã¥??ã©â€¦â€™ã§â¯â‚¬
# 89958,7829,Ã£â€šâ¹ã£æ’â€ã£æ’â¼ã£æ’â€°ã©?â€¢ã¥??
# 92368,8015,Ã©â€¡å½ã£?â®ã¨å â±ã£?â«ã£??ã£â€šë†ã©â¢â¨Ã£â€šâ...
# 93099,8070,Ã¥?â€ºã£?å’ã¥â¥â½ã£??ã£?â ã£?â€¹ã£â€šâ€°
# 93101,8070,Ã£?â€šã£?âªã£?å¸ã£?â®ã¤â¸â€“ã¤â»â£ã£?â¸ã£??ã£?â...
# 93102,8070,Ã¦å â±ã£??ã£?â€”ã£â€š?ã£?â¦!
# 93104,8070,Ã©â¢â¨ã£â€šâ€šã§â©âºã£â€šâ€šã£??ã£?â£ã£?â¨ã¢â‚¬â¦
# 97622,8416,Ã¨â»å ã£?â¨ã£?â€žã£?âµã¥??ã£?â®ã¥â¯â€ ã¥â®â¤
# 98338,8473,Ã£?â„¢ã£?â¹ã£?â¦ã£?â«ã§â­â€°ã£?â€”ã£??ã¥?â¹ã£??...
# 98342,8473,Ã¥??ã©â‚¬â€
# 99222,8543,????????
# 99223,8543,?????
# 99224,8543,??????
# 99226,8543,????
# 99227,8543,??10???3?
# 99228,8543,????????
# 99229,8543,?????
# 99231,8543,???
# 99457,8562,Ã£?å¸ã£â€š?ã£?â€žã£??-natsuyasumix-
# 99459,8562,Ã¨â¼?ã£??ã¥â¤?ã£æ’â»ã£æ’â»
# 99778,8588,Ã£â€š?ã£??ã£â€šå ã©â‚¬â¢ã£?â€ž
# 99782,8588,Ã§âªâ€œã£?â®ã£?â€¹ã£??ã£â€šå’ã£â€šâ€œã£?â¼
# 99803,8590,Ã£?â¤ã£â€šâ€œã£??With7house/loveÃ£â‚¬å“ã¦å â...
# 99806,8590,TheÃ£?â¤ã£â€šâ€œã£??ã£â‚¬â‚¬ã£æ’â€œã£æ’ë†/ã£?â...
# 99807,8590,Ã¨â¦â€¹ã£?â¦ã£?å ã£??ã£â€šå’ã¯â¼?ã£â‚¬â‚¬myLovers
# 99809,8590,Ã£?â¤ã£â€šâ€œã£??ã£â‚¬â‚¬withÃ©â«ëœã¦â©â€¹ã¦â€...
# 99810,8590,TheÃ£?â¤ã£â€šâ€œã£??ã£â‚¬â‚¬ã£æ’â€œã£æ’ë†/ã¦ëœ...
# 100218,8624,Ã¥â€˜â½ã£?â®ã¥ë†â¥ã¥??
# 100226,8624,Ã§å¾â¬ã£??ã£â€šâ€šã£?â€ºã£?å¡
# 100979,8681,???/BlueMonday
# 100980,8681,???/EdWard
# 100981,8681,???/TrainYourChild
# 100982,8681,???/WhatAreTheyDoin'InHeavenToday
# 100983,8681,???/IHadAGoodFatherAndMother
# 100984,8681,???/EdWard
# 100985,8681,???/EverbodyOughtaPraySometime
# 100986,8681,???/TheKingOfKings
# 100987,8681,???/HoneyInTheRock
# 100988,8681,???/Lord,IWishICouldSee
# 100989,8681,???/EdWard
# 100990,8681,???/GetOnBordLittleChildren
# 100991,8681,???/Don'tLeave,ThisMayBeTheLastTime
# 100992,8681,???/ThoseChimingBells
# 100993,8681,???/JesusIsTheFirstLineOfDefence
# 100994,8681,???/EdWard
# 100995,8681,???/DigALittleDeeper
# 100996,8681,???/Sometimes
# 100997,8681,???/IJohnSaw
# 100998,8681,???/YieldNotToTemptation
# 100999,8681,???/EdWard
# 101000,8681,???/LoveLikeARiver
# 101001,8681,???/WalkInTheLight
# 101002,8681,???/ITellIt,WhereEverIGo
# 101003,8681,???/EdWard
# 101004,8681,???/He'sMyRug
# 101005,8681,???/MustJesusBearThisCrossAlone?
# 101006,8681,???/GodIsStandingBy
# 101007,8681,???/Oh,WhatAMeeting
# 101008,8681,???/EdWard
# 103189,8850,Ã©?â ã£??ã£?â¸ã¢â‚¬â¦(albumMix)
# 103351,8864,Ã¥æ’â€¢ã£?â¯ã£?â©ã£?â€œã£?â¸ã¨â¡å’ã£??
# 103775,8899,Ã£æ’å ã£æ’â³ã£æ’â€˜ã£??ã£â€šâ€œ
# 103780,8899,Ã£??ã£?â®ã£?â¾ã£?â¾ã£?â®ã¥?â€º
# 105267,9022,Ã£?â¼ã£??ã£?å’ã£?â¤ã£??ã£?â£ã£?å¸ã¦â€žâ€ºã£?â®ã...
# 105270,9022,Ã£?âªã£??ã£?â€”ã£?å¸ã¨â¨â‚¬ã¨â€˜â€°
# 105271,9022,Ã¦â€šâ²ã£?â€”ã£??ã£æ’â¬ã£â€šâ¤ã£æ’â³ã£æ’â»ã£æ’ë...
# 105273,9022,Ã¥â¨ëœã£?å’ã¥â«?ã£??ã¦å“?
# 105381,9031,Ã£?â¾ã£?â£ã£?â„¢ã£??ã£?â®ã¥â€â€ž
# 105386,9031,Ã£?â¾ã£?â€žã£æ’â»ã£?â±ã£??ã£?â¨ã£?âªã£æ’â¼
# 105390,9031,Ã£?â¾ã£?â£ã£?â„¢ã£??ã£?â®ã¥â€â€ž(acousticVers...
# 106188,9093,Ã¨â¼?ã£??ã£â€šâ¹ã£â€šâ¿ã£æ’â¼ã£æ’âªã£æ’â¼ã£æ’å ...
# 106195,9093,Ã£?â„¢ã£?â¦ã£??ã£?âªã£æ’â€™ã£æ’æ’ã£æ’ë†ã£â€šâ½ã...
# 106272,9099,Ã§â¿â³ã£â€šå ã£â€šâ€ ã£??ã©æ’â¨ã¥â±â€¹
# 106341,9105,???albumVersion?
# 106343,9105,???????????
# 106602,9124,Ã¦â°â´ã£æ’â»ã©â„¢â¸ã£æ’â»ã£??ã£â€šâ€°ã£â‚¬?ã§â€...
# 117140,9888,???/Nr.30Balett
# 120012,10065,Ã¦â¤å½ã¥??ã£â€šâ€ ã£?â€ ã£?â²/namelessMelodies...
# 121483,10167,Ã£??ã£?â®ã¦â€°â€¹ã£â€šâ€™ã©â€ºâ¢ã£?â€¢ã£?å¡ã£?â...
# 121777,10190,Tokio23/ã£?â€ã£??ã£?â€™ã£â€šâ€œã£?â«ã£æ’ë†ã£æ’...
# 122027,10210,Ã£??ã£?â£ã£?â¨ã£â‚¬?ã£?å¡ã£?â£ã£?â¨
# 122509,10241,Ã¦â€šâ²ã£?â€”ã£??ã¥â®â€¡ã¥â®â„¢ã¥â€¦âµ
# 122532,10241,Ã¥â¾â©ã¨ë†ë†ã£?â®ã£?â²ã£?â³ã£??
# 122690,10252,<3ãƒâ€”3ã¥??ã¤â½å“ã¥å â€¡ã¥â â´>Ã§â„¢â½ã©â€ºâª...
# 122692,10252,<3ãƒâ€”3ã¥??ã¤â½å“ã¥å â€¡ã¥â â´>Ã£æ’â€˜ã£â€šâ¤...
# 122694,10252,<3ãƒâ€”3ã¥??ã¤â½å“ã¥å â€¡ã¥â â´>Ã£â€šâ·ã£æ’â³ã...
# 122696,10252,<3ãƒâ€”3ã¥??ã¤â½å“ã¥å â€¡ã¥â â´>Ã£â€šâ¢ã£æ’â«ã...
# 127155,10597,Ã©å“â§ã©â€ºâ¨ã£?â«ã¦â¶ë†ã£?ë†ã£?â¦ã£â€šâ€ ã£??
# 127165,10597,Ã£?â€¢ã£â€šë†ã£?âªã£â€šâ€°ã£?â€”ã£â€šâ€œã£??ã£â...
# Data removed: 205 rows
# Tracks removed: 194 rows

# %%
# before
print(len(clean_data))

## remove indexes from dataframes according to rr1 and rr2
clean_data.drop(clean_data.index[rr1], inplace=True)
clean_tracks.drop(clean_tracks.index[rr2], inplace=True)

#after
print(len(clean_data))
# Out:
# 7663
# 7458

# %%
# renaming tracks column to album_id for uniformity
clean_data = clean_data.rename(columns={"tracks": "album id"})

# %%
# we could have intorduced a album dependancy failure, so we need to check for that
def album_dependancy_check(df, tracks):
    id_to_remove = []

    for i, row in df.iterrows():
        if i == 0:
            pass
        else:
            album_id = row[4]

            tracks_for_album = tracks[tracks['Album Id'] == album_id]
            if len(tracks_for_album) == 0:
                id_to_remove.append(album_id)

    return id_to_remove

# %%
Albumns_with_no_songs_idx = album_dependancy_check(clean_data, clean_tracks)
print("Before found: " + str(len(Albumns_with_no_songs_idx)) + " out of " + str(len(clean_data)))

for id in Albumns_with_no_songs_idx:
    idx = clean_data[ clean_data['album id'] == id].index
    clean_data.drop(idx, inplace = True)


Albumns_with_no_songs_idx_2 = album_dependancy_check(clean_data, clean_tracks)
print("After found: " + str(len(Albumns_with_no_songs_idx_2)) + " out of " + str(len(clean_data)))
# Out:
# Before found: 1 out of 7458
# After found: 0 out of 7457

# %% [markdown]
# ## Export to TSV

# %%
clean_data.to_csv('../../cleaning_stages/7_unit_code_repair/cddb_5.tsv', sep="\t", index=False)
tracks.to_csv('../../cleaning_stages/7_unit_code_repair/cddb_tracks_2.tsv', sep="\t", index=False)
